# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create multiple city specific map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /opt/homebrew/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/homebrew/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /opt/homebrew/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2>=2.9->folium) (3.0.1)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_housing_assistance.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#                                            Assistance  \
# 0                         Temporary Overnight Shelter
# 1        Veteran Housing Transitional Housing Program
# 2                            Substance Abuse Services
# 3                           Homeless Motel Assistance
# 4   Housing for Pregnant Women and Women with Chil...
# 5               Transitional Shelter for Single Women
# 6                                Transitional Housing
# 7        Overflow Shelter for Single Women & Families
# 8                                Shelter for Families
# 9              Transitional Housing for Single Adults
# 10                                     Drop-In Center
# 11                               Transitional Housing
# 12                 Transitional Housing for Young Men
# 13                    Transitional Supportive Housing
# 14                       Permanent Supportive Housing
#
#                                Agency                     Address  \
# 0              FAMILY HOUSING NETWORK  1606 S Lemay Ave Suite 103
# 1      VOLUNTEERS OF AMERICA COLORADO        1055 Avenida Del Sol
# 2                           A WAY OUT                 PO Box 1124
# 3             CARING & SHARING SALIDA                220 W 4th St
# 4        CATHOLIC CHARITIES OF DENVER               6240 Smith Rd
# 5        CATHOLIC CHARITIES OF DENVER            2301 Lawrence St
# 6                       DREAM CENTERS             3650 Airport Rd
# 7   CATHOLIC CHARITIES LARIMER COUNTY        460 Linden Center Dr
# 8                HOPE @ MIRACLE HOUSE                 Main Street
# 9                      ITHAKA HOUSING                 321 Mesa Rd
# 10    MILE HIGH BEHAVIORAL HEALTHCARE             13387 E 19th Pl
# 11            HASEYA ADVOCATE PROGRAM                        I-25
# 12                 PROVIDENCE NETWORK                801 Logan St
# 13     GRAND VALLEY CATHOLIC OUTREACH                245 S 1st St
# 14     GRAND VALLEY CATHOLIC OUTREACH                245 S 1st St
#
#                 City State    Zip           County  \
# 0       Fort Collins    CO  80525   LARIMER COUNTY
# 1            Durango    CO  81301  LA PLATA COUNTY
# 2         Carbondale    CO  81623    PITKIN COUNTY
# 3             Salida    CO  81201   CHAFFEE COUNTY
# 4             Denver    CO  80207    DENVER COUNTY
# 5             Denver    CO  80205    DENVER COUNTY
# 6   Colorado Springs    CO  80910   EL PASO COUNTY
# 7       Fort Collins    CO  80524   LARIMER COUNTY
# 8        Fort Lupton    CO  80621      WELD COUNTY
# 9   Colorado Springs    CO  80905   EL PASO COUNTY
# 10            Aurora    CO  80011     ADAMS COUNTY
# 11  Colorado Springs    CO  80903   EL PASO COUNTY
# 12            Denver    CO  80203    DENVER COUNTY
# 13    Grand Junction    CO  81501      MESA COUNTY
# 14    Grand Junction    CO  81501      MESA COUNTY
#
#                                              Services  \
# 0   Provides a temporary overnight shelter for fam...
# 1   Provides veterans and their families shelter a...
# 2   Offers services that helps those suffering fro...
# 3   Provide short-term emergency housing on a case...
# 4   Provides housing and supportive services for p...
# 5   Provides shelter for up to 6 months for single...
# 6   Provides transitional housing for homeless or ...
# 7   Provides nightly, year-round overnight shelter...
# 8   Seeks to address the needs of homeless familie...
# 9   Provides transitional housing, in a group home...
# 10  Provides the following drop-in services: Break...
# 11  Provides transitional housing for Native Ameri...
# 12  Provides transitional housing and wrap-around ...
# 13  Provides individuals with the opportunity to e...
# 14  Provides homes to those with mental or physica...
#
#                                           Eligibility  \
# 0   Eligibility: Eligible adults must:Have at leas...
# 1   Eligibility: Veterans aged 18 and older who ar...
# 2   Eligibility: Individuals must be a resident of...
# 3   Eligibility: Individuals and families experien...
# 4   Eligibility: Pregnant women and female-identif...
# 5   Eligibility: Single women aged 18 and older Ar...
# 6   Eligibility: Homeless or imminently homeless w...
# 7   Eligibility: Female gender served only. There ...
# 8   Eligibility: Families experiencing homelessnes...
# 9   Eligibility: Individuals must: Be single men (...
# 10  Eligibility: No restrictions applied Area Serv...
# 11  Eligibility: Available to Native American surv...
# 12  Eligibility: Young men aged 18 - 25 years and ...
# 13  Eligibility: Individuals experiencing homeless...
# 14  Eligibility: Individuals and families living w...
#
#                                                 Hours  \
# 0   Monday - Friday, 9 a.m. - 5 p.m. (Administrati...
# 1   Monday - Friday, 8 a.m. - 5 p.m. (Administrati...
# 2                    Monday - Friday, 9 a.m. - 5 p.m.
# 3           Monday - Saturday, 10:30 a.m. - 1:30 p.m.
# 4   Monday - Thursday, 8 a.m. - 5 p.m.; Friday, 8:...
# 5   Monday - Friday, 8:30 a.m. - 5 p.m. (Administr...
# 6                              24 hours/7 days a week
# 7   Monday - Friday, 8:30 a.m. - 12 p.m., 1 p.m. -...
# 8                                          Hours Vary
# 9                  Monday - Thursday, 8 a.m. - 5 p.m.
# 10  Monday - Friday, 7:30 a.m. - 4:30 p.m. (Drop-I...
# 11  Monday, Wednesday, Thursday 9:00 a.m. - 3:00 p...
# 12  Monday - Friday, 8 a.m. - 5 p.m. (Administrati...
# 13               Monday - Friday, 9 a.m. - 11:30 a.m.
# 14               Monday - Friday, 9 a.m. - 11:30 a.m.
#
#                                        Phone  \
# 0                             (970) 484-3342
# 1                             (970) 259-1255
# 2                             (970) 340-4505
# 3                             (719) 539-4849
# 4                             (720) 799-9400
# 5   (720) 799-9506 (Samaritan House at 48th)
# 6                             (719) 301-5411
# 7                   (970) 493-0141 (Shelter)
# 8              (720) 676-9697 (Message Line)
# 9                             (719) 578-1629
# 10                            (303) 341-9160
# 11                            (719) 660-3939
# 12                            (303) 860-8404
# 13                            (970) 241-3658
# 14                            (970) 241-3658
#
#                                               Website   Latitude   Longitude
# 0        http://familyhousingnetwork.org/our-programs  40.566559 -105.056925
# 1   http://voacolorado.org/gethelp-southernco-veth...  37.276682 -107.884155
# 2                                  http://awayout.org  39.400565 -107.211241
# 3                      http://salidacaringsharing.org  38.534785 -105.996096
# 4   http://ccdenver.org/marisolservices/marisol-ho...  39.775396 -104.942292
# 5                                   No Website Listed  39.755651 -104.987200
# 6           http://dreamcenters.com/marys-home/apply/  38.825542 -104.765124
# 7                        http://ccdenver.org/larimer/  40.594737 -105.069211
# 8                       http://hopeatmiraclehouse.org  40.079786 -104.809698
# 9                               http://ithakaland.org  38.845795 -104.831625
# 10  http://comitiscrisiscenter.org/aurora-day-reso...  39.746673 -104.831612
# 11                                  http://haseya.org  38.838192 -104.830329
# 12                       http://providencenetwork.org  39.729339 -104.982719
# 13                        http://catholicoutreach.org  39.065587 -108.571251
# 14                        http://catholicoutreach.org  39.065587 -108.571251

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Assistance   114 non-null    object
#  1   Agency       114 non-null    object
#  2   Address      114 non-null    object
#  3   City         114 non-null    object
#  4   State        114 non-null    object
#  5   Zip          114 non-null    int64
#  6   County       114 non-null    object
#  7   Services     114 non-null    object
#  8   Eligibility  114 non-null    object
#  9   Hours        114 non-null    object
#  10  Phone        114 non-null    object
#  11  Website      114 non-null    object
#  12  Latitude     114 non-null    float64
#  13  Longitude    114 non-null    float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 12.6+ KB
#                                            Assistance  \
# 0                         Temporary Overnight Shelter
# 1        Veteran Housing Transitional Housing Program
# 2                            Substance Abuse Services
# 3                           Homeless Motel Assistance
# 4   Housing for Pregnant Women and Women with Chil...
# 5               Transitional Shelter for Single Women
# 6                                Transitional Housing
# 7        Overflow Shelter for Single Women & Families
# 8                                Shelter for Families
# 9              Transitional Housing for Single Adults
# 10                                     Drop-In Center
# 11                               Transitional Housing
# 12                 Transitional Housing for Young Men
# 13                    Transitional Supportive Housing
# 14                       Permanent Supportive Housing
#
#                                Agency                     Address  \
# 0              FAMILY HOUSING NETWORK  1606 S Lemay Ave Suite 103
# 1      VOLUNTEERS OF AMERICA COLORADO        1055 Avenida Del Sol
# 2                           A WAY OUT                 PO Box 1124
# 3             CARING & SHARING SALIDA                220 W 4th St
# 4        CATHOLIC CHARITIES OF DENVER               6240 Smith Rd
# 5        CATHOLIC CHARITIES OF DENVER            2301 Lawrence St
# 6                       DREAM CENTERS             3650 Airport Rd
# 7   CATHOLIC CHARITIES LARIMER COUNTY        460 Linden Center Dr
# 8                HOPE @ MIRACLE HOUSE                 Main Street
# 9                      ITHAKA HOUSING                 321 Mesa Rd
# 10    MILE HIGH BEHAVIORAL HEALTHCARE             13387 E 19th Pl
# 11            HASEYA ADVOCATE PROGRAM                        I-25
# 12                 PROVIDENCE NETWORK                801 Logan St
# 13     GRAND VALLEY CATHOLIC OUTREACH                245 S 1st St
# 14     GRAND VALLEY CATHOLIC OUTREACH                245 S 1st St
#
#                 City State    Zip           County  \
# 0       Fort Collins    CO  80525   LARIMER COUNTY
# 1            Durango    CO  81301  LA PLATA COUNTY
# 2         Carbondale    CO  81623    PITKIN COUNTY
# 3             Salida    CO  81201   CHAFFEE COUNTY
# 4             Denver    CO  80207    DENVER COUNTY
# 5             Denver    CO  80205    DENVER COUNTY
# 6   Colorado Springs    CO  80910   EL PASO COUNTY
# 7       Fort Collins    CO  80524   LARIMER COUNTY
# 8        Fort Lupton    CO  80621      WELD COUNTY
# 9   Colorado Springs    CO  80905   EL PASO COUNTY
# 10            Aurora    CO  80011     ADAMS COUNTY
# 11  Colorado Springs    CO  80903   EL PASO COUNTY
# 12            Denver    CO  80203    DENVER COUNTY
# 13    Grand Junction    CO  81501      MESA COUNTY
# 14    Grand Junction    CO  81501      MESA COUNTY
#
#                                              Services  \
# 0   Provides a temporary overnight shelter for fam...
# 1   Provides veterans and their families shelter a...
# 2   Offers services that helps those suffering fro...
# 3   Provide short-term emergency housing on a case...
# 4   Provides housing and supportive services for p...
# 5   Provides shelter for up to 6 months for single...
# 6   Provides transitional housing for homeless or ...
# 7   Provides nightly, year-round overnight shelter...
# 8   Seeks to address the needs of homeless familie...
# 9   Provides transitional housing, in a group home...
# 10  Provides the following drop-in services: Break...
# 11  Provides transitional housing for Native Ameri...
# 12  Provides transitional housing and wrap-around ...
# 13  Provides individuals with the opportunity to e...
# 14  Provides homes to those with mental or physica...
#
#                                           Eligibility  \
# 0   Eligibility: Eligible adults must:Have at leas...
# 1   Eligibility: Veterans aged 18 and older who ar...
# 2   Eligibility: Individuals must be a resident of...
# 3   Eligibility: Individuals and families experien...
# 4   Eligibility: Pregnant women and female-identif...
# 5   Eligibility: Single women aged 18 and older Ar...
# 6   Eligibility: Homeless or imminently homeless w...
# 7   Eligibility: Female gender served only. There ...
# 8   Eligibility: Families experiencing homelessnes...
# 9   Eligibility: Individuals must: Be single men (...
# 10  Eligibility: No restrictions applied Area Serv...
# 11  Eligibility: Available to Native American surv...
# 12  Eligibility: Young men aged 18 - 25 years and ...
# 13  Eligibility: Individuals experiencing homeless...
# 14  Eligibility: Individuals and families living w...
#
#                                                 Hours  \
# 0   Monday - Friday, 9 a.m. - 5 p.m. (Administrati...
# 1   Monday - Friday, 8 a.m. - 5 p.m. (Administrati...
# 2                    Monday - Friday, 9 a.m. - 5 p.m.
# 3           Monday - Saturday, 10:30 a.m. - 1:30 p.m.
# 4   Monday - Thursday, 8 a.m. - 5 p.m.; Friday, 8:...
# 5   Monday - Friday, 8:30 a.m. - 5 p.m. (Administr...
# 6                              24 hours/7 days a week
# 7   Monday - Friday, 8:30 a.m. - 12 p.m., 1 p.m. -...
# 8                                          Hours Vary
# 9                  Monday - Thursday, 8 a.m. - 5 p.m.
# 10  Monday - Friday, 7:30 a.m. - 4:30 p.m. (Drop-I...
# 11  Monday, Wednesday, Thursday 9:00 a.m. - 3:00 p...
# 12  Monday - Friday, 8 a.m. - 5 p.m. (Administrati...
# 13               Monday - Friday, 9 a.m. - 11:30 a.m.
# 14               Monday - Friday, 9 a.m. - 11:30 a.m.
#
#                                        Phone  \
# 0                             (970) 484-3342
# 1                             (970) 259-1255
# 2                             (970) 340-4505
# 3                             (719) 539-4849
# 4                             (720) 799-9400
# 5   (720) 799-9506 (Samaritan House at 48th)
# 6                             (719) 301-5411
# 7                   (970) 493-0141 (Shelter)
# 8              (720) 676-9697 (Message Line)
# 9                             (719) 578-1629
# 10                            (303) 341-9160
# 11                            (719) 660-3939
# 12                            (303) 860-8404
# 13                            (970) 241-3658
# 14                            (970) 241-3658
#
#                                               Website   Latitude   Longitude
# 0        http://familyhousingnetwork.org/our-programs  40.566559 -105.056925
# 1   http://voacolorado.org/gethelp-southernco-veth...  37.276682 -107.884155
# 2                                  http://awayout.org  39.400565 -107.211241
# 3                      http://salidacaringsharing.org  38.534785 -105.996096
# 4   http://ccdenver.org/marisolservices/marisol-ho...  39.775396 -104.942292
# 5                                   No Website Listed  39.755651 -104.987200
# 6           http://dreamcenters.com/marys-home/apply/  38.825542 -104.765124
# 7                        http://ccdenver.org/larimer/  40.594737 -105.069211
# 8                       http://hopeatmiraclehouse.org  40.079786 -104.809698
# 9                               http://ithakaland.org  38.845795 -104.831625
# 10  http://comitiscrisiscenter.org/aurora-day-reso...  39.746673 -104.831612
# 11                                  http://haseya.org  38.838192 -104.830329
# 12                       http://providencenetwork.org  39.729339 -104.982719
# 13                        http://catholicoutreach.org  39.065587 -108.571251
# 14                        http://catholicoutreach.org  39.065587 -108.571251

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each housing assistance location
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_housing_assistance_map_v2.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac4acea6dc10b304a540e0eeabd3db97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac4acea6dc10b304a540e0eeabd3db97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac4acea6dc10b304a540e0eeabd3db97 = L.map(
#                 &quot;map_ac4acea6dc10b304a540e0eeabd3db97&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_623d848b26aec780cf8b7b96e7359166 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_623d848b26aec780cf8b7b96e7359166.addTo(map_ac4acea6dc10b304a540e0eeabd3db97);
#
#
#             var marker_bdb5811b086ee0a4024b911f9a38e51a = L.marker(
#                 [40.5665586, -105.0569249],
#                 {}
#             ).addTo(map_ac4acea6dc10b304a540e0eeabd3db97);
#
#
#         var popup_37c23313b5a2b8f67861309d732da2e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae1f1eea71985b4cae665c4976372cbe = $(`&lt;div id=&quot;html_ae1f1eea71985b4cae665c4976372cbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FAMILY HOUSING NETWORK&lt;/strong&gt;&lt;br&gt;     1606 S Lemay Ave Suite 103&lt;br&gt;     Fort Collins, CO 80525&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 484-3342&quot;&gt;(970) 484-3342&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://familyhousingnetwork.org/our-programs&quot;&gt;FAMILY HOUSING NETWORK&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a temporary overnight shelter for families for up to 3-4 months. Shelter locations rotate weekly among various faith communities in Fort Collins...     &lt;/div&gt;`)[0];
#                 popup_37c23313b5a2b8f67861309d732da2e5.setContent(html_ae1f1eea71985b4cae665c4976372cbe);
#
#
#
#         marker_bdb5811b086ee0a4024b911f9a38e51a.bindPopup(popup_37c23313b5a2b8f67861309d732da2e5)
#         ;
#
#
#
#
#             var marker_13a9dd0c23f9f9b34896c9e5055d780b = L.marker(
#                 [37.2766819, -107.8841553],
#                 {}
#             ).addTo(map_ac4acea6dc10b304a540e0eeabd3db97);
#
#
#         var popup_3ee3ca67666fe65b343221a9ed0e0dfc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02b2398b21ffe9d06fdf0d2eb0fee1a3 = $(`&lt;div id=&quot;html_02b2398b21ffe9d06fdf0d2eb0fee1a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;VOLUNTEERS OF AMERICA COLORADO&lt;/strong&gt;&lt;br&gt;     1055 Avenida Del Sol&lt;br&gt;     Durango, CO 81301&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 259-1255&quot;&gt;(970) 259-1255&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://voacolorado.org/gethelp-southernco-vethousing&quot;&gt;VOLUNTEERS OF AMERICA COLORADO&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides veterans and their families shelter and support to get back on their feet. A case manager works with the veteran and their family to develop individualized goals to address barriers toward stable housing...     &lt;/div&gt;`)[0];
#                 popup_3ee3ca67666fe65b343221a9ed0e0dfc.setContent(html_02b2398b21ffe9d06fdf0d2eb0fee1a3);
#
#
#
#         marker_13a9dd0c23f9f9b34896c9e5055d780b.bindPopup(popup_3ee3ca67666fe65b343221a9ed0e0dfc)
#         ;
#
#
#
#
#             var marker_0ca649935852e98bf8da3b594d646190 = L.marker(
#                 [39.4005647, -107.2112407],
#                 {}
#             ).addTo(map_ac4acea6dc10b304a540e0eeabd3db97);
#
#
#         var popup_edb112e2b2adc2908cc9c683be890e59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_505d7a3703ca4bf408f35b637d2fb7e0 = $(`&lt;div id=&quot;html_505d7a3703ca4bf408f35b637d2fb7e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;A WAY OUT&lt;/strong&gt;&lt;br&gt;     PO Box 1124&lt;br&gt;     Carbondale, CO 81623&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 340-4505&quot;&gt;(970) 340-4505&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://awayout.org&quot;&gt;A WAY OUT&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Offers services that helps those suffering from drug or alcohol addiction, including:Drug and alcohol addiction counseling Substance use disorder/mental health assessmentsTransitional housing for AWO qualifying clientsReferrals to treatment centers, sober living facilities and detoxFinancial assistance for in-patient treatment centers and sober living facilit

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for housing assistance in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_denver_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c4ef3dc68d9b25ffa2c5db67ec9f644 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c4ef3dc68d9b25ffa2c5db67ec9f644&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c4ef3dc68d9b25ffa2c5db67ec9f644 = L.map(
#                 &quot;map_2c4ef3dc68d9b25ffa2c5db67ec9f644&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d90f7f7985776d38cd2b4a8cb5cc93d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d90f7f7985776d38cd2b4a8cb5cc93d1.addTo(map_2c4ef3dc68d9b25ffa2c5db67ec9f644);
#
#
#             var marker_c8bedda09a6dc72581df2f1d2f216e9c = L.marker(
#                 [39.7753959, -104.9422916],
#                 {}
#             ).addTo(map_2c4ef3dc68d9b25ffa2c5db67ec9f644);
#
#
#         var popup_05a0161b2f75b46cff2d9b9251810f4d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f5c00b2f7cf3021bd598a01d0b17948 = $(`&lt;div id=&quot;html_5f5c00b2f7cf3021bd598a01d0b17948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES OF DENVER&lt;/strong&gt;&lt;br&gt;     6240 Smith Rd&lt;br&gt;     Denver, CO 80207&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(720) 799-9400&quot;&gt;(720) 799-9400&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://ccdenver.org/marisolservices/marisol-homes/&quot;&gt;CATHOLIC CHARITIES OF DENVER&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides housing and supportive services for pregnant women and women with children, for as long as needed in a communal living environment...     &lt;/div&gt;`)[0];
#                 popup_05a0161b2f75b46cff2d9b9251810f4d.setContent(html_5f5c00b2f7cf3021bd598a01d0b17948);
#
#
#
#         marker_c8bedda09a6dc72581df2f1d2f216e9c.bindPopup(popup_05a0161b2f75b46cff2d9b9251810f4d)
#         ;
#
#
#
#
#             var marker_1c7822be7965acd66828f236a4386900 = L.marker(
#                 [39.7556512, -104.9872002],
#                 {}
#             ).addTo(map_2c4ef3dc68d9b25ffa2c5db67ec9f644);
#
#
#         var popup_1abda8851feb8277004e09dc31c96aca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90fea7d11308b6e7215725ce5574ee57 = $(`&lt;div id=&quot;html_90fea7d11308b6e7215725ce5574ee57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES OF DENVER&lt;/strong&gt;&lt;br&gt;     2301 Lawrence St&lt;br&gt;     Denver, CO 80205&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(720) 799-9506 (Samaritan House at 48th)&quot;&gt;(720) 799-9506 (Samaritan House at 48th)&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;No Website Listed&quot;&gt;CATHOLIC CHARITIES OF DENVER&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides shelter for up to 6 months for single women in need of housing. Program is intended to prepare individuals for more intensive housing programs...     &lt;/div&gt;`)[0];
#                 popup_1abda8851feb8277004e09dc31c96aca.setContent(html_90fea7d11308b6e7215725ce5574ee57);
#
#
#
#         marker_1c7822be7965acd66828f236a4386900.bindPopup(popup_1abda8851feb8277004e09dc31c96aca)
#         ;
#
#
#
#
#             var marker_7399dbe857386b98c1bcb22b26ca196b = L.marker(
#                 [39.7293389, -104.9827188],
#                 {}
#             ).addTo(map_2c4ef3dc68d9b25ffa2c5db67ec9f644);
#
#
#         var popup_0999f0fdf087dbe260893d9407925230 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b416e5289f6fde992c32f13fa330b5b = $(`&lt;div id=&quot;html_7b416e5289f6fde992c32f13fa330b5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;PROVIDENCE NETWORK&lt;/strong&gt;&lt;br&gt;     801 Logan St&lt;br&gt;     Denver, CO 80203&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 860-8404&quot;&gt;(303) 860-8404&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://providencenetwork.org&quot;&gt;PROVIDENCE NETWORK&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides transitional housing and wrap-around services for young men who have been experiencing homelessness.     &lt;/div&gt;`)[0];
#                 popup_0999f0fdf087dbe260893d9407925230.setContent(html_7b416e5289f6fde992c32f13fa330b5b);
#
#
#
#         marker_7399dbe857386b98c1bcb22b26ca196b.bindPopup(popup_0999f0fdf087dbe260893d9407925230)
#         ;
#
#
#
#
#             va

# %%
# Example: Search for housing assistance in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_colorado_springs_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35cc7a549de0a04395cea5d6d68e8901 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35cc7a549de0a04395cea5d6d68e8901&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35cc7a549de0a04395cea5d6d68e8901 = L.map(
#                 &quot;map_35cc7a549de0a04395cea5d6d68e8901&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9af4c663399dd9cf54bea2598a2ed968 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9af4c663399dd9cf54bea2598a2ed968.addTo(map_35cc7a549de0a04395cea5d6d68e8901);
#
#
#             var marker_f4619dc1ad37b4eebb01d1fa16af1ecb = L.marker(
#                 [38.8255421, -104.7651236],
#                 {}
#             ).addTo(map_35cc7a549de0a04395cea5d6d68e8901);
#
#
#         var popup_e4e0e99c59fbe53f13e31afd5ad96a7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c57594e15560f9edf7f3b69671472c0 = $(`&lt;div id=&quot;html_0c57594e15560f9edf7f3b69671472c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;DREAM CENTERS&lt;/strong&gt;&lt;br&gt;     3650 Airport Rd&lt;br&gt;     Colorado Springs, CO 80910&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 301-5411&quot;&gt;(719) 301-5411&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://dreamcenters.com/marys-home/apply/&quot;&gt;DREAM CENTERS&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides transitional housing for homeless or imminently homeless adult women who are TANF, CCCAP and SNAP eligible, with three or less children eight years of age or younger...     &lt;/div&gt;`)[0];
#                 popup_e4e0e99c59fbe53f13e31afd5ad96a7a.setContent(html_0c57594e15560f9edf7f3b69671472c0);
#
#
#
#         marker_f4619dc1ad37b4eebb01d1fa16af1ecb.bindPopup(popup_e4e0e99c59fbe53f13e31afd5ad96a7a)
#         ;
#
#
#
#
#             var marker_0ea30d82c46fa1bc25fb6423defadd57 = L.marker(
#                 [38.8457952, -104.8316252],
#                 {}
#             ).addTo(map_35cc7a549de0a04395cea5d6d68e8901);
#
#
#         var popup_c727cd86bf7f57978c162ebf68135ca5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_112491fa437aea7bdb256eee578675ce = $(`&lt;div id=&quot;html_112491fa437aea7bdb256eee578675ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ITHAKA HOUSING&lt;/strong&gt;&lt;br&gt;     321 Mesa Rd&lt;br&gt;     Colorado Springs, CO 80905&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 578-1629&quot;&gt;(719) 578-1629&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://ithakaland.org&quot;&gt;ITHAKA HOUSING&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides transitional housing, in a group home setting, for individual men aged 25 and older who are willing and able to work full-time...     &lt;/div&gt;`)[0];
#                 popup_c727cd86bf7f57978c162ebf68135ca5.setContent(html_112491fa437aea7bdb256eee578675ce);
#
#
#
#         marker_0ea30d82c46fa1bc25fb6423defadd57.bindPopup(popup_c727cd86bf7f57978c162ebf68135ca5)
#         ;
#
#
#
#
#             var marker_709f7b3a19ea023214daae2f302dbd57 = L.marker(
#                 [38.8381918, -104.8303286],
#                 {}
#             ).addTo(map_35cc7a549de0a04395cea5d6d68e8901);
#
#
#         var popup_00ac586916427053c0247adbea316a74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d0323283e0f738447a82e637c0ffd24 = $(`&lt;div id=&quot;html_9d0323283e0f738447a82e637c0ffd24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HASEYA ADVOCATE PROGRAM&lt;/strong&gt;&lt;br&gt;     I-25&lt;br&gt;     Colorado Springs, CO 80903&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 660-3939&quot;&gt;(719) 660-3939&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://haseya.org&quot;&gt;HASEYA ADVOCATE PROGRAM&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides transitional housing for Native American/American Indian individuals fleeing domestic violence and/or sexual assault.     &lt;/div&gt;`)[0];
#                 popup_00ac586916427053c0247adbea316a74.setContent(html_9d0323283e0f738447a82e637c0ffd24);
#
#
#
#         marker_709f7b3a19ea023214daae2f302dbd57.bindPopup(popup_00ac586916427053c0247adbea316a74)
#         ;
#
#
#
#
#             var marker_bae7017b0841ee6838c9f72fb1cfdc57 = L.marker(

# %%
# Example: Search for housing assistance in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_aurora_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df90f6983d41363b395a3f584a685705 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df90f6983d41363b395a3f584a685705&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df90f6983d41363b395a3f584a685705 = L.map(
#                 &quot;map_df90f6983d41363b395a3f584a685705&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81f5cf54fed6e2e2e609a36dad1005a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_81f5cf54fed6e2e2e609a36dad1005a2.addTo(map_df90f6983d41363b395a3f584a685705);
#
#
#             var marker_46e43f66fa72c5d2803d0512bfe22bc5 = L.marker(
#                 [39.7466731, -104.8316117],
#                 {}
#             ).addTo(map_df90f6983d41363b395a3f584a685705);
#
#
#         var popup_1869018d5887516376fed147ceb0d877 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08caa170f0f0c725ac8bb4421f2c1cc3 = $(`&lt;div id=&quot;html_08caa170f0f0c725ac8bb4421f2c1cc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/strong&gt;&lt;br&gt;     13387 E 19th Pl&lt;br&gt;     Aurora, CO 80011&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 341-9160&quot;&gt;(303) 341-9160&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://comitiscrisiscenter.org/aurora-day-resource-center&quot;&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides the following drop-in services: Breakfast and lunch Hygiene items Showers Laundry services Sleeping bags Mail and document retention Medication storage Dental and medical services Housing assistance Employment services Financial literacy Pet food Pet health services Computer lab HIV/Hepatitis C testing Acute behavioral health service...     &lt;/div&gt;`)[0];
#                 popup_1869018d5887516376fed147ceb0d877.setContent(html_08caa170f0f0c725ac8bb4421f2c1cc3);
#
#
#
#         marker_46e43f66fa72c5d2803d0512bfe22bc5.bindPopup(popup_1869018d5887516376fed147ceb0d877)
#         ;
#
#
#
#
#             var marker_7249cf9a78f64436a8ce903dcb7161bf = L.marker(
#                 [39.7492153, -104.8329055],
#                 {}
#             ).addTo(map_df90f6983d41363b395a3f584a685705);
#
#
#         var popup_a3b27c0e93cedae5ce2ddc801405c1e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44462e94ef27ef9fdcfb8390aba2f812 = $(`&lt;div id=&quot;html_44462e94ef27ef9fdcfb8390aba2f812&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/strong&gt;&lt;br&gt;     2178 Victor St&lt;br&gt;     Aurora, CO 80045&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 341-9160 (Family Lottery Line)&quot;&gt;(303) 341-9160 (Family Lottery Line)&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://comitiscrisiscenter.org/comitis-crisis-center&quot;&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Offers up to one week of emergency shelter for individuals with dependent children and their partners.     &lt;/div&gt;`)[0];
#                 popup_a3b27c0e93cedae5ce2ddc801405c1e6.setContent(html_44462e94ef27ef9fdcfb8390aba2f812);
#
#
#
#         marker_7249cf9a78f64436a8ce903dcb7161bf.bindPopup(popup_a3b27c0e93cedae5ce2ddc801405c1e6)
#         ;
#
#
#
#
#             var marker_e9c0b4c2893127cca177bca6ebc64daa = L.marker(
#                 [39.7492153, -104.8329055],
#                 {}
#             ).addTo(map_df90f6983d41363b395a3f584a685705);
#
#
#         var popup_d9a2bf65c2bbaa2bbd9ad0dcb4de2620 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac753ce4766840bdc54b044795001ac5 = $(`&lt;div id=&quot;html_ac753ce4766840bdc54b044795001ac5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/strong&gt;&lt;br&gt;     2178 Victor St&lt;br&gt;     Aurora, CO 80045&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 341-9160&quot;&gt;(303) 341-9160&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://comitiscrisiscenter.org/comitis-crisis-center&quot;&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides long-term stays of up to two years for veterans experiencing homelessness.     &lt;/div&gt;`)[0];
#                 popup_d9a2bf65c2bbaa2bbd9ad0dc

# %%
# Example: Search for housing assistance in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_fort_collins_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94dec53bcc9839686625420645ba5321 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94dec53bcc9839686625420645ba5321&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94dec53bcc9839686625420645ba5321 = L.map(
#                 &quot;map_94dec53bcc9839686625420645ba5321&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1d5a5b0fec59fa2c5adf98a05ee1eef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b1d5a5b0fec59fa2c5adf98a05ee1eef.addTo(map_94dec53bcc9839686625420645ba5321);
#
#
#             var marker_b7616745150f58db4d003b21d8a7ffba = L.marker(
#                 [40.5665586, -105.0569249],
#                 {}
#             ).addTo(map_94dec53bcc9839686625420645ba5321);
#
#
#         var popup_3268a0a3a1aabff410be2a21b2030153 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb2f273cc558110df5550733eb7c3118 = $(`&lt;div id=&quot;html_fb2f273cc558110df5550733eb7c3118&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FAMILY HOUSING NETWORK&lt;/strong&gt;&lt;br&gt;     1606 S Lemay Ave Suite 103&lt;br&gt;     Fort Collins, CO 80525&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 484-3342&quot;&gt;(970) 484-3342&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://familyhousingnetwork.org/our-programs&quot;&gt;FAMILY HOUSING NETWORK&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a temporary overnight shelter for families for up to 3-4 months. Shelter locations rotate weekly among various faith communities in Fort Collins...     &lt;/div&gt;`)[0];
#                 popup_3268a0a3a1aabff410be2a21b2030153.setContent(html_fb2f273cc558110df5550733eb7c3118);
#
#
#
#         marker_b7616745150f58db4d003b21d8a7ffba.bindPopup(popup_3268a0a3a1aabff410be2a21b2030153)
#         ;
#
#
#
#
#             var marker_8957c2cb07b78fe540cabb8055ba6f69 = L.marker(
#                 [40.5947368, -105.0692106],
#                 {}
#             ).addTo(map_94dec53bcc9839686625420645ba5321);
#
#
#         var popup_582ffe8eeb4587960331eccfe71f6420 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_670e497d480cf0b7cc30278dc7399fa6 = $(`&lt;div id=&quot;html_670e497d480cf0b7cc30278dc7399fa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     460 Linden Center Dr&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 493-0141 (Shelter)&quot;&gt;(970) 493-0141 (Shelter)&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://ccdenver.org/larimer/&quot;&gt;CATHOLIC CHARITIES LARIMER COUNTY&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides nightly, year-round overnight shelter for families with children and single adult females.     &lt;/div&gt;`)[0];
#                 popup_582ffe8eeb4587960331eccfe71f6420.setContent(html_670e497d480cf0b7cc30278dc7399fa6);
#
#
#
#         marker_8957c2cb07b78fe540cabb8055ba6f69.bindPopup(popup_582ffe8eeb4587960331eccfe71f6420)
#         ;
#
#
#
#
#             var marker_bd0d797a0e43fe7340af83921bf7dd05 = L.marker(
#                 [40.5947368, -105.0692106],
#                 {}
#             ).addTo(map_94dec53bcc9839686625420645ba5321);
#
#
#         var popup_c9561bbe6dc63aecd1cb80cd3ee6b102 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8be3516905c04d60eb6befb71436351c = $(`&lt;div id=&quot;html_8be3516905c04d60eb6befb71436351c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     460 Linden Center Dr&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 493-0141&quot;&gt;(970) 493-0141&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://ccdenver.org/larimer&quot;&gt;CATHOLIC CHARITIES LARIMER COUNTY&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a year-round, extended stay shelter program. Lengths of stay vary based on client needs and progress toward goals with a case manager (establishing income, building savings, and locating permanent housing), but are generally 4 - 6 months long. Additional...     &lt;/div&gt;`)[0];
#                 popup_c9561bbe6dc63aecd1cb80cd3ee6b102.setContent(html_8be3516905c04d60eb6befb71436351c);

# %%
# Example: Search for housing assistance in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_lakewood_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2fae17725d123657908402f2b2f790c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2fae17725d123657908402f2b2f790c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2fae17725d123657908402f2b2f790c = L.map(
#                 &quot;map_d2fae17725d123657908402f2b2f790c&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f069fde122d8293b31a301cbe95578a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f069fde122d8293b31a301cbe95578a9.addTo(map_d2fae17725d123657908402f2b2f790c);
#
#
#             tile_layer_f069fde122d8293b31a301cbe95578a9.addTo(map_d2fae17725d123657908402f2b2f790c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for housing assistance in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_arvada_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f294fc906922cb964df7e1993ca8c5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f294fc906922cb964df7e1993ca8c5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f294fc906922cb964df7e1993ca8c5f = L.map(
#                 &quot;map_9f294fc906922cb964df7e1993ca8c5f&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08bf0b540e7709824d2e716d48981d22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_08bf0b540e7709824d2e716d48981d22.addTo(map_9f294fc906922cb964df7e1993ca8c5f);
#
#
#             var marker_b0a45d6ccd4d72c276b1a7947748d4dd = L.marker(
#                 [39.8140575, -105.0557237],
#                 {}
#             ).addTo(map_9f294fc906922cb964df7e1993ca8c5f);
#
#
#         var popup_24ee010c95bd921bd8d2abf27f6bfb66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74d05fc713e2d7f39e528771e5962061 = $(`&lt;div id=&quot;html_74d05fc713e2d7f39e528771e5962061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HOPE HOUSE COLORADO&lt;/strong&gt;&lt;br&gt;     6475 Benton St Bldg A&lt;br&gt;     Arvada, CO 80003&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 429-1012 Ext 238&quot;&gt;(303) 429-1012 Ext 238&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://hopehouseofcolorado.org&quot;&gt;HOPE HOUSE COLORADO&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a safe, structured home for a parenting teen mom while working through a program designed to help earn a GED or educational certificate and move on to further education...     &lt;/div&gt;`)[0];
#                 popup_24ee010c95bd921bd8d2abf27f6bfb66.setContent(html_74d05fc713e2d7f39e528771e5962061);
#
#
#
#         marker_b0a45d6ccd4d72c276b1a7947748d4dd.bindPopup(popup_24ee010c95bd921bd8d2abf27f6bfb66)
#         ;
#
#
#
#
#             tile_layer_08bf0b540e7709824d2e716d48981d22.addTo(map_9f294fc906922cb964df7e1993ca8c5f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for housing assistance in a specific city
city_search = "Greeley"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_greeley_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a79ae5e3912dad935825b6e896a6c722 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a79ae5e3912dad935825b6e896a6c722&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a79ae5e3912dad935825b6e896a6c722 = L.map(
#                 &quot;map_a79ae5e3912dad935825b6e896a6c722&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed5d90a222aa9c80f6b2ab1c31dd70a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ed5d90a222aa9c80f6b2ab1c31dd70a2.addTo(map_a79ae5e3912dad935825b6e896a6c722);
#
#
#             var marker_a3f6aead2ee2db446d44067f98bba5c7 = L.marker(
#                 [40.4225069, -104.6982977],
#                 {}
#             ).addTo(map_a79ae5e3912dad935825b6e896a6c722);
#
#
#         var popup_44e6771b9ad58105945807c62b9f8012 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79ff95fd14cf0f3facaaa19ad7122efa = $(`&lt;div id=&quot;html_79ff95fd14cf0f3facaaa19ad7122efa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GREELEY FAMILY HOUSE&lt;/strong&gt;&lt;br&gt;     1206 10th St&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 352-3215&quot;&gt;(970) 352-3215&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://greeleyfamilyhouse.org&quot;&gt;GREELEY FAMILY HOUSE&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides an emergency shelter program (up to 60 days) for families. While living at the shelter, families are required to look for employment and housing, and meet with a case manager on a weekly basis to develop a self-suhciency plan...     &lt;/div&gt;`)[0];
#                 popup_44e6771b9ad58105945807c62b9f8012.setContent(html_79ff95fd14cf0f3facaaa19ad7122efa);
#
#
#
#         marker_a3f6aead2ee2db446d44067f98bba5c7.bindPopup(popup_44e6771b9ad58105945807c62b9f8012)
#         ;
#
#
#
#
#             var marker_cb692e191003432cf997900b49e51c3f = L.marker(
#                 [40.4501919, -104.6965757],
#                 {}
#             ).addTo(map_a79ae5e3912dad935825b6e896a6c722);
#
#
#         var popup_e8760f759467165563c5202227356251 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_051aabffb7c65d2bdd5bd3cd7b75f5b0 = $(`&lt;div id=&quot;html_051aabffb7c65d2bdd5bd3cd7b75f5b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES WELD COUNTY&lt;/strong&gt;&lt;br&gt;     1442 N 11th Ave&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 353-6433&quot;&gt;(970) 353-6433&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://ccdenver.org&quot;&gt;CATHOLIC CHARITIES WELD COUNTY&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Offers services for older adults to help keep them safe and independent in their own homes. Services include: Case management Advocacy Benefit forms assistance Home visits Information and referrals Group and educational materials Translation/interpretation services Commodities and emergency food boxes Health and safety assessment...     &lt;/div&gt;`)[0];
#                 popup_e8760f759467165563c5202227356251.setContent(html_051aabffb7c65d2bdd5bd3cd7b75f5b0);
#
#
#
#         marker_cb692e191003432cf997900b49e51c3f.bindPopup(popup_e8760f759467165563c5202227356251)
#         ;
#
#
#
#
#             var marker_f5733ad4c55f9c4db651241a26f5be4f = L.marker(
#                 [40.4501919, -104.6965757],
#                 {}
#             ).addTo(map_a79ae5e3912dad935825b6e896a6c722);
#
#
#         var popup_0d55037f471d2ba7133d6d2f12643b49 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7330e611e5f226ac52092e430442d695 = $(`&lt;div id=&quot;html_7330e611e5f226ac52092e430442d695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES WELD COUNTY&lt;/strong&gt;&lt;br&gt;     1442 N 11th Ave&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 353-6433&quot;&gt;(970) 353-6433&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://ccdenver.org&quot;&gt;CATHOLIC CHARITIES WELD COUNTY&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a 150 day transitional shelter and program for adults and families, with the goal of obtaining stable income and housing. Residents are provided with: Specialized case managementAssist

# %%
# Example: Search for housing assistance in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_pueblo_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d34ef9b39d86147a2bad326937c345c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d34ef9b39d86147a2bad326937c345c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d34ef9b39d86147a2bad326937c345c = L.map(
#                 &quot;map_1d34ef9b39d86147a2bad326937c345c&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8561fb427825a8478094479265d1745d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8561fb427825a8478094479265d1745d.addTo(map_1d34ef9b39d86147a2bad326937c345c);
#
#
#             var marker_2b330f664e2460ed1c14673febd2c5f1 = L.marker(
#                 [38.258448, -104.638301],
#                 {}
#             ).addTo(map_1d34ef9b39d86147a2bad326937c345c);
#
#
#         var popup_4d7096a27c30bc0c366ddcd258e42158 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1afa6229394ff27038ca62a51292fde5 = $(`&lt;div id=&quot;html_1afa6229394ff27038ca62a51292fde5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;POSADA OF PUEBLO&lt;/strong&gt;&lt;br&gt;     501 Belmont Ave&lt;br&gt;     Pueblo, CO 81004&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 545-8776&quot;&gt;(719) 545-8776&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://www.posadapueblo.org&quot;&gt;POSADA OF PUEBLO&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provide transitionl housing, basic needs support, case management. Provide Housing counseling, life skills, education and employment assistance, legal services, mental health and substance abuse counseling...     &lt;/div&gt;`)[0];
#                 popup_4d7096a27c30bc0c366ddcd258e42158.setContent(html_1afa6229394ff27038ca62a51292fde5);
#
#
#
#         marker_2b330f664e2460ed1c14673febd2c5f1.bindPopup(popup_4d7096a27c30bc0c366ddcd258e42158)
#         ;
#
#
#
#
#             var marker_779e76df93f1ff0060bd6157c67d351c = L.marker(
#                 [38.258448, -104.638301],
#                 {}
#             ).addTo(map_1d34ef9b39d86147a2bad326937c345c);
#
#
#         var popup_cb026c4516e8267d07d16452d1319e1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30b950bd0edd2b707bc41124418304d3 = $(`&lt;div id=&quot;html_30b950bd0edd2b707bc41124418304d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;POSADA OF PUEBLO&lt;/strong&gt;&lt;br&gt;     501 Belmont Ave&lt;br&gt;     Pueblo, CO 81004&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 545-8776&quot;&gt;(719) 545-8776&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://www.posadapueblo.org&quot;&gt;POSADA OF PUEBLO&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provide referrals to homeless families with children for shelter, basic needs. Review options for low-income housing, identify community resources and programs to obtain self-sufficiency...     &lt;/div&gt;`)[0];
#                 popup_cb026c4516e8267d07d16452d1319e1a.setContent(html_30b950bd0edd2b707bc41124418304d3);
#
#
#
#         marker_779e76df93f1ff0060bd6157c67d351c.bindPopup(popup_cb026c4516e8267d07d16452d1319e1a)
#         ;
#
#
#
#
#             tile_layer_8561fb427825a8478094479265d1745d.addTo(map_1d34ef9b39d86147a2bad326937c345c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for housing assistance in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_boulder_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18b9588e0566b92697b02041d2edb95e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18b9588e0566b92697b02041d2edb95e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18b9588e0566b92697b02041d2edb95e = L.map(
#                 &quot;map_18b9588e0566b92697b02041d2edb95e&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a190a24a7e7df76bb6feb45d484c729b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a190a24a7e7df76bb6feb45d484c729b.addTo(map_18b9588e0566b92697b02041d2edb95e);
#
#
#             var marker_3ecde2b442d7e4e82b18dbb31d704b1b = L.marker(
#                 [40.0625882, -105.282615],
#                 {}
#             ).addTo(map_18b9588e0566b92697b02041d2edb95e);
#
#
#         var popup_9ee554218999815d526c0b53afc41af9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d8406f7f4e6b620c49d2c043d907aba = $(`&lt;div id=&quot;html_1d8406f7f4e6b620c49d2c043d907aba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ALL ROADS SHELTER&lt;/strong&gt;&lt;br&gt;     4869 Broadway&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 579-4404 (Boulder)&quot;&gt;(303) 579-4404 (Boulder)&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://allroadsboco.org/housing-focused-shelter/&quot;&gt;ALL ROADS SHELTER&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Offers a overnight shelter and services for adults experiencing homelessness. Also provides long-term shelter to homeless adults with moderate and high needs in Boulder County to give them a predictable place to stay while they work toward exiting homelessness...     &lt;/div&gt;`)[0];
#                 popup_9ee554218999815d526c0b53afc41af9.setContent(html_1d8406f7f4e6b620c49d2c043d907aba);
#
#
#
#         marker_3ecde2b442d7e4e82b18dbb31d704b1b.bindPopup(popup_9ee554218999815d526c0b53afc41af9)
#         ;
#
#
#
#
#             var marker_a3d9cd3d1fff140c44321bca17293cc4 = L.marker(
#                 [40.0306466, -105.2817333],
#                 {}
#             ).addTo(map_18b9588e0566b92697b02041d2edb95e);
#
#
#         var popup_aa541aab075d471d9d5767f4fec856f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4bb895768e8761444795ebb44d0723e8 = $(`&lt;div id=&quot;html_4bb895768e8761444795ebb44d0723e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;TGTHR&lt;/strong&gt;&lt;br&gt;     3080 Broadway&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 447-1207&quot;&gt;(303) 447-1207&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://tgthr.org/&quot;&gt;TGTHR&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides street outreach and an overnight emergency shelter services for teens. The overnight shelter services include: Food Clothing Showers A place to be overnight For the overnight shelter, youth must participate in case management...     &lt;/div&gt;`)[0];
#                 popup_aa541aab075d471d9d5767f4fec856f8.setContent(html_4bb895768e8761444795ebb44d0723e8);
#
#
#
#         marker_a3d9cd3d1fff140c44321bca17293cc4.bindPopup(popup_aa541aab075d471d9d5767f4fec856f8)
#         ;
#
#
#
#
#             var marker_73621d26333ccc0a7aa5d0cc033e634c = L.marker(
#                 [40.058333, -105.2778705],
#                 {}
#             ).addTo(map_18b9588e0566b92697b02041d2edb95e);
#
#
#         var popup_af650963eb31093fc4ec96ce015b1517 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4aaf45f3df9c7f86931d4c182b508675 = $(`&lt;div id=&quot;html_4aaf45f3df9c7f86931d4c182b508675&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;EMERGENCY FAMILY ASSISTANCE ASSOCIATION&lt;/strong&gt;&lt;br&gt;     1575 Yarmouth Ave&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 442-3042&quot;&gt;(303) 442-3042&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://efaa.org/&quot;&gt;EMERGENCY FAMILY ASSISTANCE ASSOCIATION&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides direct financial assistance to qualifying households in the City of Boulder and Boulder County mountain communities in the form of direct payment to vendors...     &lt;/div&gt;`)[0];
#                 popup_af650963eb31093fc4ec96ce015b1517.setContent(html_4aaf45f

# %%
# Example: Search for housing assistance in a specific city
city_search = "Grand Junction"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_grand_junction_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfa6d7fefbc1e18820a37c821e20ddb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfa6d7fefbc1e18820a37c821e20ddb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfa6d7fefbc1e18820a37c821e20ddb1 = L.map(
#                 &quot;map_cfa6d7fefbc1e18820a37c821e20ddb1&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b92c85c808d83f5292b1706c08e88939 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b92c85c808d83f5292b1706c08e88939.addTo(map_cfa6d7fefbc1e18820a37c821e20ddb1);
#
#
#             var marker_97d21891ead6a3c31f530980a4b94880 = L.marker(
#                 [39.0655869, -108.5712505],
#                 {}
#             ).addTo(map_cfa6d7fefbc1e18820a37c821e20ddb1);
#
#
#         var popup_54869a6f574c5b45389a8fe32b517926 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44afd7b77d2cd8d0e15de1db7e872a29 = $(`&lt;div id=&quot;html_44afd7b77d2cd8d0e15de1db7e872a29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/strong&gt;&lt;br&gt;     245 S 1st St&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 241-3658&quot;&gt;(970) 241-3658&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://catholicoutreach.org&quot;&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides individuals with the opportunity to end homelessness through cooperative living, case management, and training.     &lt;/div&gt;`)[0];
#                 popup_54869a6f574c5b45389a8fe32b517926.setContent(html_44afd7b77d2cd8d0e15de1db7e872a29);
#
#
#
#         marker_97d21891ead6a3c31f530980a4b94880.bindPopup(popup_54869a6f574c5b45389a8fe32b517926)
#         ;
#
#
#
#
#             var marker_62e1a2462adcbd935c4716e6dc0ed62c = L.marker(
#                 [39.0655869, -108.5712505],
#                 {}
#             ).addTo(map_cfa6d7fefbc1e18820a37c821e20ddb1);
#
#
#         var popup_9d5c0b27abbd1bb555aa838d7b6cae52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dce1d1ad10a8938715fe49a194e4b38e = $(`&lt;div id=&quot;html_dce1d1ad10a8938715fe49a194e4b38e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/strong&gt;&lt;br&gt;     245 S 1st St&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 241-3658&quot;&gt;(970) 241-3658&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://catholicoutreach.org&quot;&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides homes to those with mental or physical impairments who have been chronically homeless and are free from drug abuse.     &lt;/div&gt;`)[0];
#                 popup_9d5c0b27abbd1bb555aa838d7b6cae52.setContent(html_dce1d1ad10a8938715fe49a194e4b38e);
#
#
#
#         marker_62e1a2462adcbd935c4716e6dc0ed62c.bindPopup(popup_9d5c0b27abbd1bb555aa838d7b6cae52)
#         ;
#
#
#
#
#             var marker_969f690402a7dec27c06792a736d7914 = L.marker(
#                 [39.0646476, -108.5676123],
#                 {}
#             ).addTo(map_cfa6d7fefbc1e18820a37c821e20ddb1);
#
#
#         var popup_d36aa45fc469be1474d962ac9af65a0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cbe6a156f257666b686818276515c4f4 = $(`&lt;div id=&quot;html_cbe6a156f257666b686818276515c4f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/strong&gt;&lt;br&gt;     302 Pitkin Ave&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 263-9445&quot;&gt;(970) 263-9445&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://catholicoutreach.org&quot;&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a day center for individuals experiencing homelessness. Addition services and amenities include: Shower and laundry services Telephone services P...     &lt;/div&gt;`)[0];
#                 popup_d36aa45fc469be1474d962ac9af65a0b.setContent(html_cbe6a156f257666b686818276515c4f4);
#
#
#
#         marker_969f690402a7dec27c06792a736d7914.bindPopup(popup_d36aa45fc469be1474d962ac9af65a0b)
#         ;
#
#
#
#
#             var marker_2e0fd49a

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_housing_assistance_v3.csv", index=False)

# Confirm the export
print("Data exported to cleaned_colorado_housing_assistance_v3.csv")
# Out:
# Data exported to cleaned_colorado_housing_assistance_v3.csv
