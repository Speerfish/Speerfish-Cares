# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create multiple city specific map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_housing_assistance.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#                                            Assistance  \
# 0                         Temporary Overnight Shelter
# 1        Veteran Housing Transitional Housing Program
# 2                            Substance Abuse Services
# 3                           Homeless Motel Assistance
# 4   Housing for Pregnant Women and Women with Chil...
# 5               Transitional Shelter for Single Women
# 6                                Transitional Housing
# 7        Overflow Shelter for Single Women & Families
# 8                                Shelter for Families
# 9              Transitional Housing for Single Adults
# 10                                     Drop-In Center
# 11                               Transitional Housing
# 12                 Transitional Housing for Young Men
# 13                    Transitional Supportive Housing
# 14                       Permanent Supportive Housing
#
#                                Agency                     Address  \
# 0              FAMILY HOUSING NETWORK  1606 S Lemay Ave Suite 103
# 1      VOLUNTEERS OF AMERICA COLORADO        1055 Avenida Del Sol
# 2                           A WAY OUT                 PO Box 1124
# 3             CARING & SHARING SALIDA                220 W 4th St
# 4        CATHOLIC CHARITIES OF DENVER               6240 Smith Rd
# 5        CATHOLIC CHARITIES OF DENVER            2301 Lawrence St
# 6                       DREAM CENTERS             3650 Airport Rd
# 7   CATHOLIC CHARITIES LARIMER COUNTY        460 Linden Center Dr
# 8                HOPE @ MIRACLE HOUSE                 Main Street
# 9                      ITHAKA HOUSING                 321 Mesa Rd
# 10    MILE HIGH BEHAVIORAL HEALTHCARE             13387 E 19th Pl
# 11            HASEYA ADVOCATE PROGRAM                        I-25
# 12                 PROVIDENCE NETWORK                801 Logan St
# 13     GRAND VALLEY CATHOLIC OUTREACH                245 S 1st St
# 14     GRAND VALLEY CATHOLIC OUTREACH                245 S 1st St
#
#                 City State    Zip           County  \
# 0       Fort Collins    CO  80525   LARIMER COUNTY
# 1            Durango    CO  81301  LA PLATA COUNTY
# 2         Carbondale    CO  81623    PITKIN COUNTY
# 3             Salida    CO  81201   CHAFFEE COUNTY
# 4             Denver    CO  80207    DENVER COUNTY
# 5             Denver    CO  80205    DENVER COUNTY
# 6   Colorado Springs    CO  80910   EL PASO COUNTY
# 7       Fort Collins    CO  80524   LARIMER COUNTY
# 8        Fort Lupton    CO  80621      WELD COUNTY
# 9   Colorado Springs    CO  80905   EL PASO COUNTY
# 10            Aurora    CO  80011     ADAMS COUNTY
# 11  Colorado Springs    CO  80903   EL PASO COUNTY
# 12            Denver    CO  80203    DENVER COUNTY
# 13    Grand Junction    CO  81501      MESA COUNTY
# 14    Grand Junction    CO  81501      MESA COUNTY
#
#                                              Services  \
# 0   Provides a temporary overnight shelter for fam...
# 1   Provides veterans and their families shelter a...
# 2   Offers services that helps those suffering fro...
# 3   Provide short-term emergency housing on a case...
# 4   Provides housing and supportive services for p...
# 5   Provides shelter for up to 6 months for single...
# 6   Provides transitional housing for homeless or ...
# 7   Provides nightly, year-round overnight shelter...
# 8   Seeks to address the needs of homeless familie...
# 9   Provides transitional housing, in a group home...
# 10  Provides the following drop-in services: Break...
# 11  Provides transitional housing for Native Ameri...
# 12  Provides transitional housing and wrap-around ...
# 13  Provides individuals with the opportunity to e...
# 14  Provides homes to those with mental or physica...
#
#                                           Eligibility  \
# 0   Eligibility: Eligible adults must:Have at leas...
# 1   Eligibility: Veterans aged 18 and older who ar...
# 2   Eligibility: Individuals must be a resident of...
# 3   Eligibility: Individuals and families experien...
# 4   Eligibility: Pregnant women and female-identif...
# 5   Eligibility: Single women aged 18 and older Ar...
# 6   Eligibility: Homeless or imminently homeless w...
# 7   Eligibility: Female gender served only. There ...
# 8   Eligibility: Families experiencing homelessnes...
# 9   Eligibility: Individuals must: Be single men (...
# 10  Eligibility: No restrictions applied Area Serv...
# 11  Eligibility: Available to Native American surv...
# 12  Eligibility: Young men aged 18 - 25 years and ...
# 13  Eligibility: Individuals experiencing homeless...
# 14  Eligibility: Individuals and families living w...
#
#                                                 Hours  \
# 0   Monday - Friday, 9 a.m. - 5 p.m. (Administrati...
# 1   Monday - Friday, 8 a.m. - 5 p.m. (Administrati...
# 2                    Monday - Friday, 9 a.m. - 5 p.m.
# 3           Monday - Saturday, 10:30 a.m. - 1:30 p.m.
# 4   Monday - Thursday, 8 a.m. - 5 p.m.; Friday, 8:...
# 5   Monday - Friday, 8:30 a.m. - 5 p.m. (Administr...
# 6                              24 hours/7 days a week
# 7   Monday - Friday, 8:30 a.m. - 12 p.m., 1 p.m. -...
# 8                                          Hours Vary
# 9                  Monday - Thursday, 8 a.m. - 5 p.m.
# 10  Monday - Friday, 7:30 a.m. - 4:30 p.m. (Drop-I...
# 11  Monday, Wednesday, Thursday 9:00 a.m. - 3:00 p...
# 12  Monday - Friday, 8 a.m. - 5 p.m. (Administrati...
# 13               Monday - Friday, 9 a.m. - 11:30 a.m.
# 14               Monday - Friday, 9 a.m. - 11:30 a.m.
#
#                                        Phone  \
# 0                             (970) 484-3342
# 1                             (970) 259-1255
# 2                             (970) 340-4505
# 3                             (719) 539-4849
# 4                             (720) 799-9400
# 5   (720) 799-9506 (Samaritan House at 48th)
# 6                             (719) 301-5411
# 7                   (970) 493-0141 (Shelter)
# 8              (720) 676-9697 (Message Line)
# 9                             (719) 578-1629
# 10                            (303) 341-9160
# 11                            (719) 660-3939
# 12                            (303) 860-8404
# 13                            (970) 241-3658
# 14                            (970) 241-3658
#
#                                               Website   Latitude   Longitude
# 0        http://familyhousingnetwork.org/our-programs  40.566559 -105.056925
# 1   http://voacolorado.org/gethelp-southernco-veth...  37.276682 -107.884155
# 2                                  http://awayout.org  39.400565 -107.211241
# 3                      http://salidacaringsharing.org  38.534785 -105.996096
# 4   http://ccdenver.org/marisolservices/marisol-ho...  39.775396 -104.942292
# 5                                   No Website Listed  39.755651 -104.987200
# 6           http://dreamcenters.com/marys-home/apply/  38.825542 -104.765124
# 7                        http://ccdenver.org/larimer/  40.594737 -105.069211
# 8                       http://hopeatmiraclehouse.org  40.079786 -104.809698
# 9                               http://ithakaland.org  38.845795 -104.831625
# 10  http://comitiscrisiscenter.org/aurora-day-reso...  39.746673 -104.831612
# 11                                  http://haseya.org  38.838192 -104.830329
# 12                       http://providencenetwork.org  39.729339 -104.982719
# 13                        http://catholicoutreach.org  39.065587 -108.571251
# 14                        http://catholicoutreach.org  39.065587 -108.571251

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Assistance   114 non-null    object
#  1   Agency       114 non-null    object
#  2   Address      114 non-null    object
#  3   City         114 non-null    object
#  4   State        114 non-null    object
#  5   Zip          114 non-null    int64
#  6   County       114 non-null    object
#  7   Services     114 non-null    object
#  8   Eligibility  114 non-null    object
#  9   Hours        114 non-null    object
#  10  Phone        114 non-null    object
#  11  Website      114 non-null    object
#  12  Latitude     114 non-null    float64
#  13  Longitude    114 non-null    float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 12.6+ KB
#                                            Assistance  \
# 0                         Temporary Overnight Shelter
# 1        Veteran Housing Transitional Housing Program
# 2                            Substance Abuse Services
# 3                           Homeless Motel Assistance
# 4   Housing for Pregnant Women and Women with Chil...
# 5               Transitional Shelter for Single Women
# 6                                Transitional Housing
# 7        Overflow Shelter for Single Women & Families
# 8                                Shelter for Families
# 9              Transitional Housing for Single Adults
# 10                                     Drop-In Center
# 11                               Transitional Housing
# 12                 Transitional Housing for Young Men
# 13                    Transitional Supportive Housing
# 14                       Permanent Supportive Housing
#
#                                Agency                     Address  \
# 0              FAMILY HOUSING NETWORK  1606 S Lemay Ave Suite 103
# 1      VOLUNTEERS OF AMERICA COLORADO        1055 Avenida Del Sol
# 2                           A WAY OUT                 PO Box 1124
# 3             CARING & SHARING SALIDA                220 W 4th St
# 4        CATHOLIC CHARITIES OF DENVER               6240 Smith Rd
# 5        CATHOLIC CHARITIES OF DENVER            2301 Lawrence St
# 6                       DREAM CENTERS             3650 Airport Rd
# 7   CATHOLIC CHARITIES LARIMER COUNTY        460 Linden Center Dr
# 8                HOPE @ MIRACLE HOUSE                 Main Street
# 9                      ITHAKA HOUSING                 321 Mesa Rd
# 10    MILE HIGH BEHAVIORAL HEALTHCARE             13387 E 19th Pl
# 11            HASEYA ADVOCATE PROGRAM                        I-25
# 12                 PROVIDENCE NETWORK                801 Logan St
# 13     GRAND VALLEY CATHOLIC OUTREACH                245 S 1st St
# 14     GRAND VALLEY CATHOLIC OUTREACH                245 S 1st St
#
#                 City State    Zip           County  \
# 0       Fort Collins    CO  80525   LARIMER COUNTY
# 1            Durango    CO  81301  LA PLATA COUNTY
# 2         Carbondale    CO  81623    PITKIN COUNTY
# 3             Salida    CO  81201   CHAFFEE COUNTY
# 4             Denver    CO  80207    DENVER COUNTY
# 5             Denver    CO  80205    DENVER COUNTY
# 6   Colorado Springs    CO  80910   EL PASO COUNTY
# 7       Fort Collins    CO  80524   LARIMER COUNTY
# 8        Fort Lupton    CO  80621      WELD COUNTY
# 9   Colorado Springs    CO  80905   EL PASO COUNTY
# 10            Aurora    CO  80011     ADAMS COUNTY
# 11  Colorado Springs    CO  80903   EL PASO COUNTY
# 12            Denver    CO  80203    DENVER COUNTY
# 13    Grand Junction    CO  81501      MESA COUNTY
# 14    Grand Junction    CO  81501      MESA COUNTY
#
#                                              Services  \
# 0   Provides a temporary overnight shelter for fam...
# 1   Provides veterans and their families shelter a...
# 2   Offers services that helps those suffering fro...
# 3   Provide short-term emergency housing on a case...
# 4   Provides housing and supportive services for p...
# 5   Provides shelter for up to 6 months for single...
# 6   Provides transitional housing for homeless or ...
# 7   Provides nightly, year-round overnight shelter...
# 8   Seeks to address the needs of homeless familie...
# 9   Provides transitional housing, in a group home...
# 10  Provides the following drop-in services: Break...
# 11  Provides transitional housing for Native Ameri...
# 12  Provides transitional housing and wrap-around ...
# 13  Provides individuals with the opportunity to e...
# 14  Provides homes to those with mental or physica...
#
#                                           Eligibility  \
# 0   Eligibility: Eligible adults must:Have at leas...
# 1   Eligibility: Veterans aged 18 and older who ar...
# 2   Eligibility: Individuals must be a resident of...
# 3   Eligibility: Individuals and families experien...
# 4   Eligibility: Pregnant women and female-identif...
# 5   Eligibility: Single women aged 18 and older Ar...
# 6   Eligibility: Homeless or imminently homeless w...
# 7   Eligibility: Female gender served only. There ...
# 8   Eligibility: Families experiencing homelessnes...
# 9   Eligibility: Individuals must: Be single men (...
# 10  Eligibility: No restrictions applied Area Serv...
# 11  Eligibility: Available to Native American surv...
# 12  Eligibility: Young men aged 18 - 25 years and ...
# 13  Eligibility: Individuals experiencing homeless...
# 14  Eligibility: Individuals and families living w...
#
#                                                 Hours  \
# 0   Monday - Friday, 9 a.m. - 5 p.m. (Administrati...
# 1   Monday - Friday, 8 a.m. - 5 p.m. (Administrati...
# 2                    Monday - Friday, 9 a.m. - 5 p.m.
# 3           Monday - Saturday, 10:30 a.m. - 1:30 p.m.
# 4   Monday - Thursday, 8 a.m. - 5 p.m.; Friday, 8:...
# 5   Monday - Friday, 8:30 a.m. - 5 p.m. (Administr...
# 6                              24 hours/7 days a week
# 7   Monday - Friday, 8:30 a.m. - 12 p.m., 1 p.m. -...
# 8                                          Hours Vary
# 9                  Monday - Thursday, 8 a.m. - 5 p.m.
# 10  Monday - Friday, 7:30 a.m. - 4:30 p.m. (Drop-I...
# 11  Monday, Wednesday, Thursday 9:00 a.m. - 3:00 p...
# 12  Monday - Friday, 8 a.m. - 5 p.m. (Administrati...
# 13               Monday - Friday, 9 a.m. - 11:30 a.m.
# 14               Monday - Friday, 9 a.m. - 11:30 a.m.
#
#                                        Phone  \
# 0                             (970) 484-3342
# 1                             (970) 259-1255
# 2                             (970) 340-4505
# 3                             (719) 539-4849
# 4                             (720) 799-9400
# 5   (720) 799-9506 (Samaritan House at 48th)
# 6                             (719) 301-5411
# 7                   (970) 493-0141 (Shelter)
# 8              (720) 676-9697 (Message Line)
# 9                             (719) 578-1629
# 10                            (303) 341-9160
# 11                            (719) 660-3939
# 12                            (303) 860-8404
# 13                            (970) 241-3658
# 14                            (970) 241-3658
#
#                                               Website   Latitude   Longitude
# 0        http://familyhousingnetwork.org/our-programs  40.566559 -105.056925
# 1   http://voacolorado.org/gethelp-southernco-veth...  37.276682 -107.884155
# 2                                  http://awayout.org  39.400565 -107.211241
# 3                      http://salidacaringsharing.org  38.534785 -105.996096
# 4   http://ccdenver.org/marisolservices/marisol-ho...  39.775396 -104.942292
# 5                                   No Website Listed  39.755651 -104.987200
# 6           http://dreamcenters.com/marys-home/apply/  38.825542 -104.765124
# 7                        http://ccdenver.org/larimer/  40.594737 -105.069211
# 8                       http://hopeatmiraclehouse.org  40.079786 -104.809698
# 9                               http://ithakaland.org  38.845795 -104.831625
# 10  http://comitiscrisiscenter.org/aurora-day-reso...  39.746673 -104.831612
# 11                                  http://haseya.org  38.838192 -104.830329
# 12                       http://providencenetwork.org  39.729339 -104.982719
# 13                        http://catholicoutreach.org  39.065587 -108.571251
# 14                        http://catholicoutreach.org  39.065587 -108.571251

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each housing assistance location
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_housing_assistance_map_v2.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d34c0ee93cb5ac00660ab34bc256314 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d34c0ee93cb5ac00660ab34bc256314&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d34c0ee93cb5ac00660ab34bc256314 = L.map(
#                 &quot;map_6d34c0ee93cb5ac00660ab34bc256314&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0627b99bbc78b6f0fcd8be856538791b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0627b99bbc78b6f0fcd8be856538791b.addTo(map_6d34c0ee93cb5ac00660ab34bc256314);
#
#
#             var marker_4a8b8cbdd614d7d9403dfff77aa854b3 = L.marker(
#                 [40.5665586, -105.0569249],
#                 {}
#             ).addTo(map_6d34c0ee93cb5ac00660ab34bc256314);
#
#
#         var popup_fb366cdefabd83685e3653f4b20b6477 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a024dcfef9271d1da9f628d42b93705 = $(`&lt;div id=&quot;html_6a024dcfef9271d1da9f628d42b93705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FAMILY HOUSING NETWORK&lt;/strong&gt;&lt;br&gt;     1606 S Lemay Ave Suite 103&lt;br&gt;     Fort Collins, CO 80525&lt;br&gt;     Phone: (970) 484-3342&lt;br&gt;     Website: &lt;a href=&quot;http://familyhousingnetwork.org/our-programs&quot;&gt;FAMILY HOUSING NETWORK&lt;/a&gt;&lt;br&gt;     Services: Provides a temporary overnight shelter for families for up to 3-4 months. Shelter locations rotate weekly among various faith communities in Fort Collins...     &lt;/div&gt;`)[0];
#                 popup_fb366cdefabd83685e3653f4b20b6477.setContent(html_6a024dcfef9271d1da9f628d42b93705);
#
#
#
#         marker_4a8b8cbdd614d7d9403dfff77aa854b3.bindPopup(popup_fb366cdefabd83685e3653f4b20b6477)
#         ;
#
#
#
#
#             var marker_6d705a19465363408b2e2f49333084a8 = L.marker(
#                 [37.2766819, -107.8841553],
#                 {}
#             ).addTo(map_6d34c0ee93cb5ac00660ab34bc256314);
#
#
#         var popup_350e35dedcd9fdb92f54f6a82efaafde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ccbd1a278969bd8e13e13f43b50a46c = $(`&lt;div id=&quot;html_2ccbd1a278969bd8e13e13f43b50a46c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;VOLUNTEERS OF AMERICA COLORADO&lt;/strong&gt;&lt;br&gt;     1055 Avenida Del Sol&lt;br&gt;     Durango, CO 81301&lt;br&gt;     Phone: (970) 259-1255&lt;br&gt;     Website: &lt;a href=&quot;http://voacolorado.org/gethelp-southernco-vethousing&quot;&gt;VOLUNTEERS OF AMERICA COLORADO&lt;/a&gt;&lt;br&gt;     Services: Provides veterans and their families shelter and support to get back on their feet. A case manager works with the veteran and their family to develop individualized goals to address barriers toward stable housing...     &lt;/div&gt;`)[0];
#                 popup_350e35dedcd9fdb92f54f6a82efaafde.setContent(html_2ccbd1a278969bd8e13e13f43b50a46c);
#
#
#
#         marker_6d705a19465363408b2e2f49333084a8.bindPopup(popup_350e35dedcd9fdb92f54f6a82efaafde)
#         ;
#
#
#
#
#             var marker_c4d8c46b77654b4c8eccd0ff7fddde2f = L.marker(
#                 [39.4005647, -107.2112407],
#                 {}
#             ).addTo(map_6d34c0ee93cb5ac00660ab34bc256314);
#
#
#         var popup_6b7ed99242642803ce9b255e8b6b154f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eddd555378157596d6f7072567ee06bd = $(`&lt;div id=&quot;html_eddd555378157596d6f7072567ee06bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;A WAY OUT&lt;/strong&gt;&lt;br&gt;     PO Box 1124&lt;br&gt;     Carbondale, CO 81623&lt;br&gt;     Phone: (970) 340-4505&lt;br&gt;     Website: &lt;a href=&quot;http://awayout.org&quot;&gt;A WAY OUT&lt;/a&gt;&lt;br&gt;     Services: Offers services that helps those suffering from drug or alcohol addiction, including:Drug and alcohol addiction counseling Substance use disorder/mental health assessmentsTransitional housing for AWO qualifying clientsReferrals to treatment centers, sober living facilities and detoxFinancial assistance for in-patient treatment centers and sober living facilitiesA year of case-managed aftercar...     &lt;/div&gt;`)[0];
#                 popup_6b7ed99242642803ce9b255e8b6b154f.setContent(html_eddd555378157596d6f7072567ee06bd);
#
#
#
#         marker_c4d8c46b77654b4c8eccd0ff7fddde2f.bindPopup(popup_6b7ed99242642803ce9b255e8b6b154f)
#         ;
#
#
#
#
#             var marker_efab54e17904e38846777b882b571fdc = L.marker(
#                 [38.5347855, -105.996

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for housing assistance in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_531815b35bc6eb2a491d6467bb3779e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_531815b35bc6eb2a491d6467bb3779e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_531815b35bc6eb2a491d6467bb3779e4 = L.map(
#                 &quot;map_531815b35bc6eb2a491d6467bb3779e4&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70428d3850c71f4d980e4bd55068c522 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_70428d3850c71f4d980e4bd55068c522.addTo(map_531815b35bc6eb2a491d6467bb3779e4);
#
#
#             var marker_111f8447bef555a64b7f49d72bd5db54 = L.marker(
#                 [39.7753959, -104.9422916],
#                 {}
#             ).addTo(map_531815b35bc6eb2a491d6467bb3779e4);
#
#
#         var popup_7764d511e6643547847239b1a0119f54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46546d275246ba9dd8d7d0910248e055 = $(`&lt;div id=&quot;html_46546d275246ba9dd8d7d0910248e055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES OF DENVER&lt;/strong&gt;&lt;br&gt;     6240 Smith Rd&lt;br&gt;     Denver, CO 80207&lt;br&gt;     Phone: (720) 799-9400&lt;br&gt;     Website: &lt;a href=&quot;http://ccdenver.org/marisolservices/marisol-homes/&quot;&gt;CATHOLIC CHARITIES OF DENVER&lt;/a&gt;&lt;br&gt;     Services: Provides housing and supportive services for pregnant women and women with children, for as long as needed in a communal living environment...     &lt;/div&gt;`)[0];
#                 popup_7764d511e6643547847239b1a0119f54.setContent(html_46546d275246ba9dd8d7d0910248e055);
#
#
#
#         marker_111f8447bef555a64b7f49d72bd5db54.bindPopup(popup_7764d511e6643547847239b1a0119f54)
#         ;
#
#
#
#
#             var marker_9094f8452bb24285a9758bd5f7fc079b = L.marker(
#                 [39.7556512, -104.9872002],
#                 {}
#             ).addTo(map_531815b35bc6eb2a491d6467bb3779e4);
#
#
#         var popup_256b98ecbca0a7820c8e2d6038c44043 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ee38fe16375f5ed519eadaec5d4fa43 = $(`&lt;div id=&quot;html_2ee38fe16375f5ed519eadaec5d4fa43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES OF DENVER&lt;/strong&gt;&lt;br&gt;     2301 Lawrence St&lt;br&gt;     Denver, CO 80205&lt;br&gt;     Phone: (720) 799-9506 (Samaritan House at 48th)&lt;br&gt;     Website: &lt;a href=&quot;No Website Listed&quot;&gt;CATHOLIC CHARITIES OF DENVER&lt;/a&gt;&lt;br&gt;     Services: Provides shelter for up to 6 months for single women in need of housing. Program is intended to prepare individuals for more intensive housing programs...     &lt;/div&gt;`)[0];
#                 popup_256b98ecbca0a7820c8e2d6038c44043.setContent(html_2ee38fe16375f5ed519eadaec5d4fa43);
#
#
#
#         marker_9094f8452bb24285a9758bd5f7fc079b.bindPopup(popup_256b98ecbca0a7820c8e2d6038c44043)
#         ;
#
#
#
#
#             var marker_91693711c6c8b1a9340ccc0d6bbce42a = L.marker(
#                 [39.7293389, -104.9827188],
#                 {}
#             ).addTo(map_531815b35bc6eb2a491d6467bb3779e4);
#
#
#         var popup_2f32d591bff3026f629e21862e021d17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99fddbff4d924aee290b8208fff76329 = $(`&lt;div id=&quot;html_99fddbff4d924aee290b8208fff76329&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;PROVIDENCE NETWORK&lt;/strong&gt;&lt;br&gt;     801 Logan St&lt;br&gt;     Denver, CO 80203&lt;br&gt;     Phone: (303) 860-8404&lt;br&gt;     Website: &lt;a href=&quot;http://providencenetwork.org&quot;&gt;PROVIDENCE NETWORK&lt;/a&gt;&lt;br&gt;     Services: Provides transitional housing and wrap-around services for young men who have been experiencing homelessness.     &lt;/div&gt;`)[0];
#                 popup_2f32d591bff3026f629e21862e021d17.setContent(html_99fddbff4d924aee290b8208fff76329);
#
#
#
#         marker_91693711c6c8b1a9340ccc0d6bbce42a.bindPopup(popup_2f32d591bff3026f629e21862e021d17)
#         ;
#
#
#
#
#             var marker_756c566caba1f59bde7e049d8410d831 = L.marker(
#                 [39.661077, -104.847177],
#                 {}
#             ).addTo(map_531815b35bc6eb2a491d6467bb3779e4);
#
#
#         var popup_ed353bc162ea34a9c41b3337abd16aaf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6d43e388c35c065ace890f4f2ffe086 = $(`&lt;div id=&quot;html_f6d43e388c35c065ace890f4f2ffe086&quot; style=&quo

# %%
# Example: Search for housing assistance in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_colorado_springs.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf07ed70f508886d28d307b794307f65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf07ed70f508886d28d307b794307f65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf07ed70f508886d28d307b794307f65 = L.map(
#                 &quot;map_cf07ed70f508886d28d307b794307f65&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4834b8afe8c7900afeb8ee76c8c43f92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4834b8afe8c7900afeb8ee76c8c43f92.addTo(map_cf07ed70f508886d28d307b794307f65);
#
#
#             var marker_cdc6bfaf2cd1a233d5b0e48584af1ac9 = L.marker(
#                 [38.8255421, -104.7651236],
#                 {}
#             ).addTo(map_cf07ed70f508886d28d307b794307f65);
#
#
#         var popup_90f74a17e7aa3988de23060f23d59311 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3571a9634a4c8a9ee8b7a7ab24e8c3a = $(`&lt;div id=&quot;html_e3571a9634a4c8a9ee8b7a7ab24e8c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;DREAM CENTERS&lt;/strong&gt;&lt;br&gt;     3650 Airport Rd&lt;br&gt;     Colorado Springs, CO 80910&lt;br&gt;     Phone: (719) 301-5411&lt;br&gt;     Website: &lt;a href=&quot;http://dreamcenters.com/marys-home/apply/&quot;&gt;DREAM CENTERS&lt;/a&gt;&lt;br&gt;     Services: Provides transitional housing for homeless or imminently homeless adult women who are TANF, CCCAP and SNAP eligible, with three or less children eight years of age or younger...     &lt;/div&gt;`)[0];
#                 popup_90f74a17e7aa3988de23060f23d59311.setContent(html_e3571a9634a4c8a9ee8b7a7ab24e8c3a);
#
#
#
#         marker_cdc6bfaf2cd1a233d5b0e48584af1ac9.bindPopup(popup_90f74a17e7aa3988de23060f23d59311)
#         ;
#
#
#
#
#             var marker_b9efb64693e989f84d6ba86bc136c06c = L.marker(
#                 [38.8457952, -104.8316252],
#                 {}
#             ).addTo(map_cf07ed70f508886d28d307b794307f65);
#
#
#         var popup_e24c321d6fa1fb1bc66e6f5633194599 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_424fa74d363033f7ef274b98de3d1dfe = $(`&lt;div id=&quot;html_424fa74d363033f7ef274b98de3d1dfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ITHAKA HOUSING&lt;/strong&gt;&lt;br&gt;     321 Mesa Rd&lt;br&gt;     Colorado Springs, CO 80905&lt;br&gt;     Phone: (719) 578-1629&lt;br&gt;     Website: &lt;a href=&quot;http://ithakaland.org&quot;&gt;ITHAKA HOUSING&lt;/a&gt;&lt;br&gt;     Services: Provides transitional housing, in a group home setting, for individual men aged 25 and older who are willing and able to work full-time...     &lt;/div&gt;`)[0];
#                 popup_e24c321d6fa1fb1bc66e6f5633194599.setContent(html_424fa74d363033f7ef274b98de3d1dfe);
#
#
#
#         marker_b9efb64693e989f84d6ba86bc136c06c.bindPopup(popup_e24c321d6fa1fb1bc66e6f5633194599)
#         ;
#
#
#
#
#             var marker_2f5ad6a61b2f9dbbce268b14038e7505 = L.marker(
#                 [38.8381918, -104.8303286],
#                 {}
#             ).addTo(map_cf07ed70f508886d28d307b794307f65);
#
#
#         var popup_0c3c225988952e6de49cad54128a0548 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c8927618555fd82c3e51d750471073a = $(`&lt;div id=&quot;html_4c8927618555fd82c3e51d750471073a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HASEYA ADVOCATE PROGRAM&lt;/strong&gt;&lt;br&gt;     I-25&lt;br&gt;     Colorado Springs, CO 80903&lt;br&gt;     Phone: (719) 660-3939&lt;br&gt;     Website: &lt;a href=&quot;http://haseya.org&quot;&gt;HASEYA ADVOCATE PROGRAM&lt;/a&gt;&lt;br&gt;     Services: Provides transitional housing for Native American/American Indian individuals fleeing domestic violence and/or sexual assault.     &lt;/div&gt;`)[0];
#                 popup_0c3c225988952e6de49cad54128a0548.setContent(html_4c8927618555fd82c3e51d750471073a);
#
#
#
#         marker_2f5ad6a61b2f9dbbce268b14038e7505.bindPopup(popup_0c3c225988952e6de49cad54128a0548)
#         ;
#
#
#
#
#             var marker_e35b2617f9f975d25e30765c826a7f6d = L.marker(
#                 [38.8242437, -104.8293314],
#                 {}
#             ).addTo(map_cf07ed70f508886d28d307b794307f65);
#
#
#         var popup_72ee9d443e54b6a935016fa631d5c962 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7cace0f8ae51ca913708bbbc630516a = $(`&lt;div id=&quot;html_f7cace0f8ae51ca913708bbbc630516a&quot; style=&quot;width: 100.0%; height: 100.0%;&

# %%
# Example: Search for housing assistance in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06ec149da8e19c26f6fde8f20aa1f034 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06ec149da8e19c26f6fde8f20aa1f034&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06ec149da8e19c26f6fde8f20aa1f034 = L.map(
#                 &quot;map_06ec149da8e19c26f6fde8f20aa1f034&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed4594ff192f232819eee48380d44172 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ed4594ff192f232819eee48380d44172.addTo(map_06ec149da8e19c26f6fde8f20aa1f034);
#
#
#             var marker_20f21c26575089333e6c1135e48a290c = L.marker(
#                 [39.7466731, -104.8316117],
#                 {}
#             ).addTo(map_06ec149da8e19c26f6fde8f20aa1f034);
#
#
#         var popup_c1c5475b43c2ba99a18a60dc87c945b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a8f16f3797f9a74fd03434518b3852b = $(`&lt;div id=&quot;html_8a8f16f3797f9a74fd03434518b3852b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/strong&gt;&lt;br&gt;     13387 E 19th Pl&lt;br&gt;     Aurora, CO 80011&lt;br&gt;     Phone: (303) 341-9160&lt;br&gt;     Website: &lt;a href=&quot;http://comitiscrisiscenter.org/aurora-day-resource-center&quot;&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/a&gt;&lt;br&gt;     Services: Provides the following drop-in services: Breakfast and lunch Hygiene items Showers Laundry services Sleeping bags Mail and document retention Medication storage Dental and medical services Housing assistance Employment services Financial literacy Pet food Pet health services Computer lab HIV/Hepatitis C testing Acute behavioral health service...     &lt;/div&gt;`)[0];
#                 popup_c1c5475b43c2ba99a18a60dc87c945b7.setContent(html_8a8f16f3797f9a74fd03434518b3852b);
#
#
#
#         marker_20f21c26575089333e6c1135e48a290c.bindPopup(popup_c1c5475b43c2ba99a18a60dc87c945b7)
#         ;
#
#
#
#
#             var marker_4af502dd087e4ae9b6ee24990f9cf527 = L.marker(
#                 [39.7492153, -104.8329055],
#                 {}
#             ).addTo(map_06ec149da8e19c26f6fde8f20aa1f034);
#
#
#         var popup_4ce717b19e332d368983b4187cf9c857 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d44473e5b0dd8969536043e106e2284 = $(`&lt;div id=&quot;html_4d44473e5b0dd8969536043e106e2284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/strong&gt;&lt;br&gt;     2178 Victor St&lt;br&gt;     Aurora, CO 80045&lt;br&gt;     Phone: (303) 341-9160 (Family Lottery Line)&lt;br&gt;     Website: &lt;a href=&quot;http://comitiscrisiscenter.org/comitis-crisis-center&quot;&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/a&gt;&lt;br&gt;     Services: Offers up to one week of emergency shelter for individuals with dependent children and their partners.     &lt;/div&gt;`)[0];
#                 popup_4ce717b19e332d368983b4187cf9c857.setContent(html_4d44473e5b0dd8969536043e106e2284);
#
#
#
#         marker_4af502dd087e4ae9b6ee24990f9cf527.bindPopup(popup_4ce717b19e332d368983b4187cf9c857)
#         ;
#
#
#
#
#             var marker_fd4c8de619aeb76a4289a47e6273443d = L.marker(
#                 [39.7492153, -104.8329055],
#                 {}
#             ).addTo(map_06ec149da8e19c26f6fde8f20aa1f034);
#
#
#         var popup_ad4eb1ddc92b2ec12792ddd8a288a108 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de23fd39c2a2b1e34e9dc0fe490a4cb0 = $(`&lt;div id=&quot;html_de23fd39c2a2b1e34e9dc0fe490a4cb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/strong&gt;&lt;br&gt;     2178 Victor St&lt;br&gt;     Aurora, CO 80045&lt;br&gt;     Phone: (303) 341-9160&lt;br&gt;     Website: &lt;a href=&quot;http://comitiscrisiscenter.org/comitis-crisis-center&quot;&gt;MILE HIGH BEHAVIORAL HEALTHCARE&lt;/a&gt;&lt;br&gt;     Services: Provides long-term stays of up to two years for veterans experiencing homelessness.     &lt;/div&gt;`)[0];
#                 popup_ad4eb1ddc92b2ec12792ddd8a288a108.setContent(html_de23fd39c2a2b1e34e9dc0fe490a4cb0);
#
#
#
#         marker_fd4c8de619aeb76a4289a47e6273443d.bindPopup(popup_ad4eb1ddc92b2ec12792ddd8a288a108)
#         ;
#
#
#
#
#             var marker_09525e37280a1a04a4bc0afc9416e0df = L.marker(
#                 [39.7492153, -104.8329055],
#                 {}
#             ).addTo(map_06ec149da8e19c26f6fde8f20aa1f034);
#
#
#         var popup_557f440f3551

# %%
# Example: Search for housing assistance in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_fort_collins.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfc946d8b6d7f5272ff0c94b160f6415 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfc946d8b6d7f5272ff0c94b160f6415&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfc946d8b6d7f5272ff0c94b160f6415 = L.map(
#                 &quot;map_bfc946d8b6d7f5272ff0c94b160f6415&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0beab538a5fb743fe44cc9947219dd35 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0beab538a5fb743fe44cc9947219dd35.addTo(map_bfc946d8b6d7f5272ff0c94b160f6415);
#
#
#             var marker_58e9f51357eb93a10371f0e8485d41dc = L.marker(
#                 [40.5665586, -105.0569249],
#                 {}
#             ).addTo(map_bfc946d8b6d7f5272ff0c94b160f6415);
#
#
#         var popup_9258bce494fa0eb55edd72121c13e7bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83d8571c8569aa3f568440220aa3e2aa = $(`&lt;div id=&quot;html_83d8571c8569aa3f568440220aa3e2aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FAMILY HOUSING NETWORK&lt;/strong&gt;&lt;br&gt;     1606 S Lemay Ave Suite 103&lt;br&gt;     Fort Collins, CO 80525&lt;br&gt;     Phone: (970) 484-3342&lt;br&gt;     Website: &lt;a href=&quot;http://familyhousingnetwork.org/our-programs&quot;&gt;FAMILY HOUSING NETWORK&lt;/a&gt;&lt;br&gt;     Services: Provides a temporary overnight shelter for families for up to 3-4 months. Shelter locations rotate weekly among various faith communities in Fort Collins...     &lt;/div&gt;`)[0];
#                 popup_9258bce494fa0eb55edd72121c13e7bc.setContent(html_83d8571c8569aa3f568440220aa3e2aa);
#
#
#
#         marker_58e9f51357eb93a10371f0e8485d41dc.bindPopup(popup_9258bce494fa0eb55edd72121c13e7bc)
#         ;
#
#
#
#
#             var marker_c1ae520528c0e50d3cc4cd3bf62905df = L.marker(
#                 [40.5947368, -105.0692106],
#                 {}
#             ).addTo(map_bfc946d8b6d7f5272ff0c94b160f6415);
#
#
#         var popup_6de825b0db8b255f460530f37620d706 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e0211341b85e0530ce77a72a965bc6fa = $(`&lt;div id=&quot;html_e0211341b85e0530ce77a72a965bc6fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     460 Linden Center Dr&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Phone: (970) 493-0141 (Shelter)&lt;br&gt;     Website: &lt;a href=&quot;http://ccdenver.org/larimer/&quot;&gt;CATHOLIC CHARITIES LARIMER COUNTY&lt;/a&gt;&lt;br&gt;     Services: Provides nightly, year-round overnight shelter for families with children and single adult females.     &lt;/div&gt;`)[0];
#                 popup_6de825b0db8b255f460530f37620d706.setContent(html_e0211341b85e0530ce77a72a965bc6fa);
#
#
#
#         marker_c1ae520528c0e50d3cc4cd3bf62905df.bindPopup(popup_6de825b0db8b255f460530f37620d706)
#         ;
#
#
#
#
#             var marker_3c647e6d3bb08d2428b325832388eff5 = L.marker(
#                 [40.5947368, -105.0692106],
#                 {}
#             ).addTo(map_bfc946d8b6d7f5272ff0c94b160f6415);
#
#
#         var popup_39b283f1672173ae03779f483653f944 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f28cb009df285f7b9e3146d68b6a7f8 = $(`&lt;div id=&quot;html_2f28cb009df285f7b9e3146d68b6a7f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     460 Linden Center Dr&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Phone: (970) 493-0141&lt;br&gt;     Website: &lt;a href=&quot;http://ccdenver.org/larimer&quot;&gt;CATHOLIC CHARITIES LARIMER COUNTY&lt;/a&gt;&lt;br&gt;     Services: Provides a year-round, extended stay shelter program. Lengths of stay vary based on client needs and progress toward goals with a case manager (establishing income, building savings, and locating permanent housing), but are generally 4 - 6 months long. Additional...     &lt;/div&gt;`)[0];
#                 popup_39b283f1672173ae03779f483653f944.setContent(html_2f28cb009df285f7b9e3146d68b6a7f8);
#
#
#
#         marker_3c647e6d3bb08d2428b325832388eff5.bindPopup(popup_39b283f1672173ae03779f483653f944)
#         ;
#
#
#
#
#             tile_layer_0beab538a5fb743fe44cc9947219dd35.addTo(map_bfc946d8b6d7f5272ff0c94b160f6415);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></if

# %%
# Example: Search for housing assistance in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_lakewood.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba8c44a4e728c98543adc3beff6bfed9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba8c44a4e728c98543adc3beff6bfed9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba8c44a4e728c98543adc3beff6bfed9 = L.map(
#                 &quot;map_ba8c44a4e728c98543adc3beff6bfed9&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b839fc9001be0a34ff6fc11c448a66e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8b839fc9001be0a34ff6fc11c448a66e.addTo(map_ba8c44a4e728c98543adc3beff6bfed9);
#
#
#             tile_layer_8b839fc9001be0a34ff6fc11c448a66e.addTo(map_ba8c44a4e728c98543adc3beff6bfed9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for housing assistance in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_arvada.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b751ccd020d9d1a9a94f68e854e7e774 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b751ccd020d9d1a9a94f68e854e7e774&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b751ccd020d9d1a9a94f68e854e7e774 = L.map(
#                 &quot;map_b751ccd020d9d1a9a94f68e854e7e774&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bf34c1c19f64c4ed5d141793371e6da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7bf34c1c19f64c4ed5d141793371e6da.addTo(map_b751ccd020d9d1a9a94f68e854e7e774);
#
#
#             var marker_e36c06ec349a3fda435bc2749a94647c = L.marker(
#                 [39.8140575, -105.0557237],
#                 {}
#             ).addTo(map_b751ccd020d9d1a9a94f68e854e7e774);
#
#
#         var popup_1f3369ea87ce22e5c614798bc5a41569 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9dbf45148be8a9f10615afbd9e175a5c = $(`&lt;div id=&quot;html_9dbf45148be8a9f10615afbd9e175a5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;HOPE HOUSE COLORADO&lt;/strong&gt;&lt;br&gt;     6475 Benton St Bldg A&lt;br&gt;     Arvada, CO 80003&lt;br&gt;     Phone: (303) 429-1012 Ext 238&lt;br&gt;     Website: &lt;a href=&quot;http://hopehouseofcolorado.org&quot;&gt;HOPE HOUSE COLORADO&lt;/a&gt;&lt;br&gt;     Services: Provides a safe, structured home for a parenting teen mom while working through a program designed to help earn a GED or educational certificate and move on to further education...     &lt;/div&gt;`)[0];
#                 popup_1f3369ea87ce22e5c614798bc5a41569.setContent(html_9dbf45148be8a9f10615afbd9e175a5c);
#
#
#
#         marker_e36c06ec349a3fda435bc2749a94647c.bindPopup(popup_1f3369ea87ce22e5c614798bc5a41569)
#         ;
#
#
#
#
#             tile_layer_7bf34c1c19f64c4ed5d141793371e6da.addTo(map_b751ccd020d9d1a9a94f68e854e7e774);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for housing assistance in a specific city
city_search = "Greeley"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_greeley.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e73448bfdf137cbb963a40487b277a26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e73448bfdf137cbb963a40487b277a26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e73448bfdf137cbb963a40487b277a26 = L.map(
#                 &quot;map_e73448bfdf137cbb963a40487b277a26&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a99b17401daaa107e5e3e41d71572371 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a99b17401daaa107e5e3e41d71572371.addTo(map_e73448bfdf137cbb963a40487b277a26);
#
#
#             var marker_bb1065346d406edc4493ee1bec014439 = L.marker(
#                 [40.4225069, -104.6982977],
#                 {}
#             ).addTo(map_e73448bfdf137cbb963a40487b277a26);
#
#
#         var popup_13ba9b9498e483539674af3c53e7e28a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a8b1a2f491edc3c92bbf4c1a2382f6c = $(`&lt;div id=&quot;html_7a8b1a2f491edc3c92bbf4c1a2382f6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GREELEY FAMILY HOUSE&lt;/strong&gt;&lt;br&gt;     1206 10th St&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 352-3215&lt;br&gt;     Website: &lt;a href=&quot;http://greeleyfamilyhouse.org&quot;&gt;GREELEY FAMILY HOUSE&lt;/a&gt;&lt;br&gt;     Services: Provides an emergency shelter program (up to 60 days) for families. While living at the shelter, families are required to look for employment and housing, and meet with a case manager on a weekly basis to develop a self-suhciency plan...     &lt;/div&gt;`)[0];
#                 popup_13ba9b9498e483539674af3c53e7e28a.setContent(html_7a8b1a2f491edc3c92bbf4c1a2382f6c);
#
#
#
#         marker_bb1065346d406edc4493ee1bec014439.bindPopup(popup_13ba9b9498e483539674af3c53e7e28a)
#         ;
#
#
#
#
#             var marker_d66e012047c0eb07fe67efa11dc0eeea = L.marker(
#                 [40.4501919, -104.6965757],
#                 {}
#             ).addTo(map_e73448bfdf137cbb963a40487b277a26);
#
#
#         var popup_cbc7e8dab75c54f8754934054c2bb785 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_553b1f00806cc319e0d70c9a815e427c = $(`&lt;div id=&quot;html_553b1f00806cc319e0d70c9a815e427c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES WELD COUNTY&lt;/strong&gt;&lt;br&gt;     1442 N 11th Ave&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 353-6433&lt;br&gt;     Website: &lt;a href=&quot;http://ccdenver.org&quot;&gt;CATHOLIC CHARITIES WELD COUNTY&lt;/a&gt;&lt;br&gt;     Services: Offers services for older adults to help keep them safe and independent in their own homes. Services include: Case management Advocacy Benefit forms assistance Home visits Information and referrals Group and educational materials Translation/interpretation services Commodities and emergency food boxes Health and safety assessment...     &lt;/div&gt;`)[0];
#                 popup_cbc7e8dab75c54f8754934054c2bb785.setContent(html_553b1f00806cc319e0d70c9a815e427c);
#
#
#
#         marker_d66e012047c0eb07fe67efa11dc0eeea.bindPopup(popup_cbc7e8dab75c54f8754934054c2bb785)
#         ;
#
#
#
#
#             var marker_baa63d166e3e76efb3746f4ac38ce818 = L.marker(
#                 [40.4501919, -104.6965757],
#                 {}
#             ).addTo(map_e73448bfdf137cbb963a40487b277a26);
#
#
#         var popup_56eb7b446bc38d998d3e00a15afa586b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89bfa2122aa12f10d1e8670fdb4ad280 = $(`&lt;div id=&quot;html_89bfa2122aa12f10d1e8670fdb4ad280&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CATHOLIC CHARITIES WELD COUNTY&lt;/strong&gt;&lt;br&gt;     1442 N 11th Ave&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 353-6433&lt;br&gt;     Website: &lt;a href=&quot;http://ccdenver.org&quot;&gt;CATHOLIC CHARITIES WELD COUNTY&lt;/a&gt;&lt;br&gt;     Services: Provides a 150 day transitional shelter and program for adults and families, with the goal of obtaining stable income and housing. Residents are provided with: Specialized case managementAssistance with obtaining government issued benefits for seniors Housing assistance Additional resource...     &lt;/div&gt;`)[0];
#                 popup_56eb7b446bc38d998d3e00a15afa586b.setContent(html_89bfa2122aa12f10d1e8670fdb4ad280);
#
#
#
#         marker_baa63d166e3e76efb3746f4ac38ce818.bindPopup(popup_56eb7b446bc38d998d3e00a15afa586b)
#         ;
#
#
#
#
#             var marker_d3431cdb58af993040b

# %%
# Example: Search for housing assistance in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_pueblo.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4978f19d0879ec20edb818f359543fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4978f19d0879ec20edb818f359543fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4978f19d0879ec20edb818f359543fb = L.map(
#                 &quot;map_a4978f19d0879ec20edb818f359543fb&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d10f106c466b5ed6f16544c33d850bae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d10f106c466b5ed6f16544c33d850bae.addTo(map_a4978f19d0879ec20edb818f359543fb);
#
#
#             var marker_d4df38217eb035bb3cd4b83ac39c6362 = L.marker(
#                 [38.258448, -104.638301],
#                 {}
#             ).addTo(map_a4978f19d0879ec20edb818f359543fb);
#
#
#         var popup_058ba53e76d97c071b8eefba93449394 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2670ba552f058e2f1a64d9cd3067bff2 = $(`&lt;div id=&quot;html_2670ba552f058e2f1a64d9cd3067bff2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;POSADA OF PUEBLO&lt;/strong&gt;&lt;br&gt;     501 Belmont Ave&lt;br&gt;     Pueblo, CO 81004&lt;br&gt;     Phone: (719) 545-8776&lt;br&gt;     Website: &lt;a href=&quot;http://www.posadapueblo.org&quot;&gt;POSADA OF PUEBLO&lt;/a&gt;&lt;br&gt;     Services: Provide transitionl housing, basic needs support, case management. Provide Housing counseling, life skills, education and employment assistance, legal services, mental health and substance abuse counseling...     &lt;/div&gt;`)[0];
#                 popup_058ba53e76d97c071b8eefba93449394.setContent(html_2670ba552f058e2f1a64d9cd3067bff2);
#
#
#
#         marker_d4df38217eb035bb3cd4b83ac39c6362.bindPopup(popup_058ba53e76d97c071b8eefba93449394)
#         ;
#
#
#
#
#             var marker_df6942e347fdff2a17dcde0a137c532d = L.marker(
#                 [38.258448, -104.638301],
#                 {}
#             ).addTo(map_a4978f19d0879ec20edb818f359543fb);
#
#
#         var popup_533f566519656e8cf4dc8e6dc0c2c674 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f723cfd53289e98451ffe0fd42f03f01 = $(`&lt;div id=&quot;html_f723cfd53289e98451ffe0fd42f03f01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;POSADA OF PUEBLO&lt;/strong&gt;&lt;br&gt;     501 Belmont Ave&lt;br&gt;     Pueblo, CO 81004&lt;br&gt;     Phone: (719) 545-8776&lt;br&gt;     Website: &lt;a href=&quot;http://www.posadapueblo.org&quot;&gt;POSADA OF PUEBLO&lt;/a&gt;&lt;br&gt;     Services: Provide referrals to homeless families with children for shelter, basic needs. Review options for low-income housing, identify community resources and programs to obtain self-sufficiency...     &lt;/div&gt;`)[0];
#                 popup_533f566519656e8cf4dc8e6dc0c2c674.setContent(html_f723cfd53289e98451ffe0fd42f03f01);
#
#
#
#         marker_df6942e347fdff2a17dcde0a137c532d.bindPopup(popup_533f566519656e8cf4dc8e6dc0c2c674)
#         ;
#
#
#
#
#             tile_layer_d10f106c466b5ed6f16544c33d850bae.addTo(map_a4978f19d0879ec20edb818f359543fb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for housing assistance in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_boulder.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94bfe314ad85503f1ac2f0e6f69ca757 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94bfe314ad85503f1ac2f0e6f69ca757&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94bfe314ad85503f1ac2f0e6f69ca757 = L.map(
#                 &quot;map_94bfe314ad85503f1ac2f0e6f69ca757&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f787a801d4941caccefcc97b4c05b41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9f787a801d4941caccefcc97b4c05b41.addTo(map_94bfe314ad85503f1ac2f0e6f69ca757);
#
#
#             var marker_4f93ebe42e1aa14e781fb1e113bd4ec7 = L.marker(
#                 [40.0625882, -105.282615],
#                 {}
#             ).addTo(map_94bfe314ad85503f1ac2f0e6f69ca757);
#
#
#         var popup_11c1894d812eb0811ec75538fcc5658a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecfd07a1bebeef54cde33f53bd5930c9 = $(`&lt;div id=&quot;html_ecfd07a1bebeef54cde33f53bd5930c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ALL ROADS SHELTER&lt;/strong&gt;&lt;br&gt;     4869 Broadway&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     Phone: (303) 579-4404 (Boulder)&lt;br&gt;     Website: &lt;a href=&quot;http://allroadsboco.org/housing-focused-shelter/&quot;&gt;ALL ROADS SHELTER&lt;/a&gt;&lt;br&gt;     Services: Offers a overnight shelter and services for adults experiencing homelessness. Also provides long-term shelter to homeless adults with moderate and high needs in Boulder County to give them a predictable place to stay while they work toward exiting homelessness...     &lt;/div&gt;`)[0];
#                 popup_11c1894d812eb0811ec75538fcc5658a.setContent(html_ecfd07a1bebeef54cde33f53bd5930c9);
#
#
#
#         marker_4f93ebe42e1aa14e781fb1e113bd4ec7.bindPopup(popup_11c1894d812eb0811ec75538fcc5658a)
#         ;
#
#
#
#
#             var marker_546e21f70b6126983a1818ec20a8555e = L.marker(
#                 [40.0306466, -105.2817333],
#                 {}
#             ).addTo(map_94bfe314ad85503f1ac2f0e6f69ca757);
#
#
#         var popup_9bd07269f8d3dbfb81a9d876e4d572ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68ac91b67654c113a24f6ea199cafd39 = $(`&lt;div id=&quot;html_68ac91b67654c113a24f6ea199cafd39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;TGTHR&lt;/strong&gt;&lt;br&gt;     3080 Broadway&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     Phone: (303) 447-1207&lt;br&gt;     Website: &lt;a href=&quot;http://tgthr.org/&quot;&gt;TGTHR&lt;/a&gt;&lt;br&gt;     Services: Provides street outreach and an overnight emergency shelter services for teens. The overnight shelter services include: Food Clothing Showers A place to be overnight For the overnight shelter, youth must participate in case management...     &lt;/div&gt;`)[0];
#                 popup_9bd07269f8d3dbfb81a9d876e4d572ba.setContent(html_68ac91b67654c113a24f6ea199cafd39);
#
#
#
#         marker_546e21f70b6126983a1818ec20a8555e.bindPopup(popup_9bd07269f8d3dbfb81a9d876e4d572ba)
#         ;
#
#
#
#
#             var marker_3f840cae7a711d640d5766e4566b5dd2 = L.marker(
#                 [40.058333, -105.2778705],
#                 {}
#             ).addTo(map_94bfe314ad85503f1ac2f0e6f69ca757);
#
#
#         var popup_7e23dea93c4054822402c8b708325f0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d27efe7d3e4fb4f5b0ce5e2fb3177771 = $(`&lt;div id=&quot;html_d27efe7d3e4fb4f5b0ce5e2fb3177771&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;EMERGENCY FAMILY ASSISTANCE ASSOCIATION&lt;/strong&gt;&lt;br&gt;     1575 Yarmouth Ave&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     Phone: (303) 442-3042&lt;br&gt;     Website: &lt;a href=&quot;http://efaa.org/&quot;&gt;EMERGENCY FAMILY ASSISTANCE ASSOCIATION&lt;/a&gt;&lt;br&gt;     Services: Provides direct financial assistance to qualifying households in the City of Boulder and Boulder County mountain communities in the form of direct payment to vendors...     &lt;/div&gt;`)[0];
#                 popup_7e23dea93c4054822402c8b708325f0e.setContent(html_d27efe7d3e4fb4f5b0ce5e2fb3177771);
#
#
#
#         marker_3f840cae7a711d640d5766e4566b5dd2.bindPopup(popup_7e23dea93c4054822402c8b708325f0e)
#         ;
#
#
#
#
#             var marker_0cfdf5b6922727b5c0b28eeda3f4b3b6 = L.marker(
#                 [40.058333, -105.2778705],
#                 {}
#             ).addTo(map_94bfe314ad85503f1ac2f0e6f69ca757);
#
#
#         var popup_f712cfa9e433f355f4bbe1297b132feb

# %%
# Example: Search for housing assistance in a specific city
city_search = "Grand Junction"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_housing_assistance_map_grand_junction.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_464a0fc257c151c0c557f258f15a73d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_464a0fc257c151c0c557f258f15a73d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_464a0fc257c151c0c557f258f15a73d7 = L.map(
#                 &quot;map_464a0fc257c151c0c557f258f15a73d7&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6026e4aa6e3cdbcc1ecce724eec1c1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d6026e4aa6e3cdbcc1ecce724eec1c1f.addTo(map_464a0fc257c151c0c557f258f15a73d7);
#
#
#             var marker_6cf5a45e69d8718683f62f30776cbb01 = L.marker(
#                 [39.0655869, -108.5712505],
#                 {}
#             ).addTo(map_464a0fc257c151c0c557f258f15a73d7);
#
#
#         var popup_b1597915be9ab44a60cdd437c918e1d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec822f65377e2ae067d42b1b16f565d5 = $(`&lt;div id=&quot;html_ec822f65377e2ae067d42b1b16f565d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/strong&gt;&lt;br&gt;     245 S 1st St&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     Phone: (970) 241-3658&lt;br&gt;     Website: &lt;a href=&quot;http://catholicoutreach.org&quot;&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/a&gt;&lt;br&gt;     Services: Provides individuals with the opportunity to end homelessness through cooperative living, case management, and training.     &lt;/div&gt;`)[0];
#                 popup_b1597915be9ab44a60cdd437c918e1d9.setContent(html_ec822f65377e2ae067d42b1b16f565d5);
#
#
#
#         marker_6cf5a45e69d8718683f62f30776cbb01.bindPopup(popup_b1597915be9ab44a60cdd437c918e1d9)
#         ;
#
#
#
#
#             var marker_08dcf7110dda85ad66512e481e7d4581 = L.marker(
#                 [39.0655869, -108.5712505],
#                 {}
#             ).addTo(map_464a0fc257c151c0c557f258f15a73d7);
#
#
#         var popup_6ceb959b3db8c71c2a12d55f58a63a7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9f72b74ed40e7c0c1f1c6a86a85d00c = $(`&lt;div id=&quot;html_b9f72b74ed40e7c0c1f1c6a86a85d00c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/strong&gt;&lt;br&gt;     245 S 1st St&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     Phone: (970) 241-3658&lt;br&gt;     Website: &lt;a href=&quot;http://catholicoutreach.org&quot;&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/a&gt;&lt;br&gt;     Services: Provides homes to those with mental or physical impairments who have been chronically homeless and are free from drug abuse.     &lt;/div&gt;`)[0];
#                 popup_6ceb959b3db8c71c2a12d55f58a63a7f.setContent(html_b9f72b74ed40e7c0c1f1c6a86a85d00c);
#
#
#
#         marker_08dcf7110dda85ad66512e481e7d4581.bindPopup(popup_6ceb959b3db8c71c2a12d55f58a63a7f)
#         ;
#
#
#
#
#             var marker_94b169ff34838793b3d824d7956e2b3a = L.marker(
#                 [39.0646476, -108.5676123],
#                 {}
#             ).addTo(map_464a0fc257c151c0c557f258f15a73d7);
#
#
#         var popup_50d591f57db6de949328edbd5a777ccf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5c1fcd98ffe31388b8774b408ff2aae = $(`&lt;div id=&quot;html_b5c1fcd98ffe31388b8774b408ff2aae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/strong&gt;&lt;br&gt;     302 Pitkin Ave&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     Phone: (970) 263-9445&lt;br&gt;     Website: &lt;a href=&quot;http://catholicoutreach.org&quot;&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/a&gt;&lt;br&gt;     Services: Provides a day center for individuals experiencing homelessness. Addition services and amenities include: Shower and laundry services Telephone services P...     &lt;/div&gt;`)[0];
#                 popup_50d591f57db6de949328edbd5a777ccf.setContent(html_b5c1fcd98ffe31388b8774b408ff2aae);
#
#
#
#         marker_94b169ff34838793b3d824d7956e2b3a.bindPopup(popup_50d591f57db6de949328edbd5a777ccf)
#         ;
#
#
#
#
#             var marker_84657cdc3a01f2e8c61b8fe7a376fc7f = L.marker(
#                 [39.0768951, -108.5226613],
#                 {}
#             ).addTo(map_464a0fc257c151c0c557f258f15a73d7);
#
#
#         var popup_21fc6b5b2128e82ea27be5f13bf5ea95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8adf3e9c570294b71ac14c626ec7f711 = $(`&lt;div id=&quot;html_8adf3e9c570294b71ac14c626ec7f711&quot;

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_housing_assistance_v2.csv", index=False)

# Confirm the export
print("Data exported to cleaned_colorado_housing_assistance_v2.csv")
# Out:
# Data exported to cleaned_colorado_housing_assistance_v2.csv
