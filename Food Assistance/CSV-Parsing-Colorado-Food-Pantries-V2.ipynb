# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create multiple city specific map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_food_pantries.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#                  Assistance  \
# 0               Food Pantry
# 1               Food Pantry
# 2               Food Pantry
# 3               Food Pantry
# 4               Food Pantry
# 5           Food Assistance
# 6               Food Pantry
# 7               Food Pantry
# 8               Food Pantry
# 9           Food Assistance
# 10              Food Pantry
# 11              Food Pantry
# 12              Food Pantry
# 13              Food Pantry
# 14  Pet Food Pantry Locator
#
#                                                Agency  \
# 0                SILVER THREAD PUBLIC HEALTH DISTRICT
# 1                                   PINE RIVER SHARES
# 2   COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SP...
# 3                              RESTORATION FELLOWSHIP
# 4                            OURAY COUNTY FOOD PANTRY
# 5                        LOVE INC OF THE YAMPA VALLEY
# 6                                  CONNECTIONS 4 LIFE
# 7                               GOD'S PANTRY MINISTRY
# 8                      GRAND VALLEY CATHOLIC OUTREACH
# 9                      WOODLAND PARK COMMUNITY CHURCH
# 10                  LA PLATA FAMILY CENTERS COALITION
# 11                        CENTER TOWARD SELF-RELIANCE
# 12                           CITY OF COLORADO SPRINGS
# 13                          NEW LIFE COMMUNITY CHURCH
# 14                                COLORADO PET PANTRY
#
#                          Address              City State    Zip  \
# 0                   304 W 3rd St         Lake City    CO  81235
# 1                  658 S East St          Bayfield    CO  81122
# 2                   434 Lewis St    Pagosa Springs    CO  81147
# 3                 264 Village Dr    Pagosa Springs    CO  81147
# 4                  602 N Cora St           Ridgway    CO  81432
# 5             1198 W Victory Way             Craig    CO  81625
# 6   6436 S U.S. Hwy 85/87 Unit U  Colorado Springs    CO  80911
# 7              30 Widefield Blvd  Colorado Springs    CO  80911
# 8                   245 S 1st St    Grand Junction    CO  81501
# 9      700 Valley View Dr Unit D     Woodland Park    CO  80863
# 10                495 Florida Rd           Durango    CO  81301
# 11                  901 W 8th St            Pueblo    CO  81003
# 12       4290 Deerfield Hills Rd  Colorado Springs    CO  80916
# 13             17690 E Iliff Ave            Aurora    CO  80013
# 14                  P.O. Box 323           Boulder    CO  80306
#
#               County                                           Services  \
# 0    HINSDALE COUNTY  Provides a food box to individuals, seniors an...
# 1    LA PLATA COUNTY  Provides food for community members in need of...
# 2   ARCHULETA COUNTY  Provides food to individuals and families in A...
# 3   ARCHULETA COUNTY  Provides food boxes for residents of Archuleta...
# 4       OURAY COUNTY  Provides groceries based on a shopping list fo...
# 5      MOFFAT COUNTY  Provides food to qualified individuals and fam...
# 6     EL PASO COUNTY       Provides a food pantry to residents in need.
# 7     EL PASO COUNTY                            Provides a food pantry.
# 8        MESA COUNTY  Provides food box for Mesa County residents in...
# 9      TELLER COUNTY  Provides emergency food necessities and delive...
# 10   LA PLATA COUNTY  Provides a food box to families in need in the...
# 11     PUEBLO COUNTY  Food Pantry provides food assistance to low-in...
# 12    EL PASO COUNTY  Provides a drive-thru style food pantry to tho...
# 13   ARAPAHOE COUNTY  Provides bags of food to the community. The pa...
# 14    BOULDER COUNTY  Provides free temporary pet food through vario...
#
#                                           Eligibility  \
# 0   Individuals in the service area Area Served: H...
# 1   Must be residents of Bayfield and the Pine Riv...
# 2   No restrictions applied Area Served: Archuleta...
# 3      No restrictions. Area Served: Archuleta County
# 4   Individuals must be a resident of Ouray County...
# 5   For TEFAP assistance, households must meet the...
# 6   Residents of the service area Area Served: El ...
# 7   No restrictions applied Area Served: El Paso C...
# 8    No restrictions applied Area Served: Mesa County
# 9   No restrictions applied Area Served: Zip Codes...
# 10  No restriction applied Area Served: La Plata, ...
# 11  Open to the Public, low-income individuals who...
# 12  No restrictions applied Area Served: El Paso C...
# 13  No restrictions applied Area Served: Adams, Ar...
# 14     No restrictions applied Area Served: Statewide
#
#                                                 Hours           Phone  \
# 0                 Monday - Friday, 8 a.m. - 4:30 p.m.  (970) 944-0321
# 1                  Monday - Thursday, 9 a.m. - 3 p.m.  (970) 884-6040
# 2                Tuesday - Thursday, 8 a.m. - 12 p.m.  (970) 264-5508
# 3                        Monday-Friday, 8:00am-5:00pm  (970) 731-2937
# 4                        Thursday, 12:30 pm - 3:30 pm  (970) 626-4273
# 5   3rd Tuesday, 10 a.m. - 12 p.m.; 3rd Thursday, ...  (970) 826-4400
# 6                                          Hours Vary  (719) 387-9919
# 7                  Monday - Saturday, 9 a.m. - 3 p.m.  (719) 382-0643
# 8                Monday - Friday, 9 a.m. - 11:30 a.m.  (970) 241-3658
# 9                 Monday - Thursday, 9 a.m. - 12 p.m.  (719) 229-4512
# 10  Monday - Thursday, 8:30 a.m. - 4:30 p.m.; Frid...  (970) 385-4747
# 11                Monday - Friday, 8 a.m. - 4:30 p.m.  (719) 546-1271
# 12                   Monday - Friday, 9 a.m. - 6 p.m.  (719) 385-5996
# 13  Tuesday, 1 p.m. - 4 p.m.; Saturday, 10 a.m. - ...  (303) 368-7567
# 14  Monday - Sunday, 9 a.m. - 5 p.m. (Administrati...  (303) 818-0618
#
#                                               Website   Latitude   Longitude
# 0                 http://silverthreadpublichealth.org  38.028217 -107.314490
# 1                          http://pinerivershares.org  37.224047 -107.598306
# 2                                   http://cumcps.org  37.267823 -107.011796
# 3                    http://restorationfellowship.net  37.258096 -107.075037
# 4                    http://ouraycountyfoodpantry.org  38.156621 -107.757265
# 5              http://loveincyampavalley.org/services  40.514264 -107.561261
# 6                   http://connections4lifecenter.org  38.745604 -104.738987
# 7                             http://godspantryco.org  38.736079 -104.727113
# 8                         http://catholicoutreach.org  39.065587 -108.571251
# 9   http://woodlandparkcommunitychurch.com/storehouse  39.012142 -105.062023
# 10                                   http://lpfcc.org  37.283861 -107.869957
# 11                              https://cfdpueblo.org  38.274091 -104.619700
# 12  http://coloradosprings.gov/deeraeld-hills-comm...  38.784574 -104.747881
# 13                              http://nlccaurora.org  39.674607 -104.778200
# 14  http://coloradopetpantry.org/events/category/p...  40.102555 -105.363208

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Assistance   443 non-null    object
#  1   Agency       443 non-null    object
#  2   Address      443 non-null    object
#  3   City         443 non-null    object
#  4   State        443 non-null    object
#  5   Zip          443 non-null    int64
#  6   County       443 non-null    object
#  7   Services     443 non-null    object
#  8   Eligibility  442 non-null    object
#  9   Hours        443 non-null    object
#  10  Phone        443 non-null    object
#  11  Website      440 non-null    object
#  12  Latitude     443 non-null    float64
#  13  Longitude    443 non-null    float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 48.6+ KB
#                  Assistance  \
# 0               Food Pantry
# 1               Food Pantry
# 2               Food Pantry
# 3               Food Pantry
# 4               Food Pantry
# 5           Food Assistance
# 6               Food Pantry
# 7               Food Pantry
# 8               Food Pantry
# 9           Food Assistance
# 10              Food Pantry
# 11              Food Pantry
# 12              Food Pantry
# 13              Food Pantry
# 14  Pet Food Pantry Locator
#
#                                                Agency  \
# 0                SILVER THREAD PUBLIC HEALTH DISTRICT
# 1                                   PINE RIVER SHARES
# 2   COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SP...
# 3                              RESTORATION FELLOWSHIP
# 4                            OURAY COUNTY FOOD PANTRY
# 5                        LOVE INC OF THE YAMPA VALLEY
# 6                                  CONNECTIONS 4 LIFE
# 7                               GOD'S PANTRY MINISTRY
# 8                      GRAND VALLEY CATHOLIC OUTREACH
# 9                      WOODLAND PARK COMMUNITY CHURCH
# 10                  LA PLATA FAMILY CENTERS COALITION
# 11                        CENTER TOWARD SELF-RELIANCE
# 12                           CITY OF COLORADO SPRINGS
# 13                          NEW LIFE COMMUNITY CHURCH
# 14                                COLORADO PET PANTRY
#
#                          Address              City State    Zip  \
# 0                   304 W 3rd St         Lake City    CO  81235
# 1                  658 S East St          Bayfield    CO  81122
# 2                   434 Lewis St    Pagosa Springs    CO  81147
# 3                 264 Village Dr    Pagosa Springs    CO  81147
# 4                  602 N Cora St           Ridgway    CO  81432
# 5             1198 W Victory Way             Craig    CO  81625
# 6   6436 S U.S. Hwy 85/87 Unit U  Colorado Springs    CO  80911
# 7              30 Widefield Blvd  Colorado Springs    CO  80911
# 8                   245 S 1st St    Grand Junction    CO  81501
# 9      700 Valley View Dr Unit D     Woodland Park    CO  80863
# 10                495 Florida Rd           Durango    CO  81301
# 11                  901 W 8th St            Pueblo    CO  81003
# 12       4290 Deerfield Hills Rd  Colorado Springs    CO  80916
# 13             17690 E Iliff Ave            Aurora    CO  80013
# 14                  P.O. Box 323           Boulder    CO  80306
#
#               County                                           Services  \
# 0    HINSDALE COUNTY  Provides a food box to individuals, seniors an...
# 1    LA PLATA COUNTY  Provides food for community members in need of...
# 2   ARCHULETA COUNTY  Provides food to individuals and families in A...
# 3   ARCHULETA COUNTY  Provides food boxes for residents of Archuleta...
# 4       OURAY COUNTY  Provides groceries based on a shopping list fo...
# 5      MOFFAT COUNTY  Provides food to qualified individuals and fam...
# 6     EL PASO COUNTY       Provides a food pantry to residents in need.
# 7     EL PASO COUNTY                            Provides a food pantry.
# 8        MESA COUNTY  Provides food box for Mesa County residents in...
# 9      TELLER COUNTY  Provides emergency food necessities and delive...
# 10   LA PLATA COUNTY  Provides a food box to families in need in the...
# 11     PUEBLO COUNTY  Food Pantry provides food assistance to low-in...
# 12    EL PASO COUNTY  Provides a drive-thru style food pantry to tho...
# 13   ARAPAHOE COUNTY  Provides bags of food to the community. The pa...
# 14    BOULDER COUNTY  Provides free temporary pet food through vario...
#
#                                           Eligibility  \
# 0   Individuals in the service area Area Served: H...
# 1   Must be residents of Bayfield and the Pine Riv...
# 2   No restrictions applied Area Served: Archuleta...
# 3      No restrictions. Area Served: Archuleta County
# 4   Individuals must be a resident of Ouray County...
# 5   For TEFAP assistance, households must meet the...
# 6   Residents of the service area Area Served: El ...
# 7   No restrictions applied Area Served: El Paso C...
# 8    No restrictions applied Area Served: Mesa County
# 9   No restrictions applied Area Served: Zip Codes...
# 10  No restriction applied Area Served: La Plata, ...
# 11  Open to the Public, low-income individuals who...
# 12  No restrictions applied Area Served: El Paso C...
# 13  No restrictions applied Area Served: Adams, Ar...
# 14     No restrictions applied Area Served: Statewide
#
#                                                 Hours           Phone  \
# 0                 Monday - Friday, 8 a.m. - 4:30 p.m.  (970) 944-0321
# 1                  Monday - Thursday, 9 a.m. - 3 p.m.  (970) 884-6040
# 2                Tuesday - Thursday, 8 a.m. - 12 p.m.  (970) 264-5508
# 3                        Monday-Friday, 8:00am-5:00pm  (970) 731-2937
# 4                        Thursday, 12:30 pm - 3:30 pm  (970) 626-4273
# 5   3rd Tuesday, 10 a.m. - 12 p.m.; 3rd Thursday, ...  (970) 826-4400
# 6                                          Hours Vary  (719) 387-9919
# 7                  Monday - Saturday, 9 a.m. - 3 p.m.  (719) 382-0643
# 8                Monday - Friday, 9 a.m. - 11:30 a.m.  (970) 241-3658
# 9                 Monday - Thursday, 9 a.m. - 12 p.m.  (719) 229-4512
# 10  Monday - Thursday, 8:30 a.m. - 4:30 p.m.; Frid...  (970) 385-4747
# 11                Monday - Friday, 8 a.m. - 4:30 p.m.  (719) 546-1271
# 12                   Monday - Friday, 9 a.m. - 6 p.m.  (719) 385-5996
# 13  Tuesday, 1 p.m. - 4 p.m.; Saturday, 10 a.m. - ...  (303) 368-7567
# 14  Monday - Sunday, 9 a.m. - 5 p.m. (Administrati...  (303) 818-0618
#
#                                               Website   Latitude   Longitude
# 0                 http://silverthreadpublichealth.org  38.028217 -107.314490
# 1                          http://pinerivershares.org  37.224047 -107.598306
# 2                                   http://cumcps.org  37.267823 -107.011796
# 3                    http://restorationfellowship.net  37.258096 -107.075037
# 4                    http://ouraycountyfoodpantry.org  38.156621 -107.757265
# 5              http://loveincyampavalley.org/services  40.514264 -107.561261
# 6                   http://connections4lifecenter.org  38.745604 -104.738987
# 7                             http://godspantryco.org  38.736079 -104.727113
# 8                         http://catholicoutreach.org  39.065587 -108.571251
# 9   http://woodlandparkcommunitychurch.com/storehouse  39.012142 -105.062023
# 10                                   http://lpfcc.org  37.283861 -107.869957
# 11                              https://cfdpueblo.org  38.274091 -104.619700
# 12  http://coloradosprings.gov/deeraeld-hills-comm...  38.784574 -104.747881
# 13                              http://nlccaurora.org  39.674607 -104.778200
# 14  http://coloradopetpantry.org/events/category/p...  40.102555 -105.363208

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_food_pantries_map_v2.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5694f2ce48dcaa642424bd6c6fde092 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5694f2ce48dcaa642424bd6c6fde092&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5694f2ce48dcaa642424bd6c6fde092 = L.map(
#                 &quot;map_d5694f2ce48dcaa642424bd6c6fde092&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_031207549e913296620cec5a85598dbf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_031207549e913296620cec5a85598dbf.addTo(map_d5694f2ce48dcaa642424bd6c6fde092);
#
#
#             var marker_01a6a1bb58ead429a4beebffba782538 = L.marker(
#                 [38.028217, -107.31449],
#                 {}
#             ).addTo(map_d5694f2ce48dcaa642424bd6c6fde092);
#
#
#         var popup_d9c1fcfbbb221e51939140a4d29887f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e81fe7bbc9d178019dab86291d590ea3 = $(`&lt;div id=&quot;html_e81fe7bbc9d178019dab86291d590ea3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SILVER THREAD PUBLIC HEALTH DISTRICT&lt;/strong&gt;&lt;br&gt;     304 W 3rd St&lt;br&gt;     Lake City, CO 81235&lt;br&gt;     Phone: (970) 944-0321&lt;br&gt;     Website: http://silverthreadpublichealth.org&lt;br&gt;     Services: Provides a food box to individuals, seniors and families in need.     &lt;/div&gt;`)[0];
#                 popup_d9c1fcfbbb221e51939140a4d29887f7.setContent(html_e81fe7bbc9d178019dab86291d590ea3);
#
#
#
#         marker_01a6a1bb58ead429a4beebffba782538.bindPopup(popup_d9c1fcfbbb221e51939140a4d29887f7)
#         ;
#
#
#
#
#             var marker_e1d3699dce44ced082be031487d9e236 = L.marker(
#                 [37.2240474, -107.5983059],
#                 {}
#             ).addTo(map_d5694f2ce48dcaa642424bd6c6fde092);
#
#
#         var popup_599a4817f4ed081b6b5354c28beabe83 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c46134649bda202713ecbc1ac0d6f6a2 = $(`&lt;div id=&quot;html_c46134649bda202713ecbc1ac0d6f6a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;PINE RIVER SHARES&lt;/strong&gt;&lt;br&gt;     658 S East St&lt;br&gt;     Bayfield, CO 81122&lt;br&gt;     Phone: (970) 884-6040&lt;br&gt;     Website: http://pinerivershares.org&lt;br&gt;     Services: Provides food for community members in need of assistance. Also offers a backpack of food for students attending the following schools to take home every weekend: Bayfield Elementary School Bayfield Primary SchoolIgnacio Elementary Schoo...     &lt;/div&gt;`)[0];
#                 popup_599a4817f4ed081b6b5354c28beabe83.setContent(html_c46134649bda202713ecbc1ac0d6f6a2);
#
#
#
#         marker_e1d3699dce44ced082be031487d9e236.bindPopup(popup_599a4817f4ed081b6b5354c28beabe83)
#         ;
#
#
#
#
#             var marker_a26a14854090469a275eabff0c444bda = L.marker(
#                 [37.2678233, -107.0117959],
#                 {}
#             ).addTo(map_d5694f2ce48dcaa642424bd6c6fde092);
#
#
#         var popup_e6abc8985660c63b00980ddc7a5c2828 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f746b3ae317966dc783f22dfee910401 = $(`&lt;div id=&quot;html_f746b3ae317966dc783f22dfee910401&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SPRINGS&lt;/strong&gt;&lt;br&gt;     434 Lewis St&lt;br&gt;     Pagosa Springs, CO 81147&lt;br&gt;     Phone: (970) 264-5508&lt;br&gt;     Website: http://cumcps.org&lt;br&gt;     Services: Provides food to individuals and families in Archuleta County who are in need. Services limited to one time a week per individual.     &lt;/div&gt;`)[0];
#                 popup_e6abc8985660c63b00980ddc7a5c2828.setContent(html_f746b3ae317966dc783f22dfee910401);
#
#
#
#         marker_a26a14854090469a275eabff0c444bda.bindPopup(popup_e6abc8985660c63b00980ddc7a5c2828)
#         ;
#
#
#
#
#             var marker_38d159cb6f2f1b80d77b4a1b27a27356 = L.marker(
#                 [37.2580963, -107.0750371],
#                 {}
#             ).addTo(map_d5694f2ce48dcaa642424bd6c6fde092);
#
#
#         var popup_551ba6f2b358648c8e4f48b30480a3b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_605533de88d41a4ef38ab05531b8bd17 = $(`&lt;div id=&quot;html_605533de88d41a4ef38ab05531b8bd17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;RESTORATION FELLOWSHIP&lt;/strong&gt;&lt;br&gt;     264 Village Dr&lt;br&gt;     Pagosa Springs, CO

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for food pantries in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b4ecd222ea5ad9744e695fb5cffbb26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b4ecd222ea5ad9744e695fb5cffbb26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b4ecd222ea5ad9744e695fb5cffbb26 = L.map(
#                 &quot;map_5b4ecd222ea5ad9744e695fb5cffbb26&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bab95f173caa137c4a19ec9f63047ad0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bab95f173caa137c4a19ec9f63047ad0.addTo(map_5b4ecd222ea5ad9744e695fb5cffbb26);
#
#
#             var marker_76c2aa7a2cdf4bbe421529cec607bc17 = L.marker(
#                 [39.7446234, -104.9730507],
#                 {}
#             ).addTo(map_5b4ecd222ea5ad9744e695fb5cffbb26);
#
#
#         var popup_624d49a04b3a88166f496e6edc0f1842 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0769f1cae8920e5ba6c13d5d5b7f325 = $(`&lt;div id=&quot;html_c0769f1cae8920e5ba6c13d5d5b7f325&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;METRO CARING&lt;/strong&gt;&lt;br&gt;     1100 E 18th Ave&lt;br&gt;     Denver, CO 80218&lt;br&gt;     Phone: Monday, Thursday, 9 a.m. - 11:30 a.m. - 12:30 p.m...&lt;br&gt;     Website: (303) 860-7200&lt;br&gt;     Services: Provides a fresh food market where the community can choose from an array of nutritious foods,     &lt;/div&gt;`)[0];
#                 popup_624d49a04b3a88166f496e6edc0f1842.setContent(html_c0769f1cae8920e5ba6c13d5d5b7f325);
#
#
#
#         marker_76c2aa7a2cdf4bbe421529cec607bc17.bindPopup(popup_624d49a04b3a88166f496e6edc0f1842)
#         ;
#
#
#
#
#             var marker_7765c97077bbb5a5f77401a1ae916a8c = L.marker(
#                 [39.6614613, -104.9122488],
#                 {}
#             ).addTo(map_5b4ecd222ea5ad9744e695fb5cffbb26);
#
#
#         var popup_1118d2e8846d7a3b1928317d42c779bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_647dbdf8ddba0b72bb0504ba569eeff1 = $(`&lt;div id=&quot;html_647dbdf8ddba0b72bb0504ba569eeff1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     3060 S Monaco St Pkwy&lt;br&gt;     Denver, CO 80222&lt;br&gt;     Phone: (303) 375-5853&lt;br&gt;     Website: http://foodbankrockies.org&lt;br&gt;     Services: Provides food to communities by sending semi-trucks to set locations and distributing food for 1-2 hours.     &lt;/div&gt;`)[0];
#                 popup_1118d2e8846d7a3b1928317d42c779bc.setContent(html_647dbdf8ddba0b72bb0504ba569eeff1);
#
#
#
#         marker_7765c97077bbb5a5f77401a1ae916a8c.bindPopup(popup_1118d2e8846d7a3b1928317d42c779bc)
#         ;
#
#
#
#
#             var marker_a815841eeb42b326b422213d7f6d5cb8 = L.marker(
#                 [39.7260565, -105.0501581],
#                 {}
#             ).addTo(map_5b4ecd222ea5ad9744e695fb5cffbb26);
#
#
#         var popup_d293d2b29a3246fda9d14f3d7220ca01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d02f6eafaf1bd097e03b890b1a4ebab = $(`&lt;div id=&quot;html_4d02f6eafaf1bd097e03b890b1a4ebab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     13300 W 6th Ave&lt;br&gt;     Denver, CO 80215&lt;br&gt;     Phone: (303) 375-5853&lt;br&gt;     Website: http://foodbankrockies.org&lt;br&gt;     Services: Provides food to communities by sending semi-trucks to set locations and distributing food for 1-2 hours.     &lt;/div&gt;`)[0];
#                 popup_d293d2b29a3246fda9d14f3d7220ca01.setContent(html_4d02f6eafaf1bd097e03b890b1a4ebab);
#
#
#
#         marker_a815841eeb42b326b422213d7f6d5cb8.bindPopup(popup_d293d2b29a3246fda9d14f3d7220ca01)
#         ;
#
#
#
#
#             var marker_84271781d8bea7da5def516f939da647 = L.marker(
#                 [39.6851808, -105.0160784],
#                 {}
#             ).addTo(map_5b4ecd222ea5ad9744e695fb5cffbb26);
#
#
#         var popup_7a4bb6739db1e0e380dfca4320ea4e8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb58211f9e73413fd397c44ba337fcff = $(`&lt;div id=&quot;html_cb58211f9e73413fd397c44ba337fcff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY MINISTRY&lt;/strong&gt;&lt;br&gt;     1755 S Zuni St&lt;br&gt;     Denver, CO 80219&lt;br&gt;     Phone: (303) 935-3428&lt;br&gt;     Website: http://comministry-denver.org&lt;br&gt;     Services: Provides emergency food for families

# %%
# Example: Search for food pantries in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_colorado_springs.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da0d26665a1ffed164a1d07aa5c4ecad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da0d26665a1ffed164a1d07aa5c4ecad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da0d26665a1ffed164a1d07aa5c4ecad = L.map(
#                 &quot;map_da0d26665a1ffed164a1d07aa5c4ecad&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_851b1a0d15feb431a53ad73b6bf9469b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_851b1a0d15feb431a53ad73b6bf9469b.addTo(map_da0d26665a1ffed164a1d07aa5c4ecad);
#
#
#             var marker_dbc29bd25f9c1ee36e8d4b87a1286b68 = L.marker(
#                 [38.745604, -104.738987],
#                 {}
#             ).addTo(map_da0d26665a1ffed164a1d07aa5c4ecad);
#
#
#         var popup_cbba21625679de4a7d801cd4ec1c39a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a40f30ce390202f3ef020dcf7cb1f3fd = $(`&lt;div id=&quot;html_a40f30ce390202f3ef020dcf7cb1f3fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CONNECTIONS 4 LIFE&lt;/strong&gt;&lt;br&gt;     6436 S U.S. Hwy 85/87 Unit U&lt;br&gt;     Colorado Springs, CO 80911&lt;br&gt;     Phone: (719) 387-9919&lt;br&gt;     Website: http://connections4lifecenter.org&lt;br&gt;     Services: Provides a food pantry to residents in need.     &lt;/div&gt;`)[0];
#                 popup_cbba21625679de4a7d801cd4ec1c39a7.setContent(html_a40f30ce390202f3ef020dcf7cb1f3fd);
#
#
#
#         marker_dbc29bd25f9c1ee36e8d4b87a1286b68.bindPopup(popup_cbba21625679de4a7d801cd4ec1c39a7)
#         ;
#
#
#
#
#             var marker_bab96e675214fce473baa23fec5a3eba = L.marker(
#                 [38.7360794, -104.7271127],
#                 {}
#             ).addTo(map_da0d26665a1ffed164a1d07aa5c4ecad);
#
#
#         var popup_362b30f830d9d15a347c0036cf25e09c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32a3d3f361ddc7e43902d2b63dc8d002 = $(`&lt;div id=&quot;html_32a3d3f361ddc7e43902d2b63dc8d002&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GOD&#x27;S PANTRY MINISTRY&lt;/strong&gt;&lt;br&gt;     30 Widefield Blvd&lt;br&gt;     Colorado Springs, CO 80911&lt;br&gt;     Phone: (719) 382-0643&lt;br&gt;     Website: http://godspantryco.org&lt;br&gt;     Services: Provides a food pantry.     &lt;/div&gt;`)[0];
#                 popup_362b30f830d9d15a347c0036cf25e09c.setContent(html_32a3d3f361ddc7e43902d2b63dc8d002);
#
#
#
#         marker_bab96e675214fce473baa23fec5a3eba.bindPopup(popup_362b30f830d9d15a347c0036cf25e09c)
#         ;
#
#
#
#
#             var marker_e9eaa62a9a9cada26d8b37eab966a166 = L.marker(
#                 [38.7845737, -104.7478808],
#                 {}
#             ).addTo(map_da0d26665a1ffed164a1d07aa5c4ecad);
#
#
#         var popup_819897944eb15ce58725600982619acd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af2c544cd58375dd33b5da149062c053 = $(`&lt;div id=&quot;html_af2c544cd58375dd33b5da149062c053&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CITY OF COLORADO SPRINGS&lt;/strong&gt;&lt;br&gt;     4290 Deerfield Hills Rd&lt;br&gt;     Colorado Springs, CO 80916&lt;br&gt;     Phone: (719) 385-5996&lt;br&gt;     Website: http://coloradosprings.gov/deeraeld-hills-community-center&lt;br&gt;     Services: Provides a drive-thru style food pantry to those in need.     &lt;/div&gt;`)[0];
#                 popup_819897944eb15ce58725600982619acd.setContent(html_af2c544cd58375dd33b5da149062c053);
#
#
#
#         marker_e9eaa62a9a9cada26d8b37eab966a166.bindPopup(popup_819897944eb15ce58725600982619acd)
#         ;
#
#
#
#
#             var marker_ae6790f133930f7230171232f2350a19 = L.marker(
#                 [38.8649785, -104.815912],
#                 {}
#             ).addTo(map_da0d26665a1ffed164a1d07aa5c4ecad);
#
#
#         var popup_745f7e09ec5bb6f98ac5af62fe50235f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8783e7460048f239b633399dba89e6a7 = $(`&lt;div id=&quot;html_8783e7460048f239b633399dba89e6a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FISHES AND LOAVES&lt;/strong&gt;&lt;br&gt;     2221 N Wahsatch Ave&lt;br&gt;     Colorado Springs, CO 80907&lt;br&gt;     Phone: (720) 373-9760&lt;br&gt;     Website: No Website Listed&lt;br&gt;     Services: Provides a food pantry to those in need living in Colorado Springs.     &lt;/div&gt;`)[0];
#                 popup_745f7e09ec5bb6f98ac5af62fe50235f.setCont

# %%
# Example: Search for food pantries in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcdda5b2aaa2200ceb36db659efc8ce6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcdda5b2aaa2200ceb36db659efc8ce6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcdda5b2aaa2200ceb36db659efc8ce6 = L.map(
#                 &quot;map_dcdda5b2aaa2200ceb36db659efc8ce6&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bbdc01c05b83c07ecbba6a80dc2a71a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bbdc01c05b83c07ecbba6a80dc2a71a1.addTo(map_dcdda5b2aaa2200ceb36db659efc8ce6);
#
#
#             var marker_728712ce4bbf057e0b4ee4eab1306d5f = L.marker(
#                 [39.6746072, -104.7782004],
#                 {}
#             ).addTo(map_dcdda5b2aaa2200ceb36db659efc8ce6);
#
#
#         var popup_920600f0c56e0dc19db0543b482b50a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_449506e1dccbcf767ff6d0f60475f417 = $(`&lt;div id=&quot;html_449506e1dccbcf767ff6d0f60475f417&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NEW LIFE COMMUNITY CHURCH&lt;/strong&gt;&lt;br&gt;     17690 E Iliff Ave&lt;br&gt;     Aurora, CO 80013&lt;br&gt;     Phone: (303) 368-7567&lt;br&gt;     Website: http://nlccaurora.org&lt;br&gt;     Services: Provides bags of food to the community. The pantry may be visited on a monthly or bi-monthly basis.     &lt;/div&gt;`)[0];
#                 popup_920600f0c56e0dc19db0543b482b50a8.setContent(html_449506e1dccbcf767ff6d0f60475f417);
#
#
#
#         marker_728712ce4bbf057e0b4ee4eab1306d5f.bindPopup(popup_920600f0c56e0dc19db0543b482b50a8)
#         ;
#
#
#
#
#             var marker_5af039121a7a66b66dd97d099e957e9b = L.marker(
#                 [39.6961142, -104.8550663],
#                 {}
#             ).addTo(map_dcdda5b2aaa2200ceb36db659efc8ce6);
#
#
#         var popup_05a7e8642621efc25649b6b8a1533765 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0459e8e8cd59b98d43232766e2321ef0 = $(`&lt;div id=&quot;html_0459e8e8cd59b98d43232766e2321ef0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AURORA FIRST SEVENTH DAY ADVENTIST CHURCH&lt;/strong&gt;&lt;br&gt;     11400 E Mississippi Ave&lt;br&gt;     Aurora, CO 80012&lt;br&gt;     Phone: (303) 755-1617&lt;br&gt;     Website: http://auroraarstco.adventistchurch.org&lt;br&gt;     Services: Provides a food and clothing bank for the community.     &lt;/div&gt;`)[0];
#                 popup_05a7e8642621efc25649b6b8a1533765.setContent(html_0459e8e8cd59b98d43232766e2321ef0);
#
#
#
#         marker_5af039121a7a66b66dd97d099e957e9b.bindPopup(popup_05a7e8642621efc25649b6b8a1533765)
#         ;
#
#
#
#
#             var marker_9889cfdea285de138bd4307590d162ba = L.marker(
#                 [39.742282, -104.8661782],
#                 {}
#             ).addTo(map_dcdda5b2aaa2200ceb36db659efc8ce6);
#
#
#         var popup_50c369971b4a854817e67975c2ca221c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26c32d2cfeba96ff603035f7802412d4 = $(`&lt;div id=&quot;html_26c32d2cfeba96ff603035f7802412d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;VILLAGE EXCHANGE CENTER&lt;/strong&gt;&lt;br&gt;     1609 Havana St&lt;br&gt;     Aurora, CO 80010&lt;br&gt;     Phone: (720) 668-9968&lt;br&gt;     Website: http://villageexchangecenter.org/programs/village-pantry/&lt;br&gt;     Services: Provides individuals and families with culturally relevant food and personal hygiene items, including: Fresh produce Meals Diapers Toiletries     &lt;/div&gt;`)[0];
#                 popup_50c369971b4a854817e67975c2ca221c.setContent(html_26c32d2cfeba96ff603035f7802412d4);
#
#
#
#         marker_9889cfdea285de138bd4307590d162ba.bindPopup(popup_50c369971b4a854817e67975c2ca221c)
#         ;
#
#
#
#
#             var marker_514e9242de2e0b92d2ea94a444412442 = L.marker(
#                 [39.6810838, -104.826839],
#                 {}
#             ).addTo(map_dcdda5b2aaa2200ceb36db659efc8ce6);
#
#
#         var popup_58521db517f5908e51eeb983c66c76bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e3e0a05f2137195ed0e8ebef2de2620 = $(`&lt;div id=&quot;html_7e3e0a05f2137195ed0e8ebef2de2620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     14000 E Jewell Ave&lt;br&gt;     Aurora, CO 80012&lt;br&gt;     Phone: (303) 375-5853&lt;br&gt;     Website: http://foodbankrockies.org&lt;br&gt;     Services:

# %%
# Example: Search for food pantries in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_fort_collins.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41ef45e768863bcb4765b5b8bf8ba0aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41ef45e768863bcb4765b5b8bf8ba0aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41ef45e768863bcb4765b5b8bf8ba0aa = L.map(
#                 &quot;map_41ef45e768863bcb4765b5b8bf8ba0aa&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67751d0d964b64d7086dc6ffdb86aaae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_67751d0d964b64d7086dc6ffdb86aaae.addTo(map_41ef45e768863bcb4765b5b8bf8ba0aa);
#
#
#             var marker_3cf1442484eace2b6036f759f3195b51 = L.marker(
#                 [40.5872724, -105.1219739],
#                 {}
#             ).addTo(map_41ef45e768863bcb4765b5b8bf8ba0aa);
#
#
#         var popup_35cb3cb0d60d7ca828c34b23e30c3c2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c6f00c2a01926514d029020ed91dce8 = $(`&lt;div id=&quot;html_9c6f00c2a01926514d029020ed91dce8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK FOR LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     201 S Impala Dr&lt;br&gt;     Fort Collins, CO 80521&lt;br&gt;     Phone: (970) 493-4477&lt;br&gt;     Website: http://foodbanklarimer.org/mobiles&lt;br&gt;     Services: Offers a drive-through mobile food pantry for those in need.     &lt;/div&gt;`)[0];
#                 popup_35cb3cb0d60d7ca828c34b23e30c3c2c.setContent(html_9c6f00c2a01926514d029020ed91dce8);
#
#
#
#         marker_3cf1442484eace2b6036f759f3195b51.bindPopup(popup_35cb3cb0d60d7ca828c34b23e30c3c2c)
#         ;
#
#
#
#
#             var marker_3320a14e21910d67b40a90661664e654 = L.marker(
#                 [40.6047193, -105.0725555],
#                 {}
#             ).addTo(map_41ef45e768863bcb4765b5b8bf8ba0aa);
#
#
#         var popup_33aa2fbe9053d06c277f795bd11663b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_254cabec3bbed3c85e46cca4e9a10196 = $(`&lt;div id=&quot;html_254cabec3bbed3c85e46cca4e9a10196&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK FOR LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     1301 Blue Spruce Dr&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Phone: (970) 493-4477&lt;br&gt;     Website: http://foodbanklarimer.org/our-programs&lt;br&gt;     Services: Provides a client choice food pantry for individuals in need. Also distributes the Commodities Supplemental Food Program (CSFP) to eligible seniors and The Emergency Food Assistance Program (TFAP)...     &lt;/div&gt;`)[0];
#                 popup_33aa2fbe9053d06c277f795bd11663b3.setContent(html_254cabec3bbed3c85e46cca4e9a10196);
#
#
#
#         marker_3320a14e21910d67b40a90661664e654.bindPopup(popup_33aa2fbe9053d06c277f795bd11663b3)
#         ;
#
#
#
#
#             var marker_f56807435b85aa71e710fc68c36c94b0 = L.marker(
#                 [40.533596, -105.0800634],
#                 {}
#             ).addTo(map_41ef45e768863bcb4765b5b8bf8ba0aa);
#
#
#         var popup_f83f850060b5929b8bf330ccb427d954 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf3cacf275d67d1f60d1395febf48ff2 = $(`&lt;div id=&quot;html_bf3cacf275d67d1f60d1395febf48ff2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SALVATION ARMY FORT COLLINS&lt;/strong&gt;&lt;br&gt;     3901 S Mason St&lt;br&gt;     Fort Collins, CO 80525&lt;br&gt;     Phone: (970) 207-4472 Ext 201&lt;br&gt;     Website: http://fortcollins.salvationarmy.org/fort_collins_corps/overcome-poverty&lt;br&gt;     Services: Provides food boxes and clothing for individuals in need. When available, also provides: Hygiene items Diapers and wipes Pet food Period kits     &lt;/div&gt;`)[0];
#                 popup_f83f850060b5929b8bf330ccb427d954.setContent(html_bf3cacf275d67d1f60d1395febf48ff2);
#
#
#
#         marker_f56807435b85aa71e710fc68c36c94b0.bindPopup(popup_f83f850060b5929b8bf330ccb427d954)
#         ;
#
#
#
#
#             var marker_6daa09c9566ea66956b6f560328e1faa = L.marker(
#                 [40.5739532, -105.0735276],
#                 {}
#             ).addTo(map_41ef45e768863bcb4765b5b8bf8ba0aa);
#
#
#         var popup_6192c9560796020e2d9cbb486aae82d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aaceb828efc4fa1d24e43383c0f1d2ac = $(`&lt;div id=&quot;html_aaceb828efc4fa1d24e43383c0f1d2ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SAINT JOHN&#x27;S LUTHERAN CHURCH&lt;/strong&gt;&lt;br&gt;

# %%
# Example: Search for food pantries in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_lakewood.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d9186a4e22827e098f0d3462f5632f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d9186a4e22827e098f0d3462f5632f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d9186a4e22827e098f0d3462f5632f5 = L.map(
#                 &quot;map_9d9186a4e22827e098f0d3462f5632f5&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ed8d6565e24ebbcac0e0130c269f9fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1ed8d6565e24ebbcac0e0130c269f9fa.addTo(map_9d9186a4e22827e098f0d3462f5632f5);
#
#
#             var marker_f78c1c676ff8fd1fab9c9c8a6b4437fc = L.marker(
#                 [39.6907746, -105.0714054],
#                 {}
#             ).addTo(map_9d9186a4e22827e098f0d3462f5632f5);
#
#
#         var popup_292e220de8c72c99f4b8d1a0da42b702 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06eb195ee700da9615cae6c224bf7564 = $(`&lt;div id=&quot;html_06eb195ee700da9615cae6c224bf7564&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     1450 S Pierce St&lt;br&gt;     Lakewood, CO 80232&lt;br&gt;     Phone: 1st Tuesday, 3 p.m. (While Supplies Last)&lt;br&gt;     Website: (303) 375-5853&lt;br&gt;     Services: Provides food to communities by sending semi-trucks to set locations and distributing food for 1-2 hours.     &lt;/div&gt;`)[0];
#                 popup_292e220de8c72c99f4b8d1a0da42b702.setContent(html_06eb195ee700da9615cae6c224bf7564);
#
#
#
#         marker_f78c1c676ff8fd1fab9c9c8a6b4437fc.bindPopup(popup_292e220de8c72c99f4b8d1a0da42b702)
#         ;
#
#
#
#
#             var marker_79635f2fe2fecb269933998cbf743d20 = L.marker(
#                 [39.7385136, -105.094918],
#                 {}
#             ).addTo(map_9d9186a4e22827e098f0d3462f5632f5);
#
#
#         var popup_fcb8d03e22b3dcf65627126d5da665e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_191303a524233a04c90f8faf91124427 = $(`&lt;div id=&quot;html_191303a524233a04c90f8faf91124427&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ACTION CENTER&lt;/strong&gt;&lt;br&gt;     8745 W 14th Ave&lt;br&gt;     Lakewood, CO 80215&lt;br&gt;     Phone: (303) 237-7704&lt;br&gt;     Website: http://theactioncenter.org&lt;br&gt;     Services: Offers a community food pantry that individuals can utilize once a month. Groceries vary by day, but typically include non-perishable and perishable food items such as: Fresh vegetables Fruits Dairy Proteins Emergency diapers and personal hygiene items may...     &lt;/div&gt;`)[0];
#                 popup_fcb8d03e22b3dcf65627126d5da665e8.setContent(html_191303a524233a04c90f8faf91124427);
#
#
#
#         marker_79635f2fe2fecb269933998cbf743d20.bindPopup(popup_fcb8d03e22b3dcf65627126d5da665e8)
#         ;
#
#
#
#
#             var marker_c9c62841058fbb7705558f0b03c2e23f = L.marker(
#                 [39.7271071, -105.0816301],
#                 {}
#             ).addTo(map_9d9186a4e22827e098f0d3462f5632f5);
#
#
#         var popup_00a01b27685a314703eda67c3c29736b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1f5ac57358e36dfc395b8cd754e2465 = $(`&lt;div id=&quot;html_e1f5ac57358e36dfc395b8cd754e2465&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CAT CARE SOCIETY&lt;/strong&gt;&lt;br&gt;     5787 W 6th Ave&lt;br&gt;     Lakewood, CO 80214&lt;br&gt;     Phone: (303) 239-9680&lt;br&gt;     Website: http://catcaresociety.org/programs/#nibbles-kibbles&lt;br&gt;     Services: Offers cat food and supplies to individuals who are experiencing temporary financial challenges.     &lt;/div&gt;`)[0];
#                 popup_00a01b27685a314703eda67c3c29736b.setContent(html_e1f5ac57358e36dfc395b8cd754e2465);
#
#
#
#         marker_c9c62841058fbb7705558f0b03c2e23f.bindPopup(popup_00a01b27685a314703eda67c3c29736b)
#         ;
#
#
#
#
#             var marker_4983809ee8b8bd9fa976c00d9173cdea = L.marker(
#                 [39.7110864, -105.060541],
#                 {}
#             ).addTo(map_9d9186a4e22827e098f0d3462f5632f5);
#
#
#         var popup_46d2ca1f498e2e17b9e9b3d7720062a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a8e0f09886b7f7499382a94fb2f8925 = $(`&lt;div id=&quot;html_7a8e0f09886b7f7499382a94fb2f8925&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     5810 W Alameda Ave&lt;br&gt;

# %%
# Example: Search for food pantries in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_arvada.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df558a651187321c828cef74c45a45de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df558a651187321c828cef74c45a45de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df558a651187321c828cef74c45a45de = L.map(
#                 &quot;map_df558a651187321c828cef74c45a45de&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d45de892373a6d5e39c2ed7185900364 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d45de892373a6d5e39c2ed7185900364.addTo(map_df558a651187321c828cef74c45a45de);
#
#
#             var marker_d7bd5851d7fdd633a8b36af9c0229f50 = L.marker(
#                 [39.800294, -105.0928581],
#                 {}
#             ).addTo(map_df558a651187321c828cef74c45a45de);
#
#
#         var popup_4eb6ffc75b6bd04c7a52f45a6f71a211 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35c42e922cc3db2f279cbc4a7866facc = $(`&lt;div id=&quot;html_35c42e922cc3db2f279cbc4a7866facc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY TABLE&lt;/strong&gt;&lt;br&gt;     8555 W 57th Ave&lt;br&gt;     Arvada, CO 80002&lt;br&gt;     Phone: (303) 424-6685&lt;br&gt;     Website: http://cotable.org&lt;br&gt;     Services: Provides emergency food to individuals and families. Each client selects a supply of food based on household size. Families and individuals may use this program when needed...     &lt;/div&gt;`)[0];
#                 popup_4eb6ffc75b6bd04c7a52f45a6f71a211.setContent(html_35c42e922cc3db2f279cbc4a7866facc);
#
#
#
#         marker_d7bd5851d7fdd633a8b36af9c0229f50.bindPopup(popup_4eb6ffc75b6bd04c7a52f45a6f71a211)
#         ;
#
#
#
#
#             var marker_0ab183183ca081fc927a0f8940d848e9 = L.marker(
#                 [39.8054671, -105.0622284],
#                 {}
#             ).addTo(map_df558a651187321c828cef74c45a45de);
#
#
#         var popup_e4eeffa0f24cffd0c4bec17e30f3f11d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f94c2d181475265abe0aa2ac32078866 = $(`&lt;div id=&quot;html_f94c2d181475265abe0aa2ac32078866&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AGAPE LIFE CHURCH&lt;/strong&gt;&lt;br&gt;     5970 W 60th Ave&lt;br&gt;     Arvada, CO 80003&lt;br&gt;     Phone: (303) 431-6481&lt;br&gt;     Website: http://agapelife.org/food-outreach/&lt;br&gt;     Services: Provides a food pantry and hosts a monthly TEFAP (The Emergency Food Assistance Program) food distribution site.     &lt;/div&gt;`)[0];
#                 popup_e4eeffa0f24cffd0c4bec17e30f3f11d.setContent(html_f94c2d181475265abe0aa2ac32078866);
#
#
#
#         marker_0ab183183ca081fc927a0f8940d848e9.bindPopup(popup_e4eeffa0f24cffd0c4bec17e30f3f11d)
#         ;
#
#
#
#
#             tile_layer_d45de892373a6d5e39c2ed7185900364.addTo(map_df558a651187321c828cef74c45a45de);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for food pantries in a specific city
city_search = "Greeley"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_greeley.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81e462a25d75f2560a4524d060fd6705 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81e462a25d75f2560a4524d060fd6705&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81e462a25d75f2560a4524d060fd6705 = L.map(
#                 &quot;map_81e462a25d75f2560a4524d060fd6705&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6fd97b40343b267d796b988a6e372558 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6fd97b40343b267d796b988a6e372558.addTo(map_81e462a25d75f2560a4524d060fd6705);
#
#
#             var marker_370165bb8366094e509a1f22b65a199e = L.marker(
#                 [40.4437132, -104.6987994],
#                 {}
#             ).addTo(map_81e462a25d75f2560a4524d060fd6705);
#
#
#         var popup_4ea991e7a878be911bc0acb4c5896ae7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8cdd9b631244cd0f6a542056ac6d1b6c = $(`&lt;div id=&quot;html_8cdd9b631244cd0f6a542056ac6d1b6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WELD FOOD BANK&lt;/strong&gt;&lt;br&gt;     1108 H St&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 356-2199&lt;br&gt;     Website: http://weldfoodbank.org/emergency-food-program/&lt;br&gt;     Services: Provides a box of basic food staples to qualified families or individuals in crisis. Individuals can receive a food box on an emergency basis, not more than once per week...     &lt;/div&gt;`)[0];
#                 popup_4ea991e7a878be911bc0acb4c5896ae7.setContent(html_8cdd9b631244cd0f6a542056ac6d1b6c);
#
#
#
#         marker_370165bb8366094e509a1f22b65a199e.bindPopup(popup_4ea991e7a878be911bc0acb4c5896ae7)
#         ;
#
#
#
#
#             var marker_1eb7ddef1832a0c0a591d1a81e9db1ad = L.marker(
#                 [40.4437132, -104.6987994],
#                 {}
#             ).addTo(map_81e462a25d75f2560a4524d060fd6705);
#
#
#         var popup_323ea0043e63c5a860a4f2d4bb579363 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a335805a679ea990243052134a90d31 = $(`&lt;div id=&quot;html_3a335805a679ea990243052134a90d31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WELD FOOD BANK&lt;/strong&gt;&lt;br&gt;     1108 H St&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 356-2199&lt;br&gt;     Website: http://weldfoodbank.org/and-food-near-you&lt;br&gt;     Services: Offers mobile food pantries at locations throughout Weld County.     &lt;/div&gt;`)[0];
#                 popup_323ea0043e63c5a860a4f2d4bb579363.setContent(html_3a335805a679ea990243052134a90d31);
#
#
#
#         marker_1eb7ddef1832a0c0a591d1a81e9db1ad.bindPopup(popup_323ea0043e63c5a860a4f2d4bb579363)
#         ;
#
#
#
#
#             var marker_ecd5e2961c70db235a9d7a01cd18e412 = L.marker(
#                 [40.4437132, -104.6987994],
#                 {}
#             ).addTo(map_81e462a25d75f2560a4524d060fd6705);
#
#
#         var popup_43a4fbf6ed8c78ef1b1799cd2a77bf8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53ef1405edd2e4bb658e146425d35cb9 = $(`&lt;div id=&quot;html_53ef1405edd2e4bb658e146425d35cb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WELD FOOD BANK&lt;/strong&gt;&lt;br&gt;     1108 H Street&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 356-2199&lt;br&gt;     Website: http://weldfoodbank.org/and-food-near-you&lt;br&gt;     Services: Offers mobile food pantries at locations throughout Weld County.     &lt;/div&gt;`)[0];
#                 popup_43a4fbf6ed8c78ef1b1799cd2a77bf8b.setContent(html_53ef1405edd2e4bb658e146425d35cb9);
#
#
#
#         marker_ecd5e2961c70db235a9d7a01cd18e412.bindPopup(popup_43a4fbf6ed8c78ef1b1799cd2a77bf8b)
#         ;
#
#
#
#
#             var marker_9d679fdc5b21f4debdff3569670f305d = L.marker(
#                 [40.4209079, -104.6925472],
#                 {}
#             ).addTo(map_81e462a25d75f2560a4524d060fd6705);
#
#
#         var popup_929081410d8ee3efb82e062fa0e3438b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7354b9f5c4f506f1be07755b6b52ae88 = $(`&lt;div id=&quot;html_7354b9f5c4f506f1be07755b6b52ae88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ST PETER ROMAN CATHOLIC CHURCH&lt;/strong&gt;&lt;br&gt;     1112 9th Ave&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 352-1060&lt;br&gt;     Website: http://stpetergreeley.org&lt;br&gt;     Services: Provides emergency food to individuals in n

# %%
# Example: Search for food pantries in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_pueblo.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25487033ec5c1344fe7a295df5621a3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25487033ec5c1344fe7a295df5621a3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25487033ec5c1344fe7a295df5621a3f = L.map(
#                 &quot;map_25487033ec5c1344fe7a295df5621a3f&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c51b1057c4d914bf1dc23d9e18291d32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c51b1057c4d914bf1dc23d9e18291d32.addTo(map_25487033ec5c1344fe7a295df5621a3f);
#
#
#             var marker_7cbfe367641c1557c9b75d0c59b871cc = L.marker(
#                 [38.274091, -104.6197],
#                 {}
#             ).addTo(map_25487033ec5c1344fe7a295df5621a3f);
#
#
#         var popup_f381de886c4d67225ceae334582f1d14 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ee2fb5d177f3e4c0b10660b34bd114f = $(`&lt;div id=&quot;html_7ee2fb5d177f3e4c0b10660b34bd114f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CENTER TOWARD SELF-RELIANCE&lt;/strong&gt;&lt;br&gt;     901 W 8th St&lt;br&gt;     Pueblo, CO 81003&lt;br&gt;     Phone: (719) 546-1271&lt;br&gt;     Website: https://cfdpueblo.org&lt;br&gt;     Services: Food Pantry provides food assistance to low-income individuals who are in need     &lt;/div&gt;`)[0];
#                 popup_f381de886c4d67225ceae334582f1d14.setContent(html_7ee2fb5d177f3e4c0b10660b34bd114f);
#
#
#
#         marker_7cbfe367641c1557c9b75d0c59b871cc.bindPopup(popup_f381de886c4d67225ceae334582f1d14)
#         ;
#
#
#
#
#             var marker_f4ddf2d1dca78257e8e2392bb9d8c6b1 = L.marker(
#                 [38.2631861, -104.6371719],
#                 {}
#             ).addTo(map_25487033ec5c1344fe7a295df5621a3f);
#
#
#         var popup_09d7edbdfa0cf9dd0889b9d90f9457c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_337323965d30c58506431af5bb1c5148 = $(`&lt;div id=&quot;html_337323965d30c58506431af5bb1c5148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/strong&gt;&lt;br&gt;     900 W Orman Ave&lt;br&gt;     Pueblo, CO 81004&lt;br&gt;     Phone: (719) 296-6995&lt;br&gt;     Website: https://careandshare.org&lt;br&gt;     Services: Food Pantry providing food to those in need.     &lt;/div&gt;`)[0];
#                 popup_09d7edbdfa0cf9dd0889b9d90f9457c5.setContent(html_337323965d30c58506431af5bb1c5148);
#
#
#
#         marker_f4ddf2d1dca78257e8e2392bb9d8c6b1.bindPopup(popup_09d7edbdfa0cf9dd0889b9d90f9457c5)
#         ;
#
#
#
#
#             var marker_63d60361dabf10fdcf5d83bfba2b1ee5 = L.marker(
#                 [38.327273, -104.77256],
#                 {}
#             ).addTo(map_25487033ec5c1344fe7a295df5621a3f);
#
#
#         var popup_a962682ff173b37b9a778b01d4ee87eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eecd02ea360e8c760716bc3c8fd69b4e = $(`&lt;div id=&quot;html_eecd02ea360e8c760716bc3c8fd69b4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/strong&gt;&lt;br&gt;     434 S Conquistador Ave&lt;br&gt;     Pueblo West, CO 81007&lt;br&gt;     Phone: (719) 547-3088&lt;br&gt;     Website: No Website Listed&lt;br&gt;     Services: Food Pantry providing food to those in need.     &lt;/div&gt;`)[0];
#                 popup_a962682ff173b37b9a778b01d4ee87eb.setContent(html_eecd02ea360e8c760716bc3c8fd69b4e);
#
#
#
#         marker_63d60361dabf10fdcf5d83bfba2b1ee5.bindPopup(popup_a962682ff173b37b9a778b01d4ee87eb)
#         ;
#
#
#
#
#             var marker_8441285254f6cb2dbbeb95a21589321f = L.marker(
#                 [38.2239923, -104.6567669],
#                 {}
#             ).addTo(map_25487033ec5c1344fe7a295df5621a3f);
#
#
#         var popup_1999b7d85f4fee6faa86881496e6c73c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67607e746da27988c84bfe2847dfd85d = $(`&lt;div id=&quot;html_67607e746da27988c84bfe2847dfd85d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/strong&gt;&lt;br&gt;     3804 W Pueblo Blvd&lt;br&gt;     Pueblo, CO 81005&lt;br&gt;     Phone: (719) 564-4434&lt;br&gt;     Website: No Website Listed&lt;br&gt;     Services: Food Pantry providing food to those in need.     &lt;/div&gt;`)[0];
#                 popup_1999b7d85f4fee6faa86881496e6c73c.setContent(html_67607e746da2

# %%
# Example: Search for food pantries in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_boulder.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e3061d84791b84e60ad0a8c5c6ba15a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e3061d84791b84e60ad0a8c5c6ba15a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e3061d84791b84e60ad0a8c5c6ba15a = L.map(
#                 &quot;map_7e3061d84791b84e60ad0a8c5c6ba15a&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bc1304e89c57331565bb8ad43442153 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2bc1304e89c57331565bb8ad43442153.addTo(map_7e3061d84791b84e60ad0a8c5c6ba15a);
#
#
#             var marker_a869b4fa62e4c08750f67cd7950b3d71 = L.marker(
#                 [40.102555, -105.3632079],
#                 {}
#             ).addTo(map_7e3061d84791b84e60ad0a8c5c6ba15a);
#
#
#         var popup_8b5c1f7a8cafc1fa3554a40feb4516a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dffee80014175fa77aa19a1b1e60edba = $(`&lt;div id=&quot;html_dffee80014175fa77aa19a1b1e60edba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COLORADO PET PANTRY&lt;/strong&gt;&lt;br&gt;     P.O. Box 323&lt;br&gt;     Boulder, CO 80306&lt;br&gt;     Phone: (303) 818-0618&lt;br&gt;     Website: http://coloradopetpantry.org/events/category/pet-food-banks/&lt;br&gt;     Services: Provides free temporary pet food through various food pantry organizations throughout Colorado.     &lt;/div&gt;`)[0];
#                 popup_8b5c1f7a8cafc1fa3554a40feb4516a0.setContent(html_dffee80014175fa77aa19a1b1e60edba);
#
#
#
#         marker_a869b4fa62e4c08750f67cd7950b3d71.bindPopup(popup_8b5c1f7a8cafc1fa3554a40feb4516a0)
#         ;
#
#
#
#
#             var marker_dbde293333c0baf79612dab17c408658 = L.marker(
#                 [40.058333, -105.2778705],
#                 {}
#             ).addTo(map_7e3061d84791b84e60ad0a8c5c6ba15a);
#
#
#         var popup_a7d3a3cfbd7146106589ae9a69c6b573 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a9ad533241691edd9b72bc897700f19 = $(`&lt;div id=&quot;html_6a9ad533241691edd9b72bc897700f19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;EMERGENCY FAMILY ASSISTANCE ASSOCIATION&lt;/strong&gt;&lt;br&gt;     1575 Yarmouth Ave&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     Phone: (303) 442-3042&lt;br&gt;     Website: http://efaa.org/get-help/food-bank/&lt;br&gt;     Services: Provides a food pantry to people living in the City of Boulder and Boulder County Mountain Communities with access to a kitchen. Eligible households may visit the food bank twice per month...     &lt;/div&gt;`)[0];
#                 popup_a7d3a3cfbd7146106589ae9a69c6b573.setContent(html_6a9ad533241691edd9b72bc897700f19);
#
#
#
#         marker_dbde293333c0baf79612dab17c408658.bindPopup(popup_a7d3a3cfbd7146106589ae9a69c6b573)
#         ;
#
#
#
#
#             var marker_fad03271ed552113995d1daa53ea3c10 = L.marker(
#                 [39.990138, -105.232704],
#                 {}
#             ).addTo(map_7e3061d84791b84e60ad0a8c5c6ba15a);
#
#
#         var popup_af1ac805ba16939e5d3e2e8ae0ae6d86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6eca287bbd6a8707252ec7fd3971f307 = $(`&lt;div id=&quot;html_6eca287bbd6a8707252ec7fd3971f307&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY FOOD SHARE&lt;/strong&gt;&lt;br&gt;     4990 Osage Dr&lt;br&gt;     Boulder, CO 80303&lt;br&gt;     Phone: (303) 652-3663&lt;br&gt;     Website: http://communityfoodshare.org/get-food/services-we-provide/mobile-pantries/&lt;br&gt;     Services: Operates a mobile food pantry at rotating locations, offering: Fresh produce Dairy Non-perishable pantry items     &lt;/div&gt;`)[0];
#                 popup_af1ac805ba16939e5d3e2e8ae0ae6d86.setContent(html_6eca287bbd6a8707252ec7fd3971f307);
#
#
#
#         marker_fad03271ed552113995d1daa53ea3c10.bindPopup(popup_af1ac805ba16939e5d3e2e8ae0ae6d86)
#         ;
#
#
#
#
#             var marker_7b7685d1d90167045c562ee2c8ceae2f = L.marker(
#                 [40.0625882, -105.282615],
#                 {}
#             ).addTo(map_7e3061d84791b84e60ad0a8c5c6ba15a);
#
#
#         var popup_3c07492bba753f87ba813757cb795fa7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78fcca9b2682bb281b88922d7d8bdf88 = $(`&lt;div id=&quot;html_78fcca9b2682bb281b88922d7d8bdf88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ALL ROADS SHELTER&lt;/strong&gt;&lt;br&gt;     4869 Broadway&lt;br&gt;     Bould

# %%
# Example: Search for food pantries in a specific city
city_search = "Grand Junction"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: {row['Website']}<br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_grand_junction.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_173aeae540b4e879ad6726c3053076df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_173aeae540b4e879ad6726c3053076df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_173aeae540b4e879ad6726c3053076df = L.map(
#                 &quot;map_173aeae540b4e879ad6726c3053076df&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_566dd30b3a67bcdd19f31b31b837437a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_566dd30b3a67bcdd19f31b31b837437a.addTo(map_173aeae540b4e879ad6726c3053076df);
#
#
#             var marker_163ce6ffb2dab80c15da52ef14de89d0 = L.marker(
#                 [39.0655869, -108.5712505],
#                 {}
#             ).addTo(map_173aeae540b4e879ad6726c3053076df);
#
#
#         var popup_6b4ca5b9477571e01b3fdb6339f449a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f5929b7f900a5dc53481a272e8ec5b8 = $(`&lt;div id=&quot;html_6f5929b7f900a5dc53481a272e8ec5b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/strong&gt;&lt;br&gt;     245 S 1st St&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     Phone: (970) 241-3658&lt;br&gt;     Website: http://catholicoutreach.org&lt;br&gt;     Services: Provides food box for Mesa County residents in need on a once-a-month basis. Food type is available depending on donated items available...     &lt;/div&gt;`)[0];
#                 popup_6b4ca5b9477571e01b3fdb6339f449a7.setContent(html_6f5929b7f900a5dc53481a272e8ec5b8);
#
#
#
#         marker_163ce6ffb2dab80c15da52ef14de89d0.bindPopup(popup_6b4ca5b9477571e01b3fdb6339f449a7)
#         ;
#
#
#
#
#             var marker_17a79b434628523b3b60a207ad05143c = L.marker(
#                 [39.0415079, -108.5435434],
#                 {}
#             ).addTo(map_173aeae540b4e879ad6726c3053076df);
#
#
#         var popup_bafcee2657c90f7746bd387952914e7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08a6134ba0ce90b6a78ab03b4e3afb77 = $(`&lt;div id=&quot;html_08a6134ba0ce90b6a78ab03b4e3afb77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ORCHARD MESA BAPTIST CHURCH&lt;/strong&gt;&lt;br&gt;     2748 B 1/2 Rd&lt;br&gt;     Grand Junction, CO 81503&lt;br&gt;     Phone: (970) 242-2355&lt;br&gt;     Website: http://ombcgj.com/&lt;br&gt;     Services: Provides a food box to those in need once a month and up to 3 times per calendar year. Additional assistance can be granted on case by case basis by the food pantry director...     &lt;/div&gt;`)[0];
#                 popup_bafcee2657c90f7746bd387952914e7d.setContent(html_08a6134ba0ce90b6a78ab03b4e3afb77);
#
#
#
#         marker_17a79b434628523b3b60a207ad05143c.bindPopup(popup_bafcee2657c90f7746bd387952914e7d)
#         ;
#
#
#
#
#             var marker_aacf892cb762c6605e48611f65c013e5 = L.marker(
#                 [39.0842939, -108.5210788],
#                 {}
#             ).addTo(map_173aeae540b4e879ad6726c3053076df);
#
#
#         var popup_b1ce60adb4a6e28f6ac1c0aa15d79111 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1f051ebf399db0ede80cc46f9ba54fa = $(`&lt;div id=&quot;html_b1f051ebf399db0ede80cc46f9ba54fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;JUNCTION COMMUNITY CHURCH&lt;/strong&gt;&lt;br&gt;     2867 Orchard Ave&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     Phone: (970) 243-0757&lt;br&gt;     Website: http://jctcc.net/saras-pantry&lt;br&gt;     Services: Provides a food box to individuals, seniors and families in need in the community. Families are limited to one box a month.     &lt;/div&gt;`)[0];
#                 popup_b1ce60adb4a6e28f6ac1c0aa15d79111.setContent(html_b1f051ebf399db0ede80cc46f9ba54fa);
#
#
#
#         marker_aacf892cb762c6605e48611f65c013e5.bindPopup(popup_b1ce60adb4a6e28f6ac1c0aa15d79111)
#         ;
#
#
#
#
#             var marker_52b80b936f9f964fa419f50a9c816306 = L.marker(
#                 [39.073337, -108.5719646],
#                 {}
#             ).addTo(map_173aeae540b4e879ad6726c3053076df);
#
#
#         var popup_9651eb2faee415cd55ebc2b8c3cccd98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3de984acbfcc8d4243434c041dd84511 = $(`&lt;div id=&quot;html_3de984acbfcc8d4243434c041dd84511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CONNECTION CHURCH - MESA COUNTY&lt;/strong&gt;&lt;br&gt;     655 N 1st St&lt;br&gt;     Grand Junction, C

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_food_pantries_v2.csv", index=False)

# Confirm the export
print("Data exported to cleaned_colorado_food_pantries_v2.csv")
# Out:
# Data exported to cleaned_colorado_food_pantries_v2.csv
