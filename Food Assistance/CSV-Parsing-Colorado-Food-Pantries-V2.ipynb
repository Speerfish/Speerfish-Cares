# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create multiple city specific map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_food_pantries.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#                  Assistance  \
# 0               Food Pantry
# 1               Food Pantry
# 2               Food Pantry
# 3               Food Pantry
# 4               Food Pantry
# 5           Food Assistance
# 6               Food Pantry
# 7               Food Pantry
# 8               Food Pantry
# 9           Food Assistance
# 10              Food Pantry
# 11              Food Pantry
# 12              Food Pantry
# 13              Food Pantry
# 14  Pet Food Pantry Locator
#
#                                                Agency  \
# 0                SILVER THREAD PUBLIC HEALTH DISTRICT
# 1                                   PINE RIVER SHARES
# 2   COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SP...
# 3                              RESTORATION FELLOWSHIP
# 4                            OURAY COUNTY FOOD PANTRY
# 5                        LOVE INC OF THE YAMPA VALLEY
# 6                                  CONNECTIONS 4 LIFE
# 7                               GOD'S PANTRY MINISTRY
# 8                      GRAND VALLEY CATHOLIC OUTREACH
# 9                      WOODLAND PARK COMMUNITY CHURCH
# 10                  LA PLATA FAMILY CENTERS COALITION
# 11                        CENTER TOWARD SELF-RELIANCE
# 12                           CITY OF COLORADO SPRINGS
# 13                          NEW LIFE COMMUNITY CHURCH
# 14                                COLORADO PET PANTRY
#
#                          Address              City State    Zip  \
# 0                   304 W 3rd St         Lake City    CO  81235
# 1                  658 S East St          Bayfield    CO  81122
# 2                   434 Lewis St    Pagosa Springs    CO  81147
# 3                 264 Village Dr    Pagosa Springs    CO  81147
# 4                  602 N Cora St           Ridgway    CO  81432
# 5             1198 W Victory Way             Craig    CO  81625
# 6   6436 S U.S. Hwy 85/87 Unit U  Colorado Springs    CO  80911
# 7              30 Widefield Blvd  Colorado Springs    CO  80911
# 8                   245 S 1st St    Grand Junction    CO  81501
# 9      700 Valley View Dr Unit D     Woodland Park    CO  80863
# 10                495 Florida Rd           Durango    CO  81301
# 11                  901 W 8th St            Pueblo    CO  81003
# 12       4290 Deerfield Hills Rd  Colorado Springs    CO  80916
# 13             17690 E Iliff Ave            Aurora    CO  80013
# 14                  P.O. Box 323           Boulder    CO  80306
#
#               County                                           Services  \
# 0    HINSDALE COUNTY  Provides a food box to individuals, seniors an...
# 1    LA PLATA COUNTY  Provides food for community members in need of...
# 2   ARCHULETA COUNTY  Provides food to individuals and families in A...
# 3   ARCHULETA COUNTY  Provides food boxes for residents of Archuleta...
# 4       OURAY COUNTY  Provides groceries based on a shopping list fo...
# 5      MOFFAT COUNTY  Provides food to qualified individuals and fam...
# 6     EL PASO COUNTY       Provides a food pantry to residents in need.
# 7     EL PASO COUNTY                            Provides a food pantry.
# 8        MESA COUNTY  Provides food box for Mesa County residents in...
# 9      TELLER COUNTY  Provides emergency food necessities and delive...
# 10   LA PLATA COUNTY  Provides a food box to families in need in the...
# 11     PUEBLO COUNTY  Food Pantry provides food assistance to low-in...
# 12    EL PASO COUNTY  Provides a drive-thru style food pantry to tho...
# 13   ARAPAHOE COUNTY  Provides bags of food to the community. The pa...
# 14    BOULDER COUNTY  Provides free temporary pet food through vario...
#
#                                           Eligibility  \
# 0   Individuals in the service area Area Served: H...
# 1   Must be residents of Bayfield and the Pine Riv...
# 2   No restrictions applied Area Served: Archuleta...
# 3      No restrictions. Area Served: Archuleta County
# 4   Individuals must be a resident of Ouray County...
# 5   For TEFAP assistance, households must meet the...
# 6   Residents of the service area Area Served: El ...
# 7   No restrictions applied Area Served: El Paso C...
# 8    No restrictions applied Area Served: Mesa County
# 9   No restrictions applied Area Served: Zip Codes...
# 10  No restriction applied Area Served: La Plata, ...
# 11  Open to the Public, low-income individuals who...
# 12  No restrictions applied Area Served: El Paso C...
# 13  No restrictions applied Area Served: Adams, Ar...
# 14     No restrictions applied Area Served: Statewide
#
#                                                 Hours           Phone  \
# 0                 Monday - Friday, 8 a.m. - 4:30 p.m.  (970) 944-0321
# 1                  Monday - Thursday, 9 a.m. - 3 p.m.  (970) 884-6040
# 2                Tuesday - Thursday, 8 a.m. - 12 p.m.  (970) 264-5508
# 3                        Monday-Friday, 8:00am-5:00pm  (970) 731-2937
# 4                        Thursday, 12:30 pm - 3:30 pm  (970) 626-4273
# 5   3rd Tuesday, 10 a.m. - 12 p.m.; 3rd Thursday, ...  (970) 826-4400
# 6                                          Hours Vary  (719) 387-9919
# 7                  Monday - Saturday, 9 a.m. - 3 p.m.  (719) 382-0643
# 8                Monday - Friday, 9 a.m. - 11:30 a.m.  (970) 241-3658
# 9                 Monday - Thursday, 9 a.m. - 12 p.m.  (719) 229-4512
# 10  Monday - Thursday, 8:30 a.m. - 4:30 p.m.; Frid...  (970) 385-4747
# 11                Monday - Friday, 8 a.m. - 4:30 p.m.  (719) 546-1271
# 12                   Monday - Friday, 9 a.m. - 6 p.m.  (719) 385-5996
# 13  Tuesday, 1 p.m. - 4 p.m.; Saturday, 10 a.m. - ...  (303) 368-7567
# 14  Monday - Sunday, 9 a.m. - 5 p.m. (Administrati...  (303) 818-0618
#
#                                               Website   Latitude   Longitude
# 0                 http://silverthreadpublichealth.org  38.028217 -107.314490
# 1                          http://pinerivershares.org  37.224047 -107.598306
# 2                                   http://cumcps.org  37.267823 -107.011796
# 3                    http://restorationfellowship.net  37.258096 -107.075037
# 4                    http://ouraycountyfoodpantry.org  38.156621 -107.757265
# 5              http://loveincyampavalley.org/services  40.514264 -107.561261
# 6                   http://connections4lifecenter.org  38.745604 -104.738987
# 7                             http://godspantryco.org  38.736079 -104.727113
# 8                         http://catholicoutreach.org  39.065587 -108.571251
# 9   http://woodlandparkcommunitychurch.com/storehouse  39.012142 -105.062023
# 10                                   http://lpfcc.org  37.283861 -107.869957
# 11                              https://cfdpueblo.org  38.274091 -104.619700
# 12  http://coloradosprings.gov/deeraeld-hills-comm...  38.784574 -104.747881
# 13                              http://nlccaurora.org  39.674607 -104.778200
# 14  http://coloradopetpantry.org/events/category/p...  40.102555 -105.363208

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Assistance   443 non-null    object
#  1   Agency       443 non-null    object
#  2   Address      443 non-null    object
#  3   City         443 non-null    object
#  4   State        443 non-null    object
#  5   Zip          443 non-null    int64
#  6   County       443 non-null    object
#  7   Services     443 non-null    object
#  8   Eligibility  442 non-null    object
#  9   Hours        443 non-null    object
#  10  Phone        443 non-null    object
#  11  Website      440 non-null    object
#  12  Latitude     443 non-null    float64
#  13  Longitude    443 non-null    float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 48.6+ KB
#                  Assistance  \
# 0               Food Pantry
# 1               Food Pantry
# 2               Food Pantry
# 3               Food Pantry
# 4               Food Pantry
# 5           Food Assistance
# 6               Food Pantry
# 7               Food Pantry
# 8               Food Pantry
# 9           Food Assistance
# 10              Food Pantry
# 11              Food Pantry
# 12              Food Pantry
# 13              Food Pantry
# 14  Pet Food Pantry Locator
#
#                                                Agency  \
# 0                SILVER THREAD PUBLIC HEALTH DISTRICT
# 1                                   PINE RIVER SHARES
# 2   COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SP...
# 3                              RESTORATION FELLOWSHIP
# 4                            OURAY COUNTY FOOD PANTRY
# 5                        LOVE INC OF THE YAMPA VALLEY
# 6                                  CONNECTIONS 4 LIFE
# 7                               GOD'S PANTRY MINISTRY
# 8                      GRAND VALLEY CATHOLIC OUTREACH
# 9                      WOODLAND PARK COMMUNITY CHURCH
# 10                  LA PLATA FAMILY CENTERS COALITION
# 11                        CENTER TOWARD SELF-RELIANCE
# 12                           CITY OF COLORADO SPRINGS
# 13                          NEW LIFE COMMUNITY CHURCH
# 14                                COLORADO PET PANTRY
#
#                          Address              City State    Zip  \
# 0                   304 W 3rd St         Lake City    CO  81235
# 1                  658 S East St          Bayfield    CO  81122
# 2                   434 Lewis St    Pagosa Springs    CO  81147
# 3                 264 Village Dr    Pagosa Springs    CO  81147
# 4                  602 N Cora St           Ridgway    CO  81432
# 5             1198 W Victory Way             Craig    CO  81625
# 6   6436 S U.S. Hwy 85/87 Unit U  Colorado Springs    CO  80911
# 7              30 Widefield Blvd  Colorado Springs    CO  80911
# 8                   245 S 1st St    Grand Junction    CO  81501
# 9      700 Valley View Dr Unit D     Woodland Park    CO  80863
# 10                495 Florida Rd           Durango    CO  81301
# 11                  901 W 8th St            Pueblo    CO  81003
# 12       4290 Deerfield Hills Rd  Colorado Springs    CO  80916
# 13             17690 E Iliff Ave            Aurora    CO  80013
# 14                  P.O. Box 323           Boulder    CO  80306
#
#               County                                           Services  \
# 0    HINSDALE COUNTY  Provides a food box to individuals, seniors an...
# 1    LA PLATA COUNTY  Provides food for community members in need of...
# 2   ARCHULETA COUNTY  Provides food to individuals and families in A...
# 3   ARCHULETA COUNTY  Provides food boxes for residents of Archuleta...
# 4       OURAY COUNTY  Provides groceries based on a shopping list fo...
# 5      MOFFAT COUNTY  Provides food to qualified individuals and fam...
# 6     EL PASO COUNTY       Provides a food pantry to residents in need.
# 7     EL PASO COUNTY                            Provides a food pantry.
# 8        MESA COUNTY  Provides food box for Mesa County residents in...
# 9      TELLER COUNTY  Provides emergency food necessities and delive...
# 10   LA PLATA COUNTY  Provides a food box to families in need in the...
# 11     PUEBLO COUNTY  Food Pantry provides food assistance to low-in...
# 12    EL PASO COUNTY  Provides a drive-thru style food pantry to tho...
# 13   ARAPAHOE COUNTY  Provides bags of food to the community. The pa...
# 14    BOULDER COUNTY  Provides free temporary pet food through vario...
#
#                                           Eligibility  \
# 0   Individuals in the service area Area Served: H...
# 1   Must be residents of Bayfield and the Pine Riv...
# 2   No restrictions applied Area Served: Archuleta...
# 3      No restrictions. Area Served: Archuleta County
# 4   Individuals must be a resident of Ouray County...
# 5   For TEFAP assistance, households must meet the...
# 6   Residents of the service area Area Served: El ...
# 7   No restrictions applied Area Served: El Paso C...
# 8    No restrictions applied Area Served: Mesa County
# 9   No restrictions applied Area Served: Zip Codes...
# 10  No restriction applied Area Served: La Plata, ...
# 11  Open to the Public, low-income individuals who...
# 12  No restrictions applied Area Served: El Paso C...
# 13  No restrictions applied Area Served: Adams, Ar...
# 14     No restrictions applied Area Served: Statewide
#
#                                                 Hours           Phone  \
# 0                 Monday - Friday, 8 a.m. - 4:30 p.m.  (970) 944-0321
# 1                  Monday - Thursday, 9 a.m. - 3 p.m.  (970) 884-6040
# 2                Tuesday - Thursday, 8 a.m. - 12 p.m.  (970) 264-5508
# 3                        Monday-Friday, 8:00am-5:00pm  (970) 731-2937
# 4                        Thursday, 12:30 pm - 3:30 pm  (970) 626-4273
# 5   3rd Tuesday, 10 a.m. - 12 p.m.; 3rd Thursday, ...  (970) 826-4400
# 6                                          Hours Vary  (719) 387-9919
# 7                  Monday - Saturday, 9 a.m. - 3 p.m.  (719) 382-0643
# 8                Monday - Friday, 9 a.m. - 11:30 a.m.  (970) 241-3658
# 9                 Monday - Thursday, 9 a.m. - 12 p.m.  (719) 229-4512
# 10  Monday - Thursday, 8:30 a.m. - 4:30 p.m.; Frid...  (970) 385-4747
# 11                Monday - Friday, 8 a.m. - 4:30 p.m.  (719) 546-1271
# 12                   Monday - Friday, 9 a.m. - 6 p.m.  (719) 385-5996
# 13  Tuesday, 1 p.m. - 4 p.m.; Saturday, 10 a.m. - ...  (303) 368-7567
# 14  Monday - Sunday, 9 a.m. - 5 p.m. (Administrati...  (303) 818-0618
#
#                                               Website   Latitude   Longitude
# 0                 http://silverthreadpublichealth.org  38.028217 -107.314490
# 1                          http://pinerivershares.org  37.224047 -107.598306
# 2                                   http://cumcps.org  37.267823 -107.011796
# 3                    http://restorationfellowship.net  37.258096 -107.075037
# 4                    http://ouraycountyfoodpantry.org  38.156621 -107.757265
# 5              http://loveincyampavalley.org/services  40.514264 -107.561261
# 6                   http://connections4lifecenter.org  38.745604 -104.738987
# 7                             http://godspantryco.org  38.736079 -104.727113
# 8                         http://catholicoutreach.org  39.065587 -108.571251
# 9   http://woodlandparkcommunitychurch.com/storehouse  39.012142 -105.062023
# 10                                   http://lpfcc.org  37.283861 -107.869957
# 11                              https://cfdpueblo.org  38.274091 -104.619700
# 12  http://coloradosprings.gov/deeraeld-hills-comm...  38.784574 -104.747881
# 13                              http://nlccaurora.org  39.674607 -104.778200
# 14  http://coloradopetpantry.org/events/category/p...  40.102555 -105.363208

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_food_pantries_map_v2.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59d35cb8a858223ed699d3ca0a682afd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59d35cb8a858223ed699d3ca0a682afd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59d35cb8a858223ed699d3ca0a682afd = L.map(
#                 &quot;map_59d35cb8a858223ed699d3ca0a682afd&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27e62f70564f56242c69ad6b65a20c62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_27e62f70564f56242c69ad6b65a20c62.addTo(map_59d35cb8a858223ed699d3ca0a682afd);
#
#
#             var marker_d8fcd45f36cb1edd5ef6791b95a78308 = L.marker(
#                 [38.028217, -107.31449],
#                 {}
#             ).addTo(map_59d35cb8a858223ed699d3ca0a682afd);
#
#
#         var popup_c982598ad03dd7eb4ce4f3ff99548cae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb1b90260f408a3777254cb06f882307 = $(`&lt;div id=&quot;html_eb1b90260f408a3777254cb06f882307&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SILVER THREAD PUBLIC HEALTH DISTRICT&lt;/strong&gt;&lt;br&gt;     304 W 3rd St&lt;br&gt;     Lake City, CO 81235&lt;br&gt;     Phone: (970) 944-0321&lt;br&gt;     Website: &lt;a href=&quot;http://silverthreadpublichealth.org&quot;&gt;SILVER THREAD PUBLIC HEALTH DISTRICT&lt;/a&gt;&lt;br&gt;     Services: Provides a food box to individuals, seniors and families in need.     &lt;/div&gt;`)[0];
#                 popup_c982598ad03dd7eb4ce4f3ff99548cae.setContent(html_eb1b90260f408a3777254cb06f882307);
#
#
#
#         marker_d8fcd45f36cb1edd5ef6791b95a78308.bindPopup(popup_c982598ad03dd7eb4ce4f3ff99548cae)
#         ;
#
#
#
#
#             var marker_29ddc08317c3414fc951425487ab5e8b = L.marker(
#                 [37.2240474, -107.5983059],
#                 {}
#             ).addTo(map_59d35cb8a858223ed699d3ca0a682afd);
#
#
#         var popup_626183f3d92746dc24a6082953cbe533 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6a7435d03e96c19075799e24d226194 = $(`&lt;div id=&quot;html_d6a7435d03e96c19075799e24d226194&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;PINE RIVER SHARES&lt;/strong&gt;&lt;br&gt;     658 S East St&lt;br&gt;     Bayfield, CO 81122&lt;br&gt;     Phone: (970) 884-6040&lt;br&gt;     Website: &lt;a href=&quot;http://pinerivershares.org&quot;&gt;PINE RIVER SHARES&lt;/a&gt;&lt;br&gt;     Services: Provides food for community members in need of assistance. Also offers a backpack of food for students attending the following schools to take home every weekend: Bayfield Elementary School Bayfield Primary SchoolIgnacio Elementary Schoo...     &lt;/div&gt;`)[0];
#                 popup_626183f3d92746dc24a6082953cbe533.setContent(html_d6a7435d03e96c19075799e24d226194);
#
#
#
#         marker_29ddc08317c3414fc951425487ab5e8b.bindPopup(popup_626183f3d92746dc24a6082953cbe533)
#         ;
#
#
#
#
#             var marker_4b758860ecf1495c9660b6d50d679ddf = L.marker(
#                 [37.2678233, -107.0117959],
#                 {}
#             ).addTo(map_59d35cb8a858223ed699d3ca0a682afd);
#
#
#         var popup_754aa5985cee22d514a90d7ab4e1e686 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1752434e48317d04d092e1d14d199e2 = $(`&lt;div id=&quot;html_c1752434e48317d04d092e1d14d199e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SPRINGS&lt;/strong&gt;&lt;br&gt;     434 Lewis St&lt;br&gt;     Pagosa Springs, CO 81147&lt;br&gt;     Phone: (970) 264-5508&lt;br&gt;     Website: &lt;a href=&quot;http://cumcps.org&quot;&gt;COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SPRINGS&lt;/a&gt;&lt;br&gt;     Services: Provides food to individuals and families in Archuleta County who are in need. Services limited to one time a week per individual.     &lt;/div&gt;`)[0];
#                 popup_754aa5985cee22d514a90d7ab4e1e686.setContent(html_c1752434e48317d04d092e1d14d199e2);
#
#
#
#         marker_4b758860ecf1495c9660b6d50d679ddf.bindPopup(popup_754aa5985cee22d514a90d7ab4e1e686)
#         ;
#
#
#
#
#             var marker_5909fe7a4193f61608ff8457ad2100e3 = L.marker(
#                 [37.2580963, -107.0750371],
#                 {}
#             ).addTo(map_59d35cb8a858223ed699d3ca0a682afd);
#
#
#         var popup_7fe87ee9ac4bf89876eeb93dab834515 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7252c1dda4545536a3452e15b9381704 = $(`&lt;div id=&quot

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for food pantries in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_denver.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfc40003bf10c17151d6c7d13da29f09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfc40003bf10c17151d6c7d13da29f09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfc40003bf10c17151d6c7d13da29f09 = L.map(
#                 &quot;map_bfc40003bf10c17151d6c7d13da29f09&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_434fc352f64c62a676732447f9acefa2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_434fc352f64c62a676732447f9acefa2.addTo(map_bfc40003bf10c17151d6c7d13da29f09);
#
#
#             var marker_29cce438c11bbda76d4b0be5daa350a5 = L.marker(
#                 [39.7446234, -104.9730507],
#                 {}
#             ).addTo(map_bfc40003bf10c17151d6c7d13da29f09);
#
#
#         var popup_fad737c3dd5359bf2f94f1c463e9c912 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7b477eb99b6999671fcb306a35928da = $(`&lt;div id=&quot;html_f7b477eb99b6999671fcb306a35928da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;METRO CARING&lt;/strong&gt;&lt;br&gt;     1100 E 18th Ave&lt;br&gt;     Denver, CO 80218&lt;br&gt;     Phone: Monday, Thursday, 9 a.m. - 11:30 a.m. - 12:30 p.m...&lt;br&gt;     Website: &lt;a href=&quot;(303) 860-7200&quot;&gt;METRO CARING&lt;/a&gt;&lt;br&gt;     Services: Provides a fresh food market where the community can choose from an array of nutritious foods,     &lt;/div&gt;`)[0];
#                 popup_fad737c3dd5359bf2f94f1c463e9c912.setContent(html_f7b477eb99b6999671fcb306a35928da);
#
#
#
#         marker_29cce438c11bbda76d4b0be5daa350a5.bindPopup(popup_fad737c3dd5359bf2f94f1c463e9c912)
#         ;
#
#
#
#
#             var marker_f1a958cffe69ef7e4393cdcee57ae44d = L.marker(
#                 [39.6614613, -104.9122488],
#                 {}
#             ).addTo(map_bfc40003bf10c17151d6c7d13da29f09);
#
#
#         var popup_6cef88fe56a2f33f301b8ac92be543db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e8694aa02e5c1fb26092b789fc82423 = $(`&lt;div id=&quot;html_8e8694aa02e5c1fb26092b789fc82423&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     3060 S Monaco St Pkwy&lt;br&gt;     Denver, CO 80222&lt;br&gt;     Phone: (303) 375-5853&lt;br&gt;     Website: &lt;a href=&quot;http://foodbankrockies.org&quot;&gt;FOOD BANK OF THE ROCKIES&lt;/a&gt;&lt;br&gt;     Services: Provides food to communities by sending semi-trucks to set locations and distributing food for 1-2 hours.     &lt;/div&gt;`)[0];
#                 popup_6cef88fe56a2f33f301b8ac92be543db.setContent(html_8e8694aa02e5c1fb26092b789fc82423);
#
#
#
#         marker_f1a958cffe69ef7e4393cdcee57ae44d.bindPopup(popup_6cef88fe56a2f33f301b8ac92be543db)
#         ;
#
#
#
#
#             var marker_293fc15047904be23c3c55a524af6284 = L.marker(
#                 [39.7260565, -105.0501581],
#                 {}
#             ).addTo(map_bfc40003bf10c17151d6c7d13da29f09);
#
#
#         var popup_2b99a29c4e8450af8037e40edcee748b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ba097593bc7daf3610041a8852d3613 = $(`&lt;div id=&quot;html_4ba097593bc7daf3610041a8852d3613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     13300 W 6th Ave&lt;br&gt;     Denver, CO 80215&lt;br&gt;     Phone: (303) 375-5853&lt;br&gt;     Website: &lt;a href=&quot;http://foodbankrockies.org&quot;&gt;FOOD BANK OF THE ROCKIES&lt;/a&gt;&lt;br&gt;     Services: Provides food to communities by sending semi-trucks to set locations and distributing food for 1-2 hours.     &lt;/div&gt;`)[0];
#                 popup_2b99a29c4e8450af8037e40edcee748b.setContent(html_4ba097593bc7daf3610041a8852d3613);
#
#
#
#         marker_293fc15047904be23c3c55a524af6284.bindPopup(popup_2b99a29c4e8450af8037e40edcee748b)
#         ;
#
#
#
#
#             var marker_e25401aedd0eb8485c66252b541e77f9 = L.marker(
#                 [39.6851808, -105.0160784],
#                 {}
#             ).addTo(map_bfc40003bf10c17151d6c7d13da29f09);
#
#
#         var popup_9822711df461d54c8a98fd18f66a15fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_385b0978f9a4fb610339f4d86ecd68ef = $(`&lt;div id=&quot;html_385b0978f9a4fb610339f4d86ecd68ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY MINISTRY&lt;/strong&gt;&lt;br&gt;     1755 S Zuni St&lt;br&gt;

# %%
# Example: Search for food pantries in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_colorado_springs.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b369f34fb6d99e4b8e984b666a7e95e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b369f34fb6d99e4b8e984b666a7e95e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b369f34fb6d99e4b8e984b666a7e95e7 = L.map(
#                 &quot;map_b369f34fb6d99e4b8e984b666a7e95e7&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2016c1e1eaf578fc01ebc9c4723354e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2016c1e1eaf578fc01ebc9c4723354e.addTo(map_b369f34fb6d99e4b8e984b666a7e95e7);
#
#
#             var marker_4fd3952e6673a25e9c3a63d1e480b9dd = L.marker(
#                 [38.745604, -104.738987],
#                 {}
#             ).addTo(map_b369f34fb6d99e4b8e984b666a7e95e7);
#
#
#         var popup_850cf7131640b026aaa9aa24ba208b02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc2b55497bcacc98b38403c882dbec1e = $(`&lt;div id=&quot;html_cc2b55497bcacc98b38403c882dbec1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CONNECTIONS 4 LIFE&lt;/strong&gt;&lt;br&gt;     6436 S U.S. Hwy 85/87 Unit U&lt;br&gt;     Colorado Springs, CO 80911&lt;br&gt;     Phone: (719) 387-9919&lt;br&gt;     Website: &lt;a href=&quot;http://connections4lifecenter.org&quot;&gt;CONNECTIONS 4 LIFE&lt;/a&gt;&lt;br&gt;     Services: Provides a food pantry to residents in need.     &lt;/div&gt;`)[0];
#                 popup_850cf7131640b026aaa9aa24ba208b02.setContent(html_cc2b55497bcacc98b38403c882dbec1e);
#
#
#
#         marker_4fd3952e6673a25e9c3a63d1e480b9dd.bindPopup(popup_850cf7131640b026aaa9aa24ba208b02)
#         ;
#
#
#
#
#             var marker_40477ff9e43b9c561bb2e70306a457fb = L.marker(
#                 [38.7360794, -104.7271127],
#                 {}
#             ).addTo(map_b369f34fb6d99e4b8e984b666a7e95e7);
#
#
#         var popup_64b5699ba9190f669b9a25d7b8908f76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa62b76e585f6ebdafffbed5076e43a7 = $(`&lt;div id=&quot;html_fa62b76e585f6ebdafffbed5076e43a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GOD&#x27;S PANTRY MINISTRY&lt;/strong&gt;&lt;br&gt;     30 Widefield Blvd&lt;br&gt;     Colorado Springs, CO 80911&lt;br&gt;     Phone: (719) 382-0643&lt;br&gt;     Website: &lt;a href=&quot;http://godspantryco.org&quot;&gt;GOD&#x27;S PANTRY MINISTRY&lt;/a&gt;&lt;br&gt;     Services: Provides a food pantry.     &lt;/div&gt;`)[0];
#                 popup_64b5699ba9190f669b9a25d7b8908f76.setContent(html_fa62b76e585f6ebdafffbed5076e43a7);
#
#
#
#         marker_40477ff9e43b9c561bb2e70306a457fb.bindPopup(popup_64b5699ba9190f669b9a25d7b8908f76)
#         ;
#
#
#
#
#             var marker_7ba0b97d62e21d93794e4a39cea92cab = L.marker(
#                 [38.7845737, -104.7478808],
#                 {}
#             ).addTo(map_b369f34fb6d99e4b8e984b666a7e95e7);
#
#
#         var popup_a138a3a9a12fbf688e8e646449431235 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_133f6093b370abd1c1b5153d3ab5ef0f = $(`&lt;div id=&quot;html_133f6093b370abd1c1b5153d3ab5ef0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CITY OF COLORADO SPRINGS&lt;/strong&gt;&lt;br&gt;     4290 Deerfield Hills Rd&lt;br&gt;     Colorado Springs, CO 80916&lt;br&gt;     Phone: (719) 385-5996&lt;br&gt;     Website: &lt;a href=&quot;http://coloradosprings.gov/deeraeld-hills-community-center&quot;&gt;CITY OF COLORADO SPRINGS&lt;/a&gt;&lt;br&gt;     Services: Provides a drive-thru style food pantry to those in need.     &lt;/div&gt;`)[0];
#                 popup_a138a3a9a12fbf688e8e646449431235.setContent(html_133f6093b370abd1c1b5153d3ab5ef0f);
#
#
#
#         marker_7ba0b97d62e21d93794e4a39cea92cab.bindPopup(popup_a138a3a9a12fbf688e8e646449431235)
#         ;
#
#
#
#
#             var marker_25aa99800fd25a6f9cc1ac99beebe7bc = L.marker(
#                 [38.8649785, -104.815912],
#                 {}
#             ).addTo(map_b369f34fb6d99e4b8e984b666a7e95e7);
#
#
#         var popup_469e5d78f4cc06ea6cbef950e7eadb71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d29c87c8a383b234c53dd56452e9506d = $(`&lt;div id=&quot;html_d29c87c8a383b234c53dd56452e9506d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FISHES AND LOAVES&lt;/strong&gt;&lt;br&gt;     2221 N Wahsatch Ave&lt;br&gt;     Colorado Springs, CO 80907&lt;br&gt;     Phone: (720) 373-9760&lt;br&gt;     Website: &lt;a href=&quot

# %%
# Example: Search for food pantries in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_aurora.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7004a7e561b788fda03455e55335f8cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7004a7e561b788fda03455e55335f8cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7004a7e561b788fda03455e55335f8cf = L.map(
#                 &quot;map_7004a7e561b788fda03455e55335f8cf&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b291752e56f3e2bde753ff39fa9a8ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5b291752e56f3e2bde753ff39fa9a8ca.addTo(map_7004a7e561b788fda03455e55335f8cf);
#
#
#             var marker_b60c0598f854d97573e67c3d739a94f8 = L.marker(
#                 [39.6746072, -104.7782004],
#                 {}
#             ).addTo(map_7004a7e561b788fda03455e55335f8cf);
#
#
#         var popup_d6650a8797b49bf6f7e4e50a7fd7cd0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59fac762647c8ef181613a3671f46533 = $(`&lt;div id=&quot;html_59fac762647c8ef181613a3671f46533&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NEW LIFE COMMUNITY CHURCH&lt;/strong&gt;&lt;br&gt;     17690 E Iliff Ave&lt;br&gt;     Aurora, CO 80013&lt;br&gt;     Phone: (303) 368-7567&lt;br&gt;     Website: &lt;a href=&quot;http://nlccaurora.org&quot;&gt;NEW LIFE COMMUNITY CHURCH&lt;/a&gt;&lt;br&gt;     Services: Provides bags of food to the community. The pantry may be visited on a monthly or bi-monthly basis.     &lt;/div&gt;`)[0];
#                 popup_d6650a8797b49bf6f7e4e50a7fd7cd0b.setContent(html_59fac762647c8ef181613a3671f46533);
#
#
#
#         marker_b60c0598f854d97573e67c3d739a94f8.bindPopup(popup_d6650a8797b49bf6f7e4e50a7fd7cd0b)
#         ;
#
#
#
#
#             var marker_8edda7cbc5dc201cb0be0438bd358252 = L.marker(
#                 [39.6961142, -104.8550663],
#                 {}
#             ).addTo(map_7004a7e561b788fda03455e55335f8cf);
#
#
#         var popup_e197494e92e73617845e59790f5f9a55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ddb039abb35009df8e38b9ebc7b8354 = $(`&lt;div id=&quot;html_9ddb039abb35009df8e38b9ebc7b8354&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AURORA FIRST SEVENTH DAY ADVENTIST CHURCH&lt;/strong&gt;&lt;br&gt;     11400 E Mississippi Ave&lt;br&gt;     Aurora, CO 80012&lt;br&gt;     Phone: (303) 755-1617&lt;br&gt;     Website: &lt;a href=&quot;http://auroraarstco.adventistchurch.org&quot;&gt;AURORA FIRST SEVENTH DAY ADVENTIST CHURCH&lt;/a&gt;&lt;br&gt;     Services: Provides a food and clothing bank for the community.     &lt;/div&gt;`)[0];
#                 popup_e197494e92e73617845e59790f5f9a55.setContent(html_9ddb039abb35009df8e38b9ebc7b8354);
#
#
#
#         marker_8edda7cbc5dc201cb0be0438bd358252.bindPopup(popup_e197494e92e73617845e59790f5f9a55)
#         ;
#
#
#
#
#             var marker_d541aa065a448674b7471439abe7a50c = L.marker(
#                 [39.742282, -104.8661782],
#                 {}
#             ).addTo(map_7004a7e561b788fda03455e55335f8cf);
#
#
#         var popup_00b2ea731f8e88b400f9819421fc468a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9216d10d3f2f156f15558ef477353082 = $(`&lt;div id=&quot;html_9216d10d3f2f156f15558ef477353082&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;VILLAGE EXCHANGE CENTER&lt;/strong&gt;&lt;br&gt;     1609 Havana St&lt;br&gt;     Aurora, CO 80010&lt;br&gt;     Phone: (720) 668-9968&lt;br&gt;     Website: &lt;a href=&quot;http://villageexchangecenter.org/programs/village-pantry/&quot;&gt;VILLAGE EXCHANGE CENTER&lt;/a&gt;&lt;br&gt;     Services: Provides individuals and families with culturally relevant food and personal hygiene items, including: Fresh produce Meals Diapers Toiletries     &lt;/div&gt;`)[0];
#                 popup_00b2ea731f8e88b400f9819421fc468a.setContent(html_9216d10d3f2f156f15558ef477353082);
#
#
#
#         marker_d541aa065a448674b7471439abe7a50c.bindPopup(popup_00b2ea731f8e88b400f9819421fc468a)
#         ;
#
#
#
#
#             var marker_8c7d2cffd369eec89af0ebf7fb0b6553 = L.marker(
#                 [39.6810838, -104.826839],
#                 {}
#             ).addTo(map_7004a7e561b788fda03455e55335f8cf);
#
#
#         var popup_cead6586df2831043b168eafc3ddf0e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fec6558e753873282a87bbb0a90a0cf3 = $(`&lt;div id=&quot;html_fec6558e753873282a87bbb0a90a0cf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF

# %%
# Example: Search for food pantries in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_fort_collins.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_671f783c9c4062da281bfeec18de06fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_671f783c9c4062da281bfeec18de06fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_671f783c9c4062da281bfeec18de06fc = L.map(
#                 &quot;map_671f783c9c4062da281bfeec18de06fc&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe9888916bc0a3019e01f0424f68c006 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fe9888916bc0a3019e01f0424f68c006.addTo(map_671f783c9c4062da281bfeec18de06fc);
#
#
#             var marker_6bc4e6e853ff2a55a34f967558e65921 = L.marker(
#                 [40.5872724, -105.1219739],
#                 {}
#             ).addTo(map_671f783c9c4062da281bfeec18de06fc);
#
#
#         var popup_4e4e659f4ae97dc4131114f44153b092 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56b36e2a527d5077a12c6f283cd29b95 = $(`&lt;div id=&quot;html_56b36e2a527d5077a12c6f283cd29b95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK FOR LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     201 S Impala Dr&lt;br&gt;     Fort Collins, CO 80521&lt;br&gt;     Phone: (970) 493-4477&lt;br&gt;     Website: &lt;a href=&quot;http://foodbanklarimer.org/mobiles&quot;&gt;FOOD BANK FOR LARIMER COUNTY&lt;/a&gt;&lt;br&gt;     Services: Offers a drive-through mobile food pantry for those in need.     &lt;/div&gt;`)[0];
#                 popup_4e4e659f4ae97dc4131114f44153b092.setContent(html_56b36e2a527d5077a12c6f283cd29b95);
#
#
#
#         marker_6bc4e6e853ff2a55a34f967558e65921.bindPopup(popup_4e4e659f4ae97dc4131114f44153b092)
#         ;
#
#
#
#
#             var marker_ba98fbfbb763a161cfcd420f99c3a57e = L.marker(
#                 [40.6047193, -105.0725555],
#                 {}
#             ).addTo(map_671f783c9c4062da281bfeec18de06fc);
#
#
#         var popup_6759c355afac40eb478063fa0d0ff8eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1be2b8b4a78f37324d75c59d9004a93e = $(`&lt;div id=&quot;html_1be2b8b4a78f37324d75c59d9004a93e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK FOR LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     1301 Blue Spruce Dr&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     Phone: (970) 493-4477&lt;br&gt;     Website: &lt;a href=&quot;http://foodbanklarimer.org/our-programs&quot;&gt;FOOD BANK FOR LARIMER COUNTY&lt;/a&gt;&lt;br&gt;     Services: Provides a client choice food pantry for individuals in need. Also distributes the Commodities Supplemental Food Program (CSFP) to eligible seniors and The Emergency Food Assistance Program (TFAP)...     &lt;/div&gt;`)[0];
#                 popup_6759c355afac40eb478063fa0d0ff8eb.setContent(html_1be2b8b4a78f37324d75c59d9004a93e);
#
#
#
#         marker_ba98fbfbb763a161cfcd420f99c3a57e.bindPopup(popup_6759c355afac40eb478063fa0d0ff8eb)
#         ;
#
#
#
#
#             var marker_c3f2e541baa9496e252954f9c06ce3ae = L.marker(
#                 [40.533596, -105.0800634],
#                 {}
#             ).addTo(map_671f783c9c4062da281bfeec18de06fc);
#
#
#         var popup_240b31625c05858139b029e043b6402e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e553534a712d8715e6d191495539733 = $(`&lt;div id=&quot;html_9e553534a712d8715e6d191495539733&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SALVATION ARMY FORT COLLINS&lt;/strong&gt;&lt;br&gt;     3901 S Mason St&lt;br&gt;     Fort Collins, CO 80525&lt;br&gt;     Phone: (970) 207-4472 Ext 201&lt;br&gt;     Website: &lt;a href=&quot;http://fortcollins.salvationarmy.org/fort_collins_corps/overcome-poverty&quot;&gt;SALVATION ARMY FORT COLLINS&lt;/a&gt;&lt;br&gt;     Services: Provides food boxes and clothing for individuals in need. When available, also provides: Hygiene items Diapers and wipes Pet food Period kits     &lt;/div&gt;`)[0];
#                 popup_240b31625c05858139b029e043b6402e.setContent(html_9e553534a712d8715e6d191495539733);
#
#
#
#         marker_c3f2e541baa9496e252954f9c06ce3ae.bindPopup(popup_240b31625c05858139b029e043b6402e)
#         ;
#
#
#
#
#             var marker_c673df03a2ffd24a35ea7ee5def67376 = L.marker(
#                 [40.5739532, -105.0735276],
#                 {}
#             ).addTo(map_671f783c9c4062da281bfeec18de06fc);
#
#
#         var popup_733a3990379ccd6c6f3e72d7fcecdc50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d7fc0bfe7322eb5b0263977a8b65042 = $(

# %%
# Example: Search for food pantries in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_lakewood.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d8504b27d462cde8d956ed75bfc8fe6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d8504b27d462cde8d956ed75bfc8fe6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d8504b27d462cde8d956ed75bfc8fe6 = L.map(
#                 &quot;map_5d8504b27d462cde8d956ed75bfc8fe6&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9695cd70d13f631221771ea327957199 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9695cd70d13f631221771ea327957199.addTo(map_5d8504b27d462cde8d956ed75bfc8fe6);
#
#
#             var marker_8e28792ce83898ca22b6da820b309907 = L.marker(
#                 [39.6907746, -105.0714054],
#                 {}
#             ).addTo(map_5d8504b27d462cde8d956ed75bfc8fe6);
#
#
#         var popup_a0c9d9d1cd90397b52bba08d943ccb58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f22a912a5e8ca28f700c5931a5e6079 = $(`&lt;div id=&quot;html_0f22a912a5e8ca28f700c5931a5e6079&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     1450 S Pierce St&lt;br&gt;     Lakewood, CO 80232&lt;br&gt;     Phone: 1st Tuesday, 3 p.m. (While Supplies Last)&lt;br&gt;     Website: &lt;a href=&quot;(303) 375-5853&quot;&gt;FOOD BANK OF THE ROCKIES&lt;/a&gt;&lt;br&gt;     Services: Provides food to communities by sending semi-trucks to set locations and distributing food for 1-2 hours.     &lt;/div&gt;`)[0];
#                 popup_a0c9d9d1cd90397b52bba08d943ccb58.setContent(html_0f22a912a5e8ca28f700c5931a5e6079);
#
#
#
#         marker_8e28792ce83898ca22b6da820b309907.bindPopup(popup_a0c9d9d1cd90397b52bba08d943ccb58)
#         ;
#
#
#
#
#             var marker_4bdf8b729f4806325efaeb2752b46891 = L.marker(
#                 [39.7385136, -105.094918],
#                 {}
#             ).addTo(map_5d8504b27d462cde8d956ed75bfc8fe6);
#
#
#         var popup_7fdea7d841495362fda67baca2ce7fc3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3668999ab7bbefe3cd57c5a219b578c8 = $(`&lt;div id=&quot;html_3668999ab7bbefe3cd57c5a219b578c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ACTION CENTER&lt;/strong&gt;&lt;br&gt;     8745 W 14th Ave&lt;br&gt;     Lakewood, CO 80215&lt;br&gt;     Phone: (303) 237-7704&lt;br&gt;     Website: &lt;a href=&quot;http://theactioncenter.org&quot;&gt;ACTION CENTER&lt;/a&gt;&lt;br&gt;     Services: Offers a community food pantry that individuals can utilize once a month. Groceries vary by day, but typically include non-perishable and perishable food items such as: Fresh vegetables Fruits Dairy Proteins Emergency diapers and personal hygiene items may...     &lt;/div&gt;`)[0];
#                 popup_7fdea7d841495362fda67baca2ce7fc3.setContent(html_3668999ab7bbefe3cd57c5a219b578c8);
#
#
#
#         marker_4bdf8b729f4806325efaeb2752b46891.bindPopup(popup_7fdea7d841495362fda67baca2ce7fc3)
#         ;
#
#
#
#
#             var marker_5ec66c044de8405499e51572f6ace56c = L.marker(
#                 [39.7271071, -105.0816301],
#                 {}
#             ).addTo(map_5d8504b27d462cde8d956ed75bfc8fe6);
#
#
#         var popup_4370cb1ea1fbf9b3d866e99600b1032a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a98847693238619becd3daddd517c440 = $(`&lt;div id=&quot;html_a98847693238619becd3daddd517c440&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CAT CARE SOCIETY&lt;/strong&gt;&lt;br&gt;     5787 W 6th Ave&lt;br&gt;     Lakewood, CO 80214&lt;br&gt;     Phone: (303) 239-9680&lt;br&gt;     Website: &lt;a href=&quot;http://catcaresociety.org/programs/#nibbles-kibbles&quot;&gt;CAT CARE SOCIETY&lt;/a&gt;&lt;br&gt;     Services: Offers cat food and supplies to individuals who are experiencing temporary financial challenges.     &lt;/div&gt;`)[0];
#                 popup_4370cb1ea1fbf9b3d866e99600b1032a.setContent(html_a98847693238619becd3daddd517c440);
#
#
#
#         marker_5ec66c044de8405499e51572f6ace56c.bindPopup(popup_4370cb1ea1fbf9b3d866e99600b1032a)
#         ;
#
#
#
#
#             var marker_4ac38ae971127b5d951f1ea9cb49d925 = L.marker(
#                 [39.7110864, -105.060541],
#                 {}
#             ).addTo(map_5d8504b27d462cde8d956ed75bfc8fe6);
#
#
#         var popup_a7dbe4ea6d57cad2ecc78abc811c5ff6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de53f0113735f4a00d872ce01b3422df = $(`&lt;div id=&quot;html_de53f0113735f4a00d872ce01b342

# %%
# Example: Search for food pantries in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_arvada.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70d10416b986c0226a859b05b6b44ea5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70d10416b986c0226a859b05b6b44ea5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70d10416b986c0226a859b05b6b44ea5 = L.map(
#                 &quot;map_70d10416b986c0226a859b05b6b44ea5&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15d8f919ce7d9cd67bde08b8eacd09e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_15d8f919ce7d9cd67bde08b8eacd09e8.addTo(map_70d10416b986c0226a859b05b6b44ea5);
#
#
#             var marker_fd3c66aef9019714635f92686efc8fa8 = L.marker(
#                 [39.800294, -105.0928581],
#                 {}
#             ).addTo(map_70d10416b986c0226a859b05b6b44ea5);
#
#
#         var popup_da43e6cf86593d1446b2d9147181e36c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_551e0cd5638310ff7693186550e95b2d = $(`&lt;div id=&quot;html_551e0cd5638310ff7693186550e95b2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY TABLE&lt;/strong&gt;&lt;br&gt;     8555 W 57th Ave&lt;br&gt;     Arvada, CO 80002&lt;br&gt;     Phone: (303) 424-6685&lt;br&gt;     Website: &lt;a href=&quot;http://cotable.org&quot;&gt;COMMUNITY TABLE&lt;/a&gt;&lt;br&gt;     Services: Provides emergency food to individuals and families. Each client selects a supply of food based on household size. Families and individuals may use this program when needed...     &lt;/div&gt;`)[0];
#                 popup_da43e6cf86593d1446b2d9147181e36c.setContent(html_551e0cd5638310ff7693186550e95b2d);
#
#
#
#         marker_fd3c66aef9019714635f92686efc8fa8.bindPopup(popup_da43e6cf86593d1446b2d9147181e36c)
#         ;
#
#
#
#
#             var marker_2af888b58c377ac2a4bb9f0ea29ea95a = L.marker(
#                 [39.8054671, -105.0622284],
#                 {}
#             ).addTo(map_70d10416b986c0226a859b05b6b44ea5);
#
#
#         var popup_261b561d52468b4c8175a8b8fbc5ee94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc5537449737d337f45872cb10a34b2e = $(`&lt;div id=&quot;html_cc5537449737d337f45872cb10a34b2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AGAPE LIFE CHURCH&lt;/strong&gt;&lt;br&gt;     5970 W 60th Ave&lt;br&gt;     Arvada, CO 80003&lt;br&gt;     Phone: (303) 431-6481&lt;br&gt;     Website: &lt;a href=&quot;http://agapelife.org/food-outreach/&quot;&gt;AGAPE LIFE CHURCH&lt;/a&gt;&lt;br&gt;     Services: Provides a food pantry and hosts a monthly TEFAP (The Emergency Food Assistance Program) food distribution site.     &lt;/div&gt;`)[0];
#                 popup_261b561d52468b4c8175a8b8fbc5ee94.setContent(html_cc5537449737d337f45872cb10a34b2e);
#
#
#
#         marker_2af888b58c377ac2a4bb9f0ea29ea95a.bindPopup(popup_261b561d52468b4c8175a8b8fbc5ee94)
#         ;
#
#
#
#
#             tile_layer_15d8f919ce7d9cd67bde08b8eacd09e8.addTo(map_70d10416b986c0226a859b05b6b44ea5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for food pantries in a specific city
city_search = "Greeley"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_greeley.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a49594fbcc02a5214067bcb63cc1fe21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a49594fbcc02a5214067bcb63cc1fe21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a49594fbcc02a5214067bcb63cc1fe21 = L.map(
#                 &quot;map_a49594fbcc02a5214067bcb63cc1fe21&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98f98e8e441c448c20ec9de2edd67163 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_98f98e8e441c448c20ec9de2edd67163.addTo(map_a49594fbcc02a5214067bcb63cc1fe21);
#
#
#             var marker_a86f3b4dc70411e01cdff766f02d96ad = L.marker(
#                 [40.4437132, -104.6987994],
#                 {}
#             ).addTo(map_a49594fbcc02a5214067bcb63cc1fe21);
#
#
#         var popup_ae355456b2f7a4c0ca8adc2e1e95340e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24f98d4ff3ddf5f0c8910d6ec86939e7 = $(`&lt;div id=&quot;html_24f98d4ff3ddf5f0c8910d6ec86939e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WELD FOOD BANK&lt;/strong&gt;&lt;br&gt;     1108 H St&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 356-2199&lt;br&gt;     Website: &lt;a href=&quot;http://weldfoodbank.org/emergency-food-program/&quot;&gt;WELD FOOD BANK&lt;/a&gt;&lt;br&gt;     Services: Provides a box of basic food staples to qualified families or individuals in crisis. Individuals can receive a food box on an emergency basis, not more than once per week...     &lt;/div&gt;`)[0];
#                 popup_ae355456b2f7a4c0ca8adc2e1e95340e.setContent(html_24f98d4ff3ddf5f0c8910d6ec86939e7);
#
#
#
#         marker_a86f3b4dc70411e01cdff766f02d96ad.bindPopup(popup_ae355456b2f7a4c0ca8adc2e1e95340e)
#         ;
#
#
#
#
#             var marker_09da7a7a89d2a60ebbdd69f9f3983348 = L.marker(
#                 [40.4437132, -104.6987994],
#                 {}
#             ).addTo(map_a49594fbcc02a5214067bcb63cc1fe21);
#
#
#         var popup_17849e5157582d2f691824854de209df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85353c15d02825836bb420141a1c6f35 = $(`&lt;div id=&quot;html_85353c15d02825836bb420141a1c6f35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WELD FOOD BANK&lt;/strong&gt;&lt;br&gt;     1108 H St&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 356-2199&lt;br&gt;     Website: &lt;a href=&quot;http://weldfoodbank.org/and-food-near-you&quot;&gt;WELD FOOD BANK&lt;/a&gt;&lt;br&gt;     Services: Offers mobile food pantries at locations throughout Weld County.     &lt;/div&gt;`)[0];
#                 popup_17849e5157582d2f691824854de209df.setContent(html_85353c15d02825836bb420141a1c6f35);
#
#
#
#         marker_09da7a7a89d2a60ebbdd69f9f3983348.bindPopup(popup_17849e5157582d2f691824854de209df)
#         ;
#
#
#
#
#             var marker_68cdb421f918d17bf3527352ac21cbac = L.marker(
#                 [40.4437132, -104.6987994],
#                 {}
#             ).addTo(map_a49594fbcc02a5214067bcb63cc1fe21);
#
#
#         var popup_9a61867735cd528267ff008d2d37d5b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b307f97fb57ad4c78957270d90f9eaf = $(`&lt;div id=&quot;html_3b307f97fb57ad4c78957270d90f9eaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WELD FOOD BANK&lt;/strong&gt;&lt;br&gt;     1108 H Street&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     Phone: (970) 356-2199&lt;br&gt;     Website: &lt;a href=&quot;http://weldfoodbank.org/and-food-near-you&quot;&gt;WELD FOOD BANK&lt;/a&gt;&lt;br&gt;     Services: Offers mobile food pantries at locations throughout Weld County.     &lt;/div&gt;`)[0];
#                 popup_9a61867735cd528267ff008d2d37d5b8.setContent(html_3b307f97fb57ad4c78957270d90f9eaf);
#
#
#
#         marker_68cdb421f918d17bf3527352ac21cbac.bindPopup(popup_9a61867735cd528267ff008d2d37d5b8)
#         ;
#
#
#
#
#             var marker_ee47ca1faa04075df3cb92eb60fb4faa = L.marker(
#                 [40.4209079, -104.6925472],
#                 {}
#             ).addTo(map_a49594fbcc02a5214067bcb63cc1fe21);
#
#
#         var popup_c0465648b666f0358ee708c7d93c7e29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb70bb7fae85069acfb96dae1f47c47a = $(`&lt;div id=&quot;html_bb70bb7fae85069acfb96dae1f47c47a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ST PETER ROMAN CATHOLIC CHURCH&lt;/strong&gt;&lt;br&gt;     1112 9th Ave&lt;br&gt;     Greeley, CO 80631

# %%
# Example: Search for food pantries in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_pueblo.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03df96de441e04d2fa68a1388dd8a7ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03df96de441e04d2fa68a1388dd8a7ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03df96de441e04d2fa68a1388dd8a7ef = L.map(
#                 &quot;map_03df96de441e04d2fa68a1388dd8a7ef&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51306cca9be046ca6d1c0526be8e7a19 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_51306cca9be046ca6d1c0526be8e7a19.addTo(map_03df96de441e04d2fa68a1388dd8a7ef);
#
#
#             var marker_f1443ad6eaf23ea2582128b26f6f8d03 = L.marker(
#                 [38.274091, -104.6197],
#                 {}
#             ).addTo(map_03df96de441e04d2fa68a1388dd8a7ef);
#
#
#         var popup_8a5ddcada69a7e4290755126a0788eec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_103d5abce8ad3c39557f38939d003f27 = $(`&lt;div id=&quot;html_103d5abce8ad3c39557f38939d003f27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CENTER TOWARD SELF-RELIANCE&lt;/strong&gt;&lt;br&gt;     901 W 8th St&lt;br&gt;     Pueblo, CO 81003&lt;br&gt;     Phone: (719) 546-1271&lt;br&gt;     Website: &lt;a href=&quot;https://cfdpueblo.org&quot;&gt;CENTER TOWARD SELF-RELIANCE&lt;/a&gt;&lt;br&gt;     Services: Food Pantry provides food assistance to low-income individuals who are in need     &lt;/div&gt;`)[0];
#                 popup_8a5ddcada69a7e4290755126a0788eec.setContent(html_103d5abce8ad3c39557f38939d003f27);
#
#
#
#         marker_f1443ad6eaf23ea2582128b26f6f8d03.bindPopup(popup_8a5ddcada69a7e4290755126a0788eec)
#         ;
#
#
#
#
#             var marker_1317f8cf55906f95303a1b3343d7710b = L.marker(
#                 [38.2631861, -104.6371719],
#                 {}
#             ).addTo(map_03df96de441e04d2fa68a1388dd8a7ef);
#
#
#         var popup_e002097f35d733eb2c0e99596ea9fc82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1452a649a01531b065235199774a94d1 = $(`&lt;div id=&quot;html_1452a649a01531b065235199774a94d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/strong&gt;&lt;br&gt;     900 W Orman Ave&lt;br&gt;     Pueblo, CO 81004&lt;br&gt;     Phone: (719) 296-6995&lt;br&gt;     Website: &lt;a href=&quot;https://careandshare.org&quot;&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/a&gt;&lt;br&gt;     Services: Food Pantry providing food to those in need.     &lt;/div&gt;`)[0];
#                 popup_e002097f35d733eb2c0e99596ea9fc82.setContent(html_1452a649a01531b065235199774a94d1);
#
#
#
#         marker_1317f8cf55906f95303a1b3343d7710b.bindPopup(popup_e002097f35d733eb2c0e99596ea9fc82)
#         ;
#
#
#
#
#             var marker_75d968b4ec9ea86f0118c0defe408ac4 = L.marker(
#                 [38.327273, -104.77256],
#                 {}
#             ).addTo(map_03df96de441e04d2fa68a1388dd8a7ef);
#
#
#         var popup_a25ade4c5835bd9c1d3155b2d7ae37e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_261f72c31aa330e69df152c8acfadb38 = $(`&lt;div id=&quot;html_261f72c31aa330e69df152c8acfadb38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/strong&gt;&lt;br&gt;     434 S Conquistador Ave&lt;br&gt;     Pueblo West, CO 81007&lt;br&gt;     Phone: (719) 547-3088&lt;br&gt;     Website: &lt;a href=&quot;No Website Listed&quot;&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/a&gt;&lt;br&gt;     Services: Food Pantry providing food to those in need.     &lt;/div&gt;`)[0];
#                 popup_a25ade4c5835bd9c1d3155b2d7ae37e8.setContent(html_261f72c31aa330e69df152c8acfadb38);
#
#
#
#         marker_75d968b4ec9ea86f0118c0defe408ac4.bindPopup(popup_a25ade4c5835bd9c1d3155b2d7ae37e8)
#         ;
#
#
#
#
#             var marker_c9ff46c3fec3ea8a74ed6755a3b88235 = L.marker(
#                 [38.2239923, -104.6567669],
#                 {}
#             ).addTo(map_03df96de441e04d2fa68a1388dd8a7ef);
#
#
#         var popup_61dc103e462c9a450a7df162d5ce3dc5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42de41fa57000159ef8bfbbb898dd814 = $(`&lt;div id=&quot;html_42de41fa57000159ef8bfbbb898dd814&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/strong&gt;&lt;br&gt;     3804 W Pueblo Blvd&lt;br&gt;     Pueblo, CO 81005&lt;br&gt;     Phone: (719) 5

# %%
# Example: Search for food pantries in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_boulder.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2da5e638f540348b882b1758b2e9338 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2da5e638f540348b882b1758b2e9338&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2da5e638f540348b882b1758b2e9338 = L.map(
#                 &quot;map_d2da5e638f540348b882b1758b2e9338&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56c87678efa771aa779b5b38ac45373b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_56c87678efa771aa779b5b38ac45373b.addTo(map_d2da5e638f540348b882b1758b2e9338);
#
#
#             var marker_b2e28ab91482774461b6664e593a3424 = L.marker(
#                 [40.102555, -105.3632079],
#                 {}
#             ).addTo(map_d2da5e638f540348b882b1758b2e9338);
#
#
#         var popup_2020f2eaa25f039cfc0387525051d537 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_751fa2f1864e5b8fdd900dc885b51331 = $(`&lt;div id=&quot;html_751fa2f1864e5b8fdd900dc885b51331&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COLORADO PET PANTRY&lt;/strong&gt;&lt;br&gt;     P.O. Box 323&lt;br&gt;     Boulder, CO 80306&lt;br&gt;     Phone: (303) 818-0618&lt;br&gt;     Website: &lt;a href=&quot;http://coloradopetpantry.org/events/category/pet-food-banks/&quot;&gt;COLORADO PET PANTRY&lt;/a&gt;&lt;br&gt;     Services: Provides free temporary pet food through various food pantry organizations throughout Colorado.     &lt;/div&gt;`)[0];
#                 popup_2020f2eaa25f039cfc0387525051d537.setContent(html_751fa2f1864e5b8fdd900dc885b51331);
#
#
#
#         marker_b2e28ab91482774461b6664e593a3424.bindPopup(popup_2020f2eaa25f039cfc0387525051d537)
#         ;
#
#
#
#
#             var marker_151de10d36084e4faab2ac91f682be6e = L.marker(
#                 [40.058333, -105.2778705],
#                 {}
#             ).addTo(map_d2da5e638f540348b882b1758b2e9338);
#
#
#         var popup_ee8463834b441bc2f6f3c8b8a73c71e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6dc6f8548c06164b2320c952890d378e = $(`&lt;div id=&quot;html_6dc6f8548c06164b2320c952890d378e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;EMERGENCY FAMILY ASSISTANCE ASSOCIATION&lt;/strong&gt;&lt;br&gt;     1575 Yarmouth Ave&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     Phone: (303) 442-3042&lt;br&gt;     Website: &lt;a href=&quot;http://efaa.org/get-help/food-bank/&quot;&gt;EMERGENCY FAMILY ASSISTANCE ASSOCIATION&lt;/a&gt;&lt;br&gt;     Services: Provides a food pantry to people living in the City of Boulder and Boulder County Mountain Communities with access to a kitchen. Eligible households may visit the food bank twice per month...     &lt;/div&gt;`)[0];
#                 popup_ee8463834b441bc2f6f3c8b8a73c71e8.setContent(html_6dc6f8548c06164b2320c952890d378e);
#
#
#
#         marker_151de10d36084e4faab2ac91f682be6e.bindPopup(popup_ee8463834b441bc2f6f3c8b8a73c71e8)
#         ;
#
#
#
#
#             var marker_71a39fc02393a50d3975bf93433d96d4 = L.marker(
#                 [39.990138, -105.232704],
#                 {}
#             ).addTo(map_d2da5e638f540348b882b1758b2e9338);
#
#
#         var popup_9cc17c0ff3781cce6f23201b8c890bec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b945879da4e6c25eafef7cc9602c2b7e = $(`&lt;div id=&quot;html_b945879da4e6c25eafef7cc9602c2b7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY FOOD SHARE&lt;/strong&gt;&lt;br&gt;     4990 Osage Dr&lt;br&gt;     Boulder, CO 80303&lt;br&gt;     Phone: (303) 652-3663&lt;br&gt;     Website: &lt;a href=&quot;http://communityfoodshare.org/get-food/services-we-provide/mobile-pantries/&quot;&gt;COMMUNITY FOOD SHARE&lt;/a&gt;&lt;br&gt;     Services: Operates a mobile food pantry at rotating locations, offering: Fresh produce Dairy Non-perishable pantry items     &lt;/div&gt;`)[0];
#                 popup_9cc17c0ff3781cce6f23201b8c890bec.setContent(html_b945879da4e6c25eafef7cc9602c2b7e);
#
#
#
#         marker_71a39fc02393a50d3975bf93433d96d4.bindPopup(popup_9cc17c0ff3781cce6f23201b8c890bec)
#         ;
#
#
#
#
#             var marker_936b7a5f06f053f58d55d7b75c34d5d2 = L.marker(
#                 [40.0625882, -105.282615],
#                 {}
#             ).addTo(map_d2da5e638f540348b882b1758b2e9338);
#
#
#         var popup_9c6d47e824db9a9d2dbbb3f26e613bb8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_848624c4bc54b6620d8ef91136d63745 = $(`&lt;div id=&quot;html_8

# %%
# Example: Search for food pantries in a specific city
city_search = "Grand Junction"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    Phone: {row['Phone']}<br>
    Website: <a href="{row['Website']}">{row['Agency']}</a><br>
    Services: {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_grand_junction.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48065beb9c4c7c01c1c3a55c783f5c6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48065beb9c4c7c01c1c3a55c783f5c6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48065beb9c4c7c01c1c3a55c783f5c6f = L.map(
#                 &quot;map_48065beb9c4c7c01c1c3a55c783f5c6f&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b277b39d814efd358e8cea47133c1cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0b277b39d814efd358e8cea47133c1cd.addTo(map_48065beb9c4c7c01c1c3a55c783f5c6f);
#
#
#             var marker_991fbab01c74ae52432605e2153ee3a4 = L.marker(
#                 [39.0655869, -108.5712505],
#                 {}
#             ).addTo(map_48065beb9c4c7c01c1c3a55c783f5c6f);
#
#
#         var popup_32794ec78b117a9e32d9cc01415badbf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24484ed78be05bb71f5f1727c597692c = $(`&lt;div id=&quot;html_24484ed78be05bb71f5f1727c597692c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/strong&gt;&lt;br&gt;     245 S 1st St&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     Phone: (970) 241-3658&lt;br&gt;     Website: &lt;a href=&quot;http://catholicoutreach.org&quot;&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/a&gt;&lt;br&gt;     Services: Provides food box for Mesa County residents in need on a once-a-month basis. Food type is available depending on donated items available...     &lt;/div&gt;`)[0];
#                 popup_32794ec78b117a9e32d9cc01415badbf.setContent(html_24484ed78be05bb71f5f1727c597692c);
#
#
#
#         marker_991fbab01c74ae52432605e2153ee3a4.bindPopup(popup_32794ec78b117a9e32d9cc01415badbf)
#         ;
#
#
#
#
#             var marker_d128b58ff692b1e9a9a0471b01432bf1 = L.marker(
#                 [39.0415079, -108.5435434],
#                 {}
#             ).addTo(map_48065beb9c4c7c01c1c3a55c783f5c6f);
#
#
#         var popup_b648e16403a6a68b5df385e9e6dcf5ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb02719477aadf7d3f2afcec36659fcd = $(`&lt;div id=&quot;html_fb02719477aadf7d3f2afcec36659fcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ORCHARD MESA BAPTIST CHURCH&lt;/strong&gt;&lt;br&gt;     2748 B 1/2 Rd&lt;br&gt;     Grand Junction, CO 81503&lt;br&gt;     Phone: (970) 242-2355&lt;br&gt;     Website: &lt;a href=&quot;http://ombcgj.com/&quot;&gt;ORCHARD MESA BAPTIST CHURCH&lt;/a&gt;&lt;br&gt;     Services: Provides a food box to those in need once a month and up to 3 times per calendar year. Additional assistance can be granted on case by case basis by the food pantry director...     &lt;/div&gt;`)[0];
#                 popup_b648e16403a6a68b5df385e9e6dcf5ad.setContent(html_fb02719477aadf7d3f2afcec36659fcd);
#
#
#
#         marker_d128b58ff692b1e9a9a0471b01432bf1.bindPopup(popup_b648e16403a6a68b5df385e9e6dcf5ad)
#         ;
#
#
#
#
#             var marker_c86da7c9a549a59894b462692b08de9b = L.marker(
#                 [39.0842939, -108.5210788],
#                 {}
#             ).addTo(map_48065beb9c4c7c01c1c3a55c783f5c6f);
#
#
#         var popup_aa36bc09c3c3e3989dfe1bc517210fb5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7c95a8b023248d2ea9591fdb048d536 = $(`&lt;div id=&quot;html_f7c95a8b023248d2ea9591fdb048d536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;JUNCTION COMMUNITY CHURCH&lt;/strong&gt;&lt;br&gt;     2867 Orchard Ave&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     Phone: (970) 243-0757&lt;br&gt;     Website: &lt;a href=&quot;http://jctcc.net/saras-pantry&quot;&gt;JUNCTION COMMUNITY CHURCH&lt;/a&gt;&lt;br&gt;     Services: Provides a food box to individuals, seniors and families in need in the community. Families are limited to one box a month.     &lt;/div&gt;`)[0];
#                 popup_aa36bc09c3c3e3989dfe1bc517210fb5.setContent(html_f7c95a8b023248d2ea9591fdb048d536);
#
#
#
#         marker_c86da7c9a549a59894b462692b08de9b.bindPopup(popup_aa36bc09c3c3e3989dfe1bc517210fb5)
#         ;
#
#
#
#
#             var marker_a7ba5b78acd09306b71819ac4948c113 = L.marker(
#                 [39.073337, -108.5719646],
#                 {}
#             ).addTo(map_48065beb9c4c7c01c1c3a55c783f5c6f);
#
#
#         var popup_f699e8a556f3127a30b56e7d5013b1d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99338c0a887afd76d45c04c005025c36 = $(`&lt;div id=&quot;html_99338c0a887afd76d45c04

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_food_pantries_v2.csv", index=False)

# Confirm the export
print("Data exported to cleaned_colorado_food_pantries_v2.csv")
# Out:
# Data exported to cleaned_colorado_food_pantries_v2.csv
