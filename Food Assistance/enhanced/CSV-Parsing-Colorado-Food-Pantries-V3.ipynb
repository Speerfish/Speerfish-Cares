# %% [markdown]
# # Jupyter Notebook: Parsing CSV file and Visualizing Data

# %% [markdown]
# In this notebook, we will load a CSV file, convert it to a pandas DataFrame, and then create multiple city specific map visualizations using folium.

# %%
pip install pandas folium
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: folium in /opt/homebrew/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: branca>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/homebrew/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /opt/homebrew/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2>=2.9->folium) (3.0.1)
# Requirement already satisfied: six>=1.5 in /Users/ceraven/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import folium

# %% [markdown]
# ## Step 1: Load CSV File

# %%
# Load the CSV file into a DataFrame
file_path = "colorado_food_pantries.csv"

df = pd.read_csv(file_path)

# Optional: Display the first few rows to check if the file is loaded correctly
df.head(15)
# Out:
#             Assistance Type  \
# 0               Food Pantry
# 1               Food Pantry
# 2               Food Pantry
# 3               Food Pantry
# 4               Food Pantry
# 5           Food Assistance
# 6               Food Pantry
# 7               Food Pantry
# 8               Food Pantry
# 9           Food Assistance
# 10              Food Pantry
# 11              Food Pantry
# 12              Food Pantry
# 13              Food Pantry
# 14  Pet Food Pantry Locator
#
#                                                Agency  \
# 0                SILVER THREAD PUBLIC HEALTH DISTRICT
# 1                                   PINE RIVER SHARES
# 2   COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SP...
# 3                              RESTORATION FELLOWSHIP
# 4                            OURAY COUNTY FOOD PANTRY
# 5                        LOVE INC OF THE YAMPA VALLEY
# 6                                  CONNECTIONS 4 LIFE
# 7                               GOD'S PANTRY MINISTRY
# 8                      GRAND VALLEY CATHOLIC OUTREACH
# 9                      WOODLAND PARK COMMUNITY CHURCH
# 10                  LA PLATA FAMILY CENTERS COALITION
# 11                        CENTER TOWARD SELF-RELIANCE
# 12                           CITY OF COLORADO SPRINGS
# 13                          NEW LIFE COMMUNITY CHURCH
# 14                                COLORADO PET PANTRY
#
#                          Address              City State    Zip  \
# 0                   304 W 3rd St         Lake City    CO  81235
# 1                  658 S East St          Bayfield    CO  81122
# 2                   434 Lewis St    Pagosa Springs    CO  81147
# 3                 264 Village Dr    Pagosa Springs    CO  81147
# 4                  602 N Cora St           Ridgway    CO  81432
# 5             1198 W Victory Way             Craig    CO  81625
# 6   6436 S U.S. Hwy 85/87 Unit U  Colorado Springs    CO  80911
# 7              30 Widefield Blvd  Colorado Springs    CO  80911
# 8                   245 S 1st St    Grand Junction    CO  81501
# 9      700 Valley View Dr Unit D     Woodland Park    CO  80863
# 10                495 Florida Rd           Durango    CO  81301
# 11                  901 W 8th St            Pueblo    CO  81003
# 12       4290 Deerfield Hills Rd  Colorado Springs    CO  80916
# 13             17690 E Iliff Ave            Aurora    CO  80013
# 14                  P.O. Box 323           Boulder    CO  80306
#
#               County                                           Services  \
# 0    HINSDALE COUNTY  Provides a food box to individuals, seniors an...
# 1    LA PLATA COUNTY  Provides food for community members in need of...
# 2   ARCHULETA COUNTY  Provides food to individuals and families in A...
# 3   ARCHULETA COUNTY  Provides food boxes for residents of Archuleta...
# 4       OURAY COUNTY  Provides groceries based on a shopping list fo...
# 5      MOFFAT COUNTY  Provides food to qualified individuals and fam...
# 6     EL PASO COUNTY       Provides a food pantry to residents in need.
# 7     EL PASO COUNTY                            Provides a food pantry.
# 8        MESA COUNTY  Provides food box for Mesa County residents in...
# 9      TELLER COUNTY  Provides emergency food necessities and delive...
# 10   LA PLATA COUNTY  Provides a food box to families in need in the...
# 11     PUEBLO COUNTY  Food Pantry provides food assistance to low-in...
# 12    EL PASO COUNTY  Provides a drive-thru style food pantry to tho...
# 13   ARAPAHOE COUNTY  Provides bags of food to the community. The pa...
# 14    BOULDER COUNTY  Provides free temporary pet food through vario...
#
#                                           Eligibility  \
# 0   Individuals in the service area Area Served: H...
# 1   Must be residents of Bayfield and the Pine Riv...
# 2   No restrictions applied Area Served: Archuleta...
# 3      No restrictions. Area Served: Archuleta County
# 4   Individuals must be a resident of Ouray County...
# 5   For TEFAP assistance, households must meet the...
# 6   Residents of the service area Area Served: El ...
# 7   No restrictions applied Area Served: El Paso C...
# 8    No restrictions applied Area Served: Mesa County
# 9   No restrictions applied Area Served: Zip Codes...
# 10  No restriction applied Area Served: La Plata, ...
# 11  Open to the Public, low-income individuals who...
# 12  No restrictions applied Area Served: El Paso C...
# 13  No restrictions applied Area Served: Adams, Ar...
# 14     No restrictions applied Area Served: Statewide
#
#                                                 Hours           Phone  \
# 0                 Monday - Friday, 8 a.m. - 4:30 p.m.  (970) 944-0321
# 1                  Monday - Thursday, 9 a.m. - 3 p.m.  (970) 884-6040
# 2                Tuesday - Thursday, 8 a.m. - 12 p.m.  (970) 264-5508
# 3                      Monday-Friday, 8:00am - 5:00pm  (970) 731-2937
# 4                        Thursday, 12:30 pm - 3:30 pm  (970) 626-4273
# 5   3rd Tuesday, 10 a.m. - 12 p.m.; 3rd Thursday, ...  (970) 826-4400
# 6                                          Hours Vary  (719) 387-9919
# 7                  Monday - Saturday, 9 a.m. - 3 p.m.  (719) 382-0643
# 8                Monday - Friday, 9 a.m. - 11:30 a.m.  (970) 241-3658
# 9                 Monday - Thursday, 9 a.m. - 12 p.m.  (719) 229-4512
# 10  Monday - Thursday, 8:30 a.m. - 4:30 p.m.; Frid...  (970) 385-4747
# 11                Monday - Friday, 8 a.m. - 4:30 p.m.  (719) 546-1271
# 12                   Monday - Friday, 9 a.m. - 6 p.m.  (719) 385-5996
# 13  Tuesday, 1 p.m. - 4 p.m.; Saturday, 10 a.m. - ...  (303) 368-7567
# 14  Monday - Sunday, 9 a.m. - 5 p.m. (Administrati...  (303) 818-0618
#
#                                               Website   Latitude   Longitude
# 0                 http://silverthreadpublichealth.org  38.028217 -107.314490
# 1                          http://pinerivershares.org  37.224047 -107.598306
# 2                                   http://cumcps.org  37.267823 -107.011796
# 3                    http://restorationfellowship.net  37.258096 -107.075037
# 4                    http://ouraycountyfoodpantry.org  38.156621 -107.757265
# 5              http://loveincyampavalley.org/services  40.514264 -107.561261
# 6                   http://connections4lifecenter.org  38.745604 -104.738987
# 7                             http://godspantryco.org  38.736079 -104.727113
# 8                         http://catholicoutreach.org  39.065587 -108.571251
# 9   http://woodlandparkcommunitychurch.com/storehouse  39.012142 -105.062023
# 10                                   http://lpfcc.org  37.283861 -107.869957
# 11                              https://cfdpueblo.org  38.274091 -104.619700
# 12  http://coloradosprings.gov/deeraeld-hills-comm...  38.784574 -104.747881
# 13                              http://nlccaurora.org  39.674607 -104.778200
# 14  http://coloradopetpantry.org/events/category/p...  40.102555 -105.363208

# %% [markdown]
# ## Step 2: Clean and Prepare the Data

# %%
# Check column names and data types
df.info()

# Clean any missing latitude or longitude data
df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Optional: Check for missing values in other important columns
df.isnull().sum()

# Optional: Display the first few rows of cleaned data
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Assistance Type  443 non-null    object
#  1   Agency           443 non-null    object
#  2   Address          443 non-null    object
#  3   City             443 non-null    object
#  4   State            443 non-null    object
#  5   Zip              443 non-null    int64
#  6   County           443 non-null    object
#  7   Services         443 non-null    object
#  8   Eligibility      443 non-null    object
#  9   Hours            443 non-null    object
#  10  Phone            443 non-null    object
#  11  Website          443 non-null    object
#  12  Latitude         443 non-null    float64
#  13  Longitude        443 non-null    float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 48.6+ KB
#             Assistance Type  \
# 0               Food Pantry
# 1               Food Pantry
# 2               Food Pantry
# 3               Food Pantry
# 4               Food Pantry
# 5           Food Assistance
# 6               Food Pantry
# 7               Food Pantry
# 8               Food Pantry
# 9           Food Assistance
# 10              Food Pantry
# 11              Food Pantry
# 12              Food Pantry
# 13              Food Pantry
# 14  Pet Food Pantry Locator
#
#                                                Agency  \
# 0                SILVER THREAD PUBLIC HEALTH DISTRICT
# 1                                   PINE RIVER SHARES
# 2   COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SP...
# 3                              RESTORATION FELLOWSHIP
# 4                            OURAY COUNTY FOOD PANTRY
# 5                        LOVE INC OF THE YAMPA VALLEY
# 6                                  CONNECTIONS 4 LIFE
# 7                               GOD'S PANTRY MINISTRY
# 8                      GRAND VALLEY CATHOLIC OUTREACH
# 9                      WOODLAND PARK COMMUNITY CHURCH
# 10                  LA PLATA FAMILY CENTERS COALITION
# 11                        CENTER TOWARD SELF-RELIANCE
# 12                           CITY OF COLORADO SPRINGS
# 13                          NEW LIFE COMMUNITY CHURCH
# 14                                COLORADO PET PANTRY
#
#                          Address              City State    Zip  \
# 0                   304 W 3rd St         Lake City    CO  81235
# 1                  658 S East St          Bayfield    CO  81122
# 2                   434 Lewis St    Pagosa Springs    CO  81147
# 3                 264 Village Dr    Pagosa Springs    CO  81147
# 4                  602 N Cora St           Ridgway    CO  81432
# 5             1198 W Victory Way             Craig    CO  81625
# 6   6436 S U.S. Hwy 85/87 Unit U  Colorado Springs    CO  80911
# 7              30 Widefield Blvd  Colorado Springs    CO  80911
# 8                   245 S 1st St    Grand Junction    CO  81501
# 9      700 Valley View Dr Unit D     Woodland Park    CO  80863
# 10                495 Florida Rd           Durango    CO  81301
# 11                  901 W 8th St            Pueblo    CO  81003
# 12       4290 Deerfield Hills Rd  Colorado Springs    CO  80916
# 13             17690 E Iliff Ave            Aurora    CO  80013
# 14                  P.O. Box 323           Boulder    CO  80306
#
#               County                                           Services  \
# 0    HINSDALE COUNTY  Provides a food box to individuals, seniors an...
# 1    LA PLATA COUNTY  Provides food for community members in need of...
# 2   ARCHULETA COUNTY  Provides food to individuals and families in A...
# 3   ARCHULETA COUNTY  Provides food boxes for residents of Archuleta...
# 4       OURAY COUNTY  Provides groceries based on a shopping list fo...
# 5      MOFFAT COUNTY  Provides food to qualified individuals and fam...
# 6     EL PASO COUNTY       Provides a food pantry to residents in need.
# 7     EL PASO COUNTY                            Provides a food pantry.
# 8        MESA COUNTY  Provides food box for Mesa County residents in...
# 9      TELLER COUNTY  Provides emergency food necessities and delive...
# 10   LA PLATA COUNTY  Provides a food box to families in need in the...
# 11     PUEBLO COUNTY  Food Pantry provides food assistance to low-in...
# 12    EL PASO COUNTY  Provides a drive-thru style food pantry to tho...
# 13   ARAPAHOE COUNTY  Provides bags of food to the community. The pa...
# 14    BOULDER COUNTY  Provides free temporary pet food through vario...
#
#                                           Eligibility  \
# 0   Individuals in the service area Area Served: H...
# 1   Must be residents of Bayfield and the Pine Riv...
# 2   No restrictions applied Area Served: Archuleta...
# 3      No restrictions. Area Served: Archuleta County
# 4   Individuals must be a resident of Ouray County...
# 5   For TEFAP assistance, households must meet the...
# 6   Residents of the service area Area Served: El ...
# 7   No restrictions applied Area Served: El Paso C...
# 8    No restrictions applied Area Served: Mesa County
# 9   No restrictions applied Area Served: Zip Codes...
# 10  No restriction applied Area Served: La Plata, ...
# 11  Open to the Public, low-income individuals who...
# 12  No restrictions applied Area Served: El Paso C...
# 13  No restrictions applied Area Served: Adams, Ar...
# 14     No restrictions applied Area Served: Statewide
#
#                                                 Hours           Phone  \
# 0                 Monday - Friday, 8 a.m. - 4:30 p.m.  (970) 944-0321
# 1                  Monday - Thursday, 9 a.m. - 3 p.m.  (970) 884-6040
# 2                Tuesday - Thursday, 8 a.m. - 12 p.m.  (970) 264-5508
# 3                      Monday-Friday, 8:00am - 5:00pm  (970) 731-2937
# 4                        Thursday, 12:30 pm - 3:30 pm  (970) 626-4273
# 5   3rd Tuesday, 10 a.m. - 12 p.m.; 3rd Thursday, ...  (970) 826-4400
# 6                                          Hours Vary  (719) 387-9919
# 7                  Monday - Saturday, 9 a.m. - 3 p.m.  (719) 382-0643
# 8                Monday - Friday, 9 a.m. - 11:30 a.m.  (970) 241-3658
# 9                 Monday - Thursday, 9 a.m. - 12 p.m.  (719) 229-4512
# 10  Monday - Thursday, 8:30 a.m. - 4:30 p.m.; Frid...  (970) 385-4747
# 11                Monday - Friday, 8 a.m. - 4:30 p.m.  (719) 546-1271
# 12                   Monday - Friday, 9 a.m. - 6 p.m.  (719) 385-5996
# 13  Tuesday, 1 p.m. - 4 p.m.; Saturday, 10 a.m. - ...  (303) 368-7567
# 14  Monday - Sunday, 9 a.m. - 5 p.m. (Administrati...  (303) 818-0618
#
#                                               Website   Latitude   Longitude
# 0                 http://silverthreadpublichealth.org  38.028217 -107.314490
# 1                          http://pinerivershares.org  37.224047 -107.598306
# 2                                   http://cumcps.org  37.267823 -107.011796
# 3                    http://restorationfellowship.net  37.258096 -107.075037
# 4                    http://ouraycountyfoodpantry.org  38.156621 -107.757265
# 5              http://loveincyampavalley.org/services  40.514264 -107.561261
# 6                   http://connections4lifecenter.org  38.745604 -104.738987
# 7                             http://godspantryco.org  38.736079 -104.727113
# 8                         http://catholicoutreach.org  39.065587 -108.571251
# 9   http://woodlandparkcommunitychurch.com/storehouse  39.012142 -105.062023
# 10                                   http://lpfcc.org  37.283861 -107.869957
# 11                              https://cfdpueblo.org  38.274091 -104.619700
# 12  http://coloradosprings.gov/deeraeld-hills-comm...  38.784574 -104.747881
# 13                              http://nlccaurora.org  39.674607 -104.778200
# 14  http://coloradopetpantry.org/events/category/p...  40.102555 -105.363208

# %% [markdown]
# ## Step 3: Create a Searchable Map

# %%
# Initialize the map centered around Colorado
m = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

# Add markers to the map for each food pantry
for idx, row in df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m)

# Save the map as an HTML file
m.save("colorado_food_pantries_map_v2.html")

# Display the map in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acef65d7b1dbd9c26721cb8add3f9ee1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acef65d7b1dbd9c26721cb8add3f9ee1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acef65d7b1dbd9c26721cb8add3f9ee1 = L.map(
#                 &quot;map_acef65d7b1dbd9c26721cb8add3f9ee1&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56b6e35d40218c05a081fa9536ac80e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_56b6e35d40218c05a081fa9536ac80e2.addTo(map_acef65d7b1dbd9c26721cb8add3f9ee1);
#
#
#             var marker_6e410fa8ecd77528a101a346d14221e9 = L.marker(
#                 [38.028217, -107.31449],
#                 {}
#             ).addTo(map_acef65d7b1dbd9c26721cb8add3f9ee1);
#
#
#         var popup_6da9bae54935cb04a3ef329d1a29036f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a5f641175315cc136ef44ce3542196a = $(`&lt;div id=&quot;html_0a5f641175315cc136ef44ce3542196a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SILVER THREAD PUBLIC HEALTH DISTRICT&lt;/strong&gt;&lt;br&gt;     304 W 3rd St&lt;br&gt;     Lake City, CO 81235&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 944-0321&quot;&gt;(970) 944-0321&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://silverthreadpublichealth.org&quot;&gt;SILVER THREAD PUBLIC HEALTH DISTRICT&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a food box to individuals, seniors and families in need.     &lt;/div&gt;`)[0];
#                 popup_6da9bae54935cb04a3ef329d1a29036f.setContent(html_0a5f641175315cc136ef44ce3542196a);
#
#
#
#         marker_6e410fa8ecd77528a101a346d14221e9.bindPopup(popup_6da9bae54935cb04a3ef329d1a29036f)
#         ;
#
#
#
#
#             var marker_8517f0b708979272593e80bcebc23219 = L.marker(
#                 [37.2240474, -107.5983059],
#                 {}
#             ).addTo(map_acef65d7b1dbd9c26721cb8add3f9ee1);
#
#
#         var popup_3b113412aadcaff220482611096d136f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41c8a07cc3260712ecb1e304dcbf66f5 = $(`&lt;div id=&quot;html_41c8a07cc3260712ecb1e304dcbf66f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;PINE RIVER SHARES&lt;/strong&gt;&lt;br&gt;     658 S East St&lt;br&gt;     Bayfield, CO 81122&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 884-6040&quot;&gt;(970) 884-6040&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://pinerivershares.org&quot;&gt;PINE RIVER SHARES&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides food for community members in need of assistance. Also offers a backpack of food for students attending the following schools to take home every weekend: Bayfield Elementary School Bayfield Primary SchoolIgnacio Elementary Schoo...     &lt;/div&gt;`)[0];
#                 popup_3b113412aadcaff220482611096d136f.setContent(html_41c8a07cc3260712ecb1e304dcbf66f5);
#
#
#
#         marker_8517f0b708979272593e80bcebc23219.bindPopup(popup_3b113412aadcaff220482611096d136f)
#         ;
#
#
#
#
#             var marker_e40c1102bf640c91c01d9db78b0de48f = L.marker(
#                 [37.2678233, -107.0117959],
#                 {}
#             ).addTo(map_acef65d7b1dbd9c26721cb8add3f9ee1);
#
#
#         var popup_9f69bd366a1b1f29bc2e7aea310731f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4af4e8c144e8ef86b1155729b08c5e83 = $(`&lt;div id=&quot;html_4af4e8c144e8ef86b1155729b08c5e83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SPRINGS&lt;/strong&gt;&lt;br&gt;     434 Lewis St&lt;br&gt;     Pagosa Springs, CO 81147&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 264-5508&quot;&gt;(970) 264-5508&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://cumcps.org&quot;&gt;COMMUNITY UNITED METHODIST CHURCH OF PAGOSA SPRINGS&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides food to individuals and families in Archuleta County who are in need. Services limited to one time a week per individual.     &lt;/div&gt;`)[0];
#                 popup_9f69bd366a1b1f29bc2e7aea310731f4.setContent(html_4af4e8c144e8ef86b1155729b08c5e83);
#
#
#
#         marker_e40c1102bf640c91c01d9db78b0de48f.bindPopup(popup_9f69bd366a1b1f29bc2e7aea310731f4)
#         ;

# %% [markdown]
# ## Step 4: Implement Search Functionality

# %%
# Example: Search for food pantries in a specific city
city_search = "Denver"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.5501, -105.7821], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_denver_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_212d2dc23a025a76d4057798c3a14974 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_212d2dc23a025a76d4057798c3a14974&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_212d2dc23a025a76d4057798c3a14974 = L.map(
#                 &quot;map_212d2dc23a025a76d4057798c3a14974&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2457b1f6d4f7c9fceba15f04e234492 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2457b1f6d4f7c9fceba15f04e234492.addTo(map_212d2dc23a025a76d4057798c3a14974);
#
#
#             var marker_8881b8eff7317da970811526495cbd55 = L.marker(
#                 [39.7446234, -104.9730507],
#                 {}
#             ).addTo(map_212d2dc23a025a76d4057798c3a14974);
#
#
#         var popup_b6c13fc43403134071cfc18882d336f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c47cc890f98e510e2b7169af307de516 = $(`&lt;div id=&quot;html_c47cc890f98e510e2b7169af307de516&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;METRO CARING&lt;/strong&gt;&lt;br&gt;     1100 E 18th Ave&lt;br&gt;     Denver, CO 80218&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 860-7200&quot;&gt;(303) 860-7200&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://metrocaring.org/fresh-foods-market&quot;&gt;METRO CARING&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a fresh food market where the community can choose from an array of nutritious foods, including: Fresh fruits and vegetables Whole grains Dairy Lean protein Baby formula and diapers are offered when they&#x27;re available…     &lt;/div&gt;`)[0];
#                 popup_b6c13fc43403134071cfc18882d336f0.setContent(html_c47cc890f98e510e2b7169af307de516);
#
#
#
#         marker_8881b8eff7317da970811526495cbd55.bindPopup(popup_b6c13fc43403134071cfc18882d336f0)
#         ;
#
#
#
#
#             var marker_9d5089177752c7571bb3db844398d3e9 = L.marker(
#                 [39.6614613, -104.9122488],
#                 {}
#             ).addTo(map_212d2dc23a025a76d4057798c3a14974);
#
#
#         var popup_dae885f24c17af62e35b85543345579f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4d61ce7cc734ad386532ab0670f5d87 = $(`&lt;div id=&quot;html_f4d61ce7cc734ad386532ab0670f5d87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     3060 S Monaco St Pkwy&lt;br&gt;     Denver, CO 80222&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 375-5853&quot;&gt;(303) 375-5853&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://foodbankrockies.org&quot;&gt;FOOD BANK OF THE ROCKIES&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides food to communities by sending semi-trucks to set locations and distributing food for 1-2 hours.     &lt;/div&gt;`)[0];
#                 popup_dae885f24c17af62e35b85543345579f.setContent(html_f4d61ce7cc734ad386532ab0670f5d87);
#
#
#
#         marker_9d5089177752c7571bb3db844398d3e9.bindPopup(popup_dae885f24c17af62e35b85543345579f)
#         ;
#
#
#
#
#             var marker_70faf676a3907fae02d8f92b048ca4ff = L.marker(
#                 [39.7260565, -105.0501581],
#                 {}
#             ).addTo(map_212d2dc23a025a76d4057798c3a14974);
#
#
#         var popup_99bdbfeb66c35bce4b34633073e820a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_100122d6652187ad0fae32b243b3dafe = $(`&lt;div id=&quot;html_100122d6652187ad0fae32b243b3dafe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     13300 W 6th Ave&lt;br&gt;     Denver, CO 80215&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 375-5853&quot;&gt;(303) 375-5853&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://foodbankrockies.org&quot;&gt;FOOD BANK OF THE ROCKIES&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides food to communities by sending semi-trucks to set locations and distributing food for 1-2 hours.     &lt;/div&gt;`)[0];
#                 popup_99bdbfeb66c35bce4b34633073e820a8.setContent(html_100122d6652187ad0fae32b243b3dafe);
#
#
#
#         marker_70faf676a3907fae02d8f92b048ca4ff.bindPopup(popup_99bdbfeb66c35bce4b34633073e820a8)
#         ;
#
#
#
#
#             var marker_d4852a11290e7b2d173ffb8f7fa

# %%
# Example: Search for food pantries in a specific city
city_search = "Colorado Springs"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.8591, -104.8135], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_colorado_springs_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f57f7705dbb8733ec4dbbd45f105fd32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f57f7705dbb8733ec4dbbd45f105fd32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f57f7705dbb8733ec4dbbd45f105fd32 = L.map(
#                 &quot;map_f57f7705dbb8733ec4dbbd45f105fd32&quot;,
#                 {
#                     center: [38.8591, -104.8135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec1b3bd4e5cd2771f98692d57c4d715d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ec1b3bd4e5cd2771f98692d57c4d715d.addTo(map_f57f7705dbb8733ec4dbbd45f105fd32);
#
#
#             var marker_ae019aff202ab12eeaead82f7aee250c = L.marker(
#                 [38.745604, -104.738987],
#                 {}
#             ).addTo(map_f57f7705dbb8733ec4dbbd45f105fd32);
#
#
#         var popup_3a99b1aeca4bbb68a16e7a3ace03b2cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37f36ebfe30faaea98f3db7c61733f10 = $(`&lt;div id=&quot;html_37f36ebfe30faaea98f3db7c61733f10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CONNECTIONS 4 LIFE&lt;/strong&gt;&lt;br&gt;     6436 S U.S. Hwy 85/87 Unit U&lt;br&gt;     Colorado Springs, CO 80911&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 387-9919&quot;&gt;(719) 387-9919&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://connections4lifecenter.org&quot;&gt;CONNECTIONS 4 LIFE&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a food pantry to residents in need.     &lt;/div&gt;`)[0];
#                 popup_3a99b1aeca4bbb68a16e7a3ace03b2cc.setContent(html_37f36ebfe30faaea98f3db7c61733f10);
#
#
#
#         marker_ae019aff202ab12eeaead82f7aee250c.bindPopup(popup_3a99b1aeca4bbb68a16e7a3ace03b2cc)
#         ;
#
#
#
#
#             var marker_bc07c815850a1154d63dcbea3e1eb56f = L.marker(
#                 [38.7360794, -104.7271127],
#                 {}
#             ).addTo(map_f57f7705dbb8733ec4dbbd45f105fd32);
#
#
#         var popup_52842327355bd43c0b5b195e5b6a7732 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a48aecd312f7fb8f3757daa9d3ad24b4 = $(`&lt;div id=&quot;html_a48aecd312f7fb8f3757daa9d3ad24b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GOD&#x27;S PANTRY MINISTRY&lt;/strong&gt;&lt;br&gt;     30 Widefield Blvd&lt;br&gt;     Colorado Springs, CO 80911&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 382-0643&quot;&gt;(719) 382-0643&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://godspantryco.org&quot;&gt;GOD&#x27;S PANTRY MINISTRY&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a food pantry.     &lt;/div&gt;`)[0];
#                 popup_52842327355bd43c0b5b195e5b6a7732.setContent(html_a48aecd312f7fb8f3757daa9d3ad24b4);
#
#
#
#         marker_bc07c815850a1154d63dcbea3e1eb56f.bindPopup(popup_52842327355bd43c0b5b195e5b6a7732)
#         ;
#
#
#
#
#             var marker_30adeff85d6f93be4f47e470c6646b56 = L.marker(
#                 [38.7845737, -104.7478808],
#                 {}
#             ).addTo(map_f57f7705dbb8733ec4dbbd45f105fd32);
#
#
#         var popup_34318230662ad7d8b72feaf60eda4b88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4e1691dec3a37bdbc4ebfa59038a907 = $(`&lt;div id=&quot;html_a4e1691dec3a37bdbc4ebfa59038a907&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CITY OF COLORADO SPRINGS&lt;/strong&gt;&lt;br&gt;     4290 Deerfield Hills Rd&lt;br&gt;     Colorado Springs, CO 80916&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 385-5996&quot;&gt;(719) 385-5996&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://coloradosprings.gov/deeraeld-hills-community-center&quot;&gt;CITY OF COLORADO SPRINGS&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a drive-thru style food pantry to those in need.     &lt;/div&gt;`)[0];
#                 popup_34318230662ad7d8b72feaf60eda4b88.setContent(html_a4e1691dec3a37bdbc4ebfa59038a907);
#
#
#
#         marker_30adeff85d6f93be4f47e470c6646b56.bindPopup(popup_34318230662ad7d8b72feaf60eda4b88)
#         ;
#
#
#
#
#             var marker_23dc52ddbb0cd2b8e2481c115b013feb = L.marker(
#                 [38.8649785, -104.815912],
#                 {}
#             ).addTo(map_f57f7705dbb8733ec4dbbd45f105fd32);
#
#
#         var popup_ac8fde96dcd2e5a970dd7e60c1fe17dc = L.popup({&quot;maxWidth&quot;

# %%
# Example: Search for food pantries in a specific city
city_search = "Aurora"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7108, -104.8125], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_aurora_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06062dbcef54f9311b1a3d683234a1a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06062dbcef54f9311b1a3d683234a1a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06062dbcef54f9311b1a3d683234a1a0 = L.map(
#                 &quot;map_06062dbcef54f9311b1a3d683234a1a0&quot;,
#                 {
#                     center: [39.7108, -104.8125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44f03c0a177480e313c5205443c36f73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_44f03c0a177480e313c5205443c36f73.addTo(map_06062dbcef54f9311b1a3d683234a1a0);
#
#
#             var marker_a9560612df1a1b895e78d2a725891786 = L.marker(
#                 [39.6746072, -104.7782004],
#                 {}
#             ).addTo(map_06062dbcef54f9311b1a3d683234a1a0);
#
#
#         var popup_f0cde5583ea83644b2d67f4bb0c2cad6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82d8254714e7d084951dd73aacf6bf36 = $(`&lt;div id=&quot;html_82d8254714e7d084951dd73aacf6bf36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;NEW LIFE COMMUNITY CHURCH&lt;/strong&gt;&lt;br&gt;     17690 E Iliff Ave&lt;br&gt;     Aurora, CO 80013&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 368-7567&quot;&gt;(303) 368-7567&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://nlccaurora.org&quot;&gt;NEW LIFE COMMUNITY CHURCH&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides bags of food to the community. The pantry may be visited on a monthly or bi-monthly basis.     &lt;/div&gt;`)[0];
#                 popup_f0cde5583ea83644b2d67f4bb0c2cad6.setContent(html_82d8254714e7d084951dd73aacf6bf36);
#
#
#
#         marker_a9560612df1a1b895e78d2a725891786.bindPopup(popup_f0cde5583ea83644b2d67f4bb0c2cad6)
#         ;
#
#
#
#
#             var marker_9a54ded5d4833c69334a4d6ddea97212 = L.marker(
#                 [39.6961142, -104.8550663],
#                 {}
#             ).addTo(map_06062dbcef54f9311b1a3d683234a1a0);
#
#
#         var popup_c9a2bf4bab9da8c5eb73098c17c665b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_189884001a995fe2329d584e2dc8001c = $(`&lt;div id=&quot;html_189884001a995fe2329d584e2dc8001c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AURORA FIRST SEVENTH DAY ADVENTIST CHURCH&lt;/strong&gt;&lt;br&gt;     11400 E Mississippi Ave&lt;br&gt;     Aurora, CO 80012&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 755-1617&quot;&gt;(303) 755-1617&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://auroraarstco.adventistchurch.org&quot;&gt;AURORA FIRST SEVENTH DAY ADVENTIST CHURCH&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a food and clothing bank for the community.     &lt;/div&gt;`)[0];
#                 popup_c9a2bf4bab9da8c5eb73098c17c665b3.setContent(html_189884001a995fe2329d584e2dc8001c);
#
#
#
#         marker_9a54ded5d4833c69334a4d6ddea97212.bindPopup(popup_c9a2bf4bab9da8c5eb73098c17c665b3)
#         ;
#
#
#
#
#             var marker_7f6419777d86b6cbc21ff7871ba0a131 = L.marker(
#                 [39.742282, -104.8661782],
#                 {}
#             ).addTo(map_06062dbcef54f9311b1a3d683234a1a0);
#
#
#         var popup_08e571717e41fac23d88f9bed9803589 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c520b46c8081c1729596630858e6bfd = $(`&lt;div id=&quot;html_4c520b46c8081c1729596630858e6bfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;VILLAGE EXCHANGE CENTER&lt;/strong&gt;&lt;br&gt;     1609 Havana St&lt;br&gt;     Aurora, CO 80010&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(720) 668-9968&quot;&gt;(720) 668-9968&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://villageexchangecenter.org/programs/village-pantry/&quot;&gt;VILLAGE EXCHANGE CENTER&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides individuals and families with culturally relevant food and personal hygiene items, including: Fresh produce Meals Diapers Toiletries     &lt;/div&gt;`)[0];
#                 popup_08e571717e41fac23d88f9bed9803589.setContent(html_4c520b46c8081c1729596630858e6bfd);
#
#
#
#         marker_7f6419777d86b6cbc21ff7871ba0a131.bindPopup(popup_08e571717e41fac23d88f9bed9803589)
#         ;
#
#
#
#
#             var marker_1e7ffd18e3bc78dfc798fe3e294c19c3 = L.marker(
#                 [39.6810838, -104.826839],

# %%
# Example: Search for food pantries in a specific city
city_search = "Fort Collins"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.5853, -105.0844], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_fort_collins_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fc865a6124774d42eccb69960dacf53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fc865a6124774d42eccb69960dacf53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fc865a6124774d42eccb69960dacf53 = L.map(
#                 &quot;map_8fc865a6124774d42eccb69960dacf53&quot;,
#                 {
#                     center: [40.5853, -105.0844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_553fbb87a246997872c1153705e6a237 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_553fbb87a246997872c1153705e6a237.addTo(map_8fc865a6124774d42eccb69960dacf53);
#
#
#             var marker_e7b8258847db433c392ab4c5a974aca5 = L.marker(
#                 [40.5872724, -105.1219739],
#                 {}
#             ).addTo(map_8fc865a6124774d42eccb69960dacf53);
#
#
#         var popup_1e4792ddfb5c5110dd7030a05f4b005e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ecb18e6776dbf72592a9ab51b379c26 = $(`&lt;div id=&quot;html_5ecb18e6776dbf72592a9ab51b379c26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK FOR LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     201 S Impala Dr&lt;br&gt;     Fort Collins, CO 80521&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 493-4477&quot;&gt;(970) 493-4477&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://foodbanklarimer.org/mobiles&quot;&gt;FOOD BANK FOR LARIMER COUNTY&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Offers a drive-through mobile food pantry for those in need.     &lt;/div&gt;`)[0];
#                 popup_1e4792ddfb5c5110dd7030a05f4b005e.setContent(html_5ecb18e6776dbf72592a9ab51b379c26);
#
#
#
#         marker_e7b8258847db433c392ab4c5a974aca5.bindPopup(popup_1e4792ddfb5c5110dd7030a05f4b005e)
#         ;
#
#
#
#
#             var marker_364fe7922ccef5b7ed5af5974676fa32 = L.marker(
#                 [40.6047193, -105.0725555],
#                 {}
#             ).addTo(map_8fc865a6124774d42eccb69960dacf53);
#
#
#         var popup_59dd3e34f432445f6d22f7b865a6255b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_300edc9b1e5ad80b00a049b088d2d2d0 = $(`&lt;div id=&quot;html_300edc9b1e5ad80b00a049b088d2d2d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK FOR LARIMER COUNTY&lt;/strong&gt;&lt;br&gt;     1301 Blue Spruce Dr&lt;br&gt;     Fort Collins, CO 80524&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 493-4477&quot;&gt;(970) 493-4477&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://foodbanklarimer.org/our-programs&quot;&gt;FOOD BANK FOR LARIMER COUNTY&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a client choice food pantry for individuals in need. Also distributes the Commodities Supplemental Food Program (CSFP) to eligible seniors and The Emergency Food Assistance Program (TFAP)...     &lt;/div&gt;`)[0];
#                 popup_59dd3e34f432445f6d22f7b865a6255b.setContent(html_300edc9b1e5ad80b00a049b088d2d2d0);
#
#
#
#         marker_364fe7922ccef5b7ed5af5974676fa32.bindPopup(popup_59dd3e34f432445f6d22f7b865a6255b)
#         ;
#
#
#
#
#             var marker_3a2c700800d7280a7aab3abeae21a3c5 = L.marker(
#                 [40.533596, -105.0800634],
#                 {}
#             ).addTo(map_8fc865a6124774d42eccb69960dacf53);
#
#
#         var popup_78cb055ce2d4a64d04ebc859863e00bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b21e813e1723feeae4f73cbcefa932c = $(`&lt;div id=&quot;html_3b21e813e1723feeae4f73cbcefa932c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;SALVATION ARMY FORT COLLINS&lt;/strong&gt;&lt;br&gt;     3901 S Mason St&lt;br&gt;     Fort Collins, CO 80525&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 207-4472 Ext 201&quot;&gt;(970) 207-4472 Ext 201&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://fortcollins.salvationarmy.org/fort_collins_corps/overcome-poverty&quot;&gt;SALVATION ARMY FORT COLLINS&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides food boxes and clothing for individuals in need. When available, also provides: Hygiene items Diapers and wipes Pet food Period kits     &lt;/div&gt;`)[0];
#                 popup_78cb055ce2d4a64d04ebc859863e00bb.setContent(html_3b21e813e1723feeae4f73cbcefa932c);
#
#
#
#         marker_3a2c700800d7280a7aab3abeae21a3c5.bindPopup(popup_78cb055ce2d4a64d04ebc85986

# %%
# Example: Search for food pantries in a specific city
city_search = "Lakewood"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.7109, -105.0815], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_lakewood_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a859a30fc6af834a29a4476ea19dda5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a859a30fc6af834a29a4476ea19dda5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a859a30fc6af834a29a4476ea19dda5f = L.map(
#                 &quot;map_a859a30fc6af834a29a4476ea19dda5f&quot;,
#                 {
#                     center: [39.7109, -105.0815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_571cf7a8a89eb8a8e01e2a424fedd3a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_571cf7a8a89eb8a8e01e2a424fedd3a2.addTo(map_a859a30fc6af834a29a4476ea19dda5f);
#
#
#             var marker_e5bd14628f4402b621affaff25f44cd2 = L.marker(
#                 [39.6907746, -105.0714054],
#                 {}
#             ).addTo(map_a859a30fc6af834a29a4476ea19dda5f);
#
#
#         var popup_847f6fabdc78e1d7aad7925a1ba3f95a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5cac25139ec061269308266d30df5216 = $(`&lt;div id=&quot;html_5cac25139ec061269308266d30df5216&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;FOOD BANK OF THE ROCKIES&lt;/strong&gt;&lt;br&gt;     1450 S Pierce St&lt;br&gt;     Lakewood, CO 80232&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 375-5853&quot;&gt;(303) 375-5853&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://foodbankrockies.org&quot;&gt;FOOD BANK OF THE ROCKIES&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides food to communities by sending semi-trucks to set locations and distributing food for 1-2 hours.      &lt;/div&gt;`)[0];
#                 popup_847f6fabdc78e1d7aad7925a1ba3f95a.setContent(html_5cac25139ec061269308266d30df5216);
#
#
#
#         marker_e5bd14628f4402b621affaff25f44cd2.bindPopup(popup_847f6fabdc78e1d7aad7925a1ba3f95a)
#         ;
#
#
#
#
#             var marker_c9424f5c01f1573902fdd0d6a66999ae = L.marker(
#                 [39.7385136, -105.094918],
#                 {}
#             ).addTo(map_a859a30fc6af834a29a4476ea19dda5f);
#
#
#         var popup_d3bf586225b54335005a3b93f0313711 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b47b200e876e1f50301a5f6709b7546d = $(`&lt;div id=&quot;html_b47b200e876e1f50301a5f6709b7546d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ACTION CENTER&lt;/strong&gt;&lt;br&gt;     8745 W 14th Ave&lt;br&gt;     Lakewood, CO 80215&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 237-7704&quot;&gt;(303) 237-7704&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://theactioncenter.org&quot;&gt;ACTION CENTER&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Offers a community food pantry that individuals can utilize once a month. Groceries vary by day, but typically include non-perishable and perishable food items such as: Fresh vegetables Fruits Dairy Proteins Emergency diapers and personal hygiene items may...     &lt;/div&gt;`)[0];
#                 popup_d3bf586225b54335005a3b93f0313711.setContent(html_b47b200e876e1f50301a5f6709b7546d);
#
#
#
#         marker_c9424f5c01f1573902fdd0d6a66999ae.bindPopup(popup_d3bf586225b54335005a3b93f0313711)
#         ;
#
#
#
#
#             var marker_32238cde4e8c365056293e2378540fe4 = L.marker(
#                 [39.7271071, -105.0816301],
#                 {}
#             ).addTo(map_a859a30fc6af834a29a4476ea19dda5f);
#
#
#         var popup_90e7cbd8b05c3c2c98dcbe4cac317eaf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aff45a215e6f776254366e099511101e = $(`&lt;div id=&quot;html_aff45a215e6f776254366e099511101e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CAT CARE SOCIETY&lt;/strong&gt;&lt;br&gt;     5787 W 6th Ave&lt;br&gt;     Lakewood, CO 80214&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 239-9680&quot;&gt;(303) 239-9680&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://catcaresociety.org/programs/#nibbles-kibbles&quot;&gt;CAT CARE SOCIETY&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Offers cat food and supplies to individuals who are experiencing temporary financial challenges.     &lt;/div&gt;`)[0];
#                 popup_90e7cbd8b05c3c2c98dcbe4cac317eaf.setContent(html_aff45a215e6f776254366e099511101e);
#
#
#
#         marker_32238cde4e8c365056293e2378540fe4.bindPopup(popup_90e7cbd8b05c3c2c98dcbe4cac317eaf)
#         ;
#
#
#
#
#             var marker_419e0a3882b8

# %%
# Example: Search for food pantries in a specific city
city_search = "Arvada"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.8028, -105.0875], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_arvada_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fe86b4be8de4b2268ce34a86e306455 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fe86b4be8de4b2268ce34a86e306455&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fe86b4be8de4b2268ce34a86e306455 = L.map(
#                 &quot;map_3fe86b4be8de4b2268ce34a86e306455&quot;,
#                 {
#                     center: [39.8028, -105.0875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00e101e8ca53a21ac49e58b953d97c29 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_00e101e8ca53a21ac49e58b953d97c29.addTo(map_3fe86b4be8de4b2268ce34a86e306455);
#
#
#             var marker_75d1be7e1c43009a4d2b737723c45c13 = L.marker(
#                 [39.800294, -105.0928581],
#                 {}
#             ).addTo(map_3fe86b4be8de4b2268ce34a86e306455);
#
#
#         var popup_89ec788db6f0d71d3bd3c88eda0aee6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07197090267a7c3489c4c1db8257c10a = $(`&lt;div id=&quot;html_07197090267a7c3489c4c1db8257c10a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY TABLE&lt;/strong&gt;&lt;br&gt;     8555 W 57th Ave&lt;br&gt;     Arvada, CO 80002&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 424-6685&quot;&gt;(303) 424-6685&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://cotable.org&quot;&gt;COMMUNITY TABLE&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides emergency food to individuals and families. Each client selects a supply of food based on household size. Families and individuals may use this program when needed...     &lt;/div&gt;`)[0];
#                 popup_89ec788db6f0d71d3bd3c88eda0aee6d.setContent(html_07197090267a7c3489c4c1db8257c10a);
#
#
#
#         marker_75d1be7e1c43009a4d2b737723c45c13.bindPopup(popup_89ec788db6f0d71d3bd3c88eda0aee6d)
#         ;
#
#
#
#
#             var marker_32211e831329ecfd32eb3fb8d83e3e0a = L.marker(
#                 [39.8054671, -105.0622284],
#                 {}
#             ).addTo(map_3fe86b4be8de4b2268ce34a86e306455);
#
#
#         var popup_7e30687504186efdc0a057aa21e662e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f23cb441c939d09b881b31fed0cfe5f = $(`&lt;div id=&quot;html_0f23cb441c939d09b881b31fed0cfe5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;AGAPE LIFE CHURCH&lt;/strong&gt;&lt;br&gt;     5970 W 60th Ave&lt;br&gt;     Arvada, CO 80003&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 431-6481&quot;&gt;(303) 431-6481&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://agapelife.org/food-outreach/&quot;&gt;AGAPE LIFE CHURCH&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a food pantry and hosts a monthly TEFAP (The Emergency Food Assistance Program) food distribution site.     &lt;/div&gt;`)[0];
#                 popup_7e30687504186efdc0a057aa21e662e7.setContent(html_0f23cb441c939d09b881b31fed0cfe5f);
#
#
#
#         marker_32211e831329ecfd32eb3fb8d83e3e0a.bindPopup(popup_7e30687504186efdc0a057aa21e662e7)
#         ;
#
#
#
#
#             tile_layer_00e101e8ca53a21ac49e58b953d97c29.addTo(map_3fe86b4be8de4b2268ce34a86e306455);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Example: Search for food pantries in a specific city
city_search = "Greeley"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.4233, -104.7112], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_greeley_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1059b5e7b6a68b7775fd22b5283ab38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1059b5e7b6a68b7775fd22b5283ab38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1059b5e7b6a68b7775fd22b5283ab38 = L.map(
#                 &quot;map_a1059b5e7b6a68b7775fd22b5283ab38&quot;,
#                 {
#                     center: [40.4233, -104.7112],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9bd4e93a933e395b916c453f13ef9ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e9bd4e93a933e395b916c453f13ef9ad.addTo(map_a1059b5e7b6a68b7775fd22b5283ab38);
#
#
#             var marker_03faaf0e28dbd198dff48d73bbc2fbd9 = L.marker(
#                 [40.4437132, -104.6987994],
#                 {}
#             ).addTo(map_a1059b5e7b6a68b7775fd22b5283ab38);
#
#
#         var popup_8600b107ac9c3452faf0b8d347136ba7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_167ad77f019e2d1f8c04bf96477e3ed0 = $(`&lt;div id=&quot;html_167ad77f019e2d1f8c04bf96477e3ed0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WELD FOOD BANK&lt;/strong&gt;&lt;br&gt;     1108 H St&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 356-2199&quot;&gt;(970) 356-2199&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://weldfoodbank.org/emergency-food-program/&quot;&gt;WELD FOOD BANK&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a box of basic food staples to qualified families or individuals in crisis. Individuals can receive a food box on an emergency basis, not more than once per week...     &lt;/div&gt;`)[0];
#                 popup_8600b107ac9c3452faf0b8d347136ba7.setContent(html_167ad77f019e2d1f8c04bf96477e3ed0);
#
#
#
#         marker_03faaf0e28dbd198dff48d73bbc2fbd9.bindPopup(popup_8600b107ac9c3452faf0b8d347136ba7)
#         ;
#
#
#
#
#             var marker_c9e5ac45077d6b10c45373cc34296d01 = L.marker(
#                 [40.4437132, -104.6987994],
#                 {}
#             ).addTo(map_a1059b5e7b6a68b7775fd22b5283ab38);
#
#
#         var popup_22abeab9e038c334d1dcf02d23c095a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1da8f1b15873c1df41525fd51860507 = $(`&lt;div id=&quot;html_b1da8f1b15873c1df41525fd51860507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WELD FOOD BANK&lt;/strong&gt;&lt;br&gt;     1108 H St&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 356-2199&quot;&gt;(970) 356-2199&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://weldfoodbank.org/and-food-near-you&quot;&gt;WELD FOOD BANK&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Offers mobile food pantries at locations throughout Weld County.     &lt;/div&gt;`)[0];
#                 popup_22abeab9e038c334d1dcf02d23c095a5.setContent(html_b1da8f1b15873c1df41525fd51860507);
#
#
#
#         marker_c9e5ac45077d6b10c45373cc34296d01.bindPopup(popup_22abeab9e038c334d1dcf02d23c095a5)
#         ;
#
#
#
#
#             var marker_05151504fb77b59c2acfb711516f0322 = L.marker(
#                 [40.4437132, -104.6987994],
#                 {}
#             ).addTo(map_a1059b5e7b6a68b7775fd22b5283ab38);
#
#
#         var popup_0157159b8d2aeb91a5f96d6def3b9293 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a9e5fb55cbecc7d9f3eebb4040b1fe8 = $(`&lt;div id=&quot;html_6a9e5fb55cbecc7d9f3eebb4040b1fe8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;WELD FOOD BANK&lt;/strong&gt;&lt;br&gt;     1108 H Street&lt;br&gt;     Greeley, CO 80631&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 356-2199&quot;&gt;(970) 356-2199&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://weldfoodbank.org/and-food-near-you&quot;&gt;WELD FOOD BANK&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Offers mobile food pantries at locations throughout Weld County.     &lt;/div&gt;`)[0];
#                 popup_0157159b8d2aeb91a5f96d6def3b9293.setContent(html_6a9e5fb55cbecc7d9f3eebb4040b1fe8);
#
#
#
#         marker_05151504fb77b59c2acfb711516f0322.bindPopup(popup_0157159b8d2aeb91a5f96d6def3b9293)
#         ;
#
#
#
#
#             var marker_58feba2f6c9a2576a1c900e667a9fed9 = L.marker(
#                 [40.4209079, -104.6925472],
#                 {}
#             ).addTo(map_a1059b5e7b6a68b7775fd22b5283ab38);

# %%
# Example: Search for food pantries in a specific city
city_search = "Pueblo"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[38.2765, -104.6046], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_pueblo_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7a9f1f3d0a41b2e7fab2af140532625 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7a9f1f3d0a41b2e7fab2af140532625&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7a9f1f3d0a41b2e7fab2af140532625 = L.map(
#                 &quot;map_e7a9f1f3d0a41b2e7fab2af140532625&quot;,
#                 {
#                     center: [38.2765, -104.6046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a53ed740cd1047e315dc62601c01e87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5a53ed740cd1047e315dc62601c01e87.addTo(map_e7a9f1f3d0a41b2e7fab2af140532625);
#
#
#             var marker_22736842627ee74b2c89bdb0d7391196 = L.marker(
#                 [38.274091, -104.6197],
#                 {}
#             ).addTo(map_e7a9f1f3d0a41b2e7fab2af140532625);
#
#
#         var popup_fff5bbc70b3cd54b16a2743c521e6e47 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d33f7be651c5a7d27e5e348158c1252 = $(`&lt;div id=&quot;html_9d33f7be651c5a7d27e5e348158c1252&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CENTER TOWARD SELF-RELIANCE&lt;/strong&gt;&lt;br&gt;     901 W 8th St&lt;br&gt;     Pueblo, CO 81003&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 546-1271&quot;&gt;(719) 546-1271&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;https://cfdpueblo.org&quot;&gt;CENTER TOWARD SELF-RELIANCE&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Food Pantry provides food assistance to low-income individuals who are in need     &lt;/div&gt;`)[0];
#                 popup_fff5bbc70b3cd54b16a2743c521e6e47.setContent(html_9d33f7be651c5a7d27e5e348158c1252);
#
#
#
#         marker_22736842627ee74b2c89bdb0d7391196.bindPopup(popup_fff5bbc70b3cd54b16a2743c521e6e47)
#         ;
#
#
#
#
#             var marker_1b96c72bf97d0b5349c3f4856a1cffee = L.marker(
#                 [38.2631861, -104.6371719],
#                 {}
#             ).addTo(map_e7a9f1f3d0a41b2e7fab2af140532625);
#
#
#         var popup_82d4fcb2ca33050a1cc11d88996e314e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f22109df4d60a1a5685cd1c06448c7bd = $(`&lt;div id=&quot;html_f22109df4d60a1a5685cd1c06448c7bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/strong&gt;&lt;br&gt;     900 W Orman Ave&lt;br&gt;     Pueblo, CO 81004&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 296-6995&quot;&gt;(719) 296-6995&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;https://careandshare.org&quot;&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Food Pantry providing food to those in need.     &lt;/div&gt;`)[0];
#                 popup_82d4fcb2ca33050a1cc11d88996e314e.setContent(html_f22109df4d60a1a5685cd1c06448c7bd);
#
#
#
#         marker_1b96c72bf97d0b5349c3f4856a1cffee.bindPopup(popup_82d4fcb2ca33050a1cc11d88996e314e)
#         ;
#
#
#
#
#             var marker_e9d634e515ebd4c30cd1d7cf0554f4bd = L.marker(
#                 [38.327273, -104.77256],
#                 {}
#             ).addTo(map_e7a9f1f3d0a41b2e7fab2af140532625);
#
#
#         var popup_3bd6c3a30760a246059737d8da30ac7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed2b38d9f4d323491844c110ae636ece = $(`&lt;div id=&quot;html_ed2b38d9f4d323491844c110ae636ece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/strong&gt;&lt;br&gt;     434 S Conquistador Ave&lt;br&gt;     Pueblo West, CO 81007&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(719) 547-3088&quot;&gt;(719) 547-3088&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;No Website Listed&quot;&gt;CARE AND SHARE - PUEBLO DISTRIBUTION CENTER&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Food Pantry providing food to those in need.     &lt;/div&gt;`)[0];
#                 popup_3bd6c3a30760a246059737d8da30ac7a.setContent(html_ed2b38d9f4d323491844c110ae636ece);
#
#
#
#         marker_e9d634e515ebd4c30cd1d7cf0554f4bd.bindPopup(popup_3bd6c3a30760a246059737d8da30ac7a)
#         ;
#
#
#
#
#             var marker_072b545d8e2986b6b140e3380b8f4796 = L.marker(
#                 [38.2239923, -104.6567669],
#                 {}
#             ).addTo(map_e7a9f1f3d0a41b2e7fab2af140532625);
#
#
#         var popup_868ffcc9e8050374e95de8156a6e6999

# %%
# Example: Search for food pantries in a specific city
city_search = "Boulder"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[40.0150, -105.2705], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_boulder_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c91ad6905ecccff56db605c577846704 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c91ad6905ecccff56db605c577846704&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c91ad6905ecccff56db605c577846704 = L.map(
#                 &quot;map_c91ad6905ecccff56db605c577846704&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44d7489689fc45a738f672f0adc4bcc7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_44d7489689fc45a738f672f0adc4bcc7.addTo(map_c91ad6905ecccff56db605c577846704);
#
#
#             var marker_1fc27e00c6b3096e6e4f367e966721e0 = L.marker(
#                 [40.102555, -105.3632079],
#                 {}
#             ).addTo(map_c91ad6905ecccff56db605c577846704);
#
#
#         var popup_77f09c6fab44a6904f19c12e9fb9227e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fc655921fc5ff062db18aced5c79611 = $(`&lt;div id=&quot;html_3fc655921fc5ff062db18aced5c79611&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COLORADO PET PANTRY&lt;/strong&gt;&lt;br&gt;     P.O. Box 323&lt;br&gt;     Boulder, CO 80306&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 818-0618&quot;&gt;(303) 818-0618&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://coloradopetpantry.org/events/category/pet-food-banks/&quot;&gt;COLORADO PET PANTRY&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides free temporary pet food through various food pantry organizations throughout Colorado.     &lt;/div&gt;`)[0];
#                 popup_77f09c6fab44a6904f19c12e9fb9227e.setContent(html_3fc655921fc5ff062db18aced5c79611);
#
#
#
#         marker_1fc27e00c6b3096e6e4f367e966721e0.bindPopup(popup_77f09c6fab44a6904f19c12e9fb9227e)
#         ;
#
#
#
#
#             var marker_88228bc6cb7888583aa31357d0bf81da = L.marker(
#                 [40.058333, -105.2778705],
#                 {}
#             ).addTo(map_c91ad6905ecccff56db605c577846704);
#
#
#         var popup_44d022ccccb5ae07de9f61e8cea31845 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10256853254392f015fd3e34d47f78e0 = $(`&lt;div id=&quot;html_10256853254392f015fd3e34d47f78e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;EMERGENCY FAMILY ASSISTANCE ASSOCIATION&lt;/strong&gt;&lt;br&gt;     1575 Yarmouth Ave&lt;br&gt;     Boulder, CO 80304&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 442-3042&quot;&gt;(303) 442-3042&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://efaa.org/get-help/food-bank/&quot;&gt;EMERGENCY FAMILY ASSISTANCE ASSOCIATION&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a food pantry to people living in the City of Boulder and Boulder County Mountain Communities with access to a kitchen. Eligible households may visit the food bank twice per month...     &lt;/div&gt;`)[0];
#                 popup_44d022ccccb5ae07de9f61e8cea31845.setContent(html_10256853254392f015fd3e34d47f78e0);
#
#
#
#         marker_88228bc6cb7888583aa31357d0bf81da.bindPopup(popup_44d022ccccb5ae07de9f61e8cea31845)
#         ;
#
#
#
#
#             var marker_b4eabbaf0cef28f4069cc21d0cc12254 = L.marker(
#                 [39.990138, -105.232704],
#                 {}
#             ).addTo(map_c91ad6905ecccff56db605c577846704);
#
#
#         var popup_a7a77bd07a508d76cc176336bba1ee8f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb7b96947437ee6a01876245354f5eec = $(`&lt;div id=&quot;html_bb7b96947437ee6a01876245354f5eec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;COMMUNITY FOOD SHARE&lt;/strong&gt;&lt;br&gt;     4990 Osage Dr&lt;br&gt;     Boulder, CO 80303&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(303) 652-3663&quot;&gt;(303) 652-3663&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://communityfoodshare.org/get-food/services-we-provide/mobile-pantries/&quot;&gt;COMMUNITY FOOD SHARE&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Operates a mobile food pantry at rotating locations, offering: Fresh produce Dairy Non-perishable pantry items     &lt;/div&gt;`)[0];
#                 popup_a7a77bd07a508d76cc176336bba1ee8f.setContent(html_bb7b96947437ee6a01876245354f5eec);
#
#
#
#         marker_b4eabbaf0cef28f4069cc21d0cc12254.bindPopup(popup_a7a77bd07a508d76cc176336bba1ee8f)
#         ;

# %%
# Example: Search for food pantries in a specific city
city_search = "Grand Junction"  # Replace with user input

# Filter the DataFrame based on the city
filtered_df = df[df['City'].str.contains(city_search, case=False, na=False)]

# Create a map for the filtered results
m_filtered = folium.Map(location=[39.0714, -108.5497], zoom_start=7)

for idx, row in filtered_df.iterrows():
    popup_text = f"""
    <strong>{row['Agency']}</strong><br>
    {row['Address']}<br>
    {row['City']}, {row['State']} {row['Zip']}<br>
    <b>Phone:</b><br><a href="tel:{row['Phone']}">{row['Phone']}</a><br>
    <b>Website:</b><br> <a href="{row['Website']}">{row['Agency']}</a><br>
    <b>Services:</b><br> {row['Services']}
    """
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
    ).add_to(m_filtered)

# Save the filtered map as an HTML file
m_filtered.save("filtered_colorado_food_pantries_map_grand_junction_v2.html")

# Display the filtered map in the notebook
m_filtered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca91fa5673f86bb9276068b785212512 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca91fa5673f86bb9276068b785212512&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca91fa5673f86bb9276068b785212512 = L.map(
#                 &quot;map_ca91fa5673f86bb9276068b785212512&quot;,
#                 {
#                     center: [39.0714, -108.5497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb75f2b5b4c587b9982af89ab9f2c622 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb75f2b5b4c587b9982af89ab9f2c622.addTo(map_ca91fa5673f86bb9276068b785212512);
#
#
#             var marker_9aebebc34f0469866ff4f2b3269ba86d = L.marker(
#                 [39.0655869, -108.5712505],
#                 {}
#             ).addTo(map_ca91fa5673f86bb9276068b785212512);
#
#
#         var popup_bfe67345c2506470a40b00d24f280838 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7501123a7e95fe24ea524aa6340529e = $(`&lt;div id=&quot;html_a7501123a7e95fe24ea524aa6340529e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/strong&gt;&lt;br&gt;     245 S 1st St&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 241-3658&quot;&gt;(970) 241-3658&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://catholicoutreach.org&quot;&gt;GRAND VALLEY CATHOLIC OUTREACH&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides food box for Mesa County residents in need on a once-a-month basis. Food type is available depending on donated items available...     &lt;/div&gt;`)[0];
#                 popup_bfe67345c2506470a40b00d24f280838.setContent(html_a7501123a7e95fe24ea524aa6340529e);
#
#
#
#         marker_9aebebc34f0469866ff4f2b3269ba86d.bindPopup(popup_bfe67345c2506470a40b00d24f280838)
#         ;
#
#
#
#
#             var marker_7838fa90155735974833e5434f801811 = L.marker(
#                 [39.0415079, -108.5435434],
#                 {}
#             ).addTo(map_ca91fa5673f86bb9276068b785212512);
#
#
#         var popup_7c0c2208331bdbcad85ef57f70b74e39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3b96fc56d2ee25beac9df21ffd8f5f8 = $(`&lt;div id=&quot;html_f3b96fc56d2ee25beac9df21ffd8f5f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;ORCHARD MESA BAPTIST CHURCH&lt;/strong&gt;&lt;br&gt;     2748 B 1/2 Rd&lt;br&gt;     Grand Junction, CO 81503&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 242-2355&quot;&gt;(970) 242-2355&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://ombcgj.com/&quot;&gt;ORCHARD MESA BAPTIST CHURCH&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a food box to those in need once a month and up to 3 times per calendar year. Additional assistance can be granted on case by case basis by the food pantry director...     &lt;/div&gt;`)[0];
#                 popup_7c0c2208331bdbcad85ef57f70b74e39.setContent(html_f3b96fc56d2ee25beac9df21ffd8f5f8);
#
#
#
#         marker_7838fa90155735974833e5434f801811.bindPopup(popup_7c0c2208331bdbcad85ef57f70b74e39)
#         ;
#
#
#
#
#             var marker_13e06fde5126dbea0cdac86f6f7ea2d5 = L.marker(
#                 [39.0842939, -108.5210788],
#                 {}
#             ).addTo(map_ca91fa5673f86bb9276068b785212512);
#
#
#         var popup_ba85a851d2089def2f595626964f3e8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_157f99b790ad1165f704674ddd79d29f = $(`&lt;div id=&quot;html_157f99b790ad1165f704674ddd79d29f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;strong&gt;JUNCTION COMMUNITY CHURCH&lt;/strong&gt;&lt;br&gt;     2867 Orchard Ave&lt;br&gt;     Grand Junction, CO 81501&lt;br&gt;     &lt;b&gt;Phone:&lt;/b&gt;&lt;br&gt;&lt;a href=&quot;tel:(970) 243-0757&quot;&gt;(970) 243-0757&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Website:&lt;/b&gt;&lt;br&gt; &lt;a href=&quot;http://jctcc.net/saras-pantry&quot;&gt;JUNCTION COMMUNITY CHURCH&lt;/a&gt;&lt;br&gt;     &lt;b&gt;Services:&lt;/b&gt;&lt;br&gt; Provides a food box to individuals, seniors and families in need in the community. Families are limited to one box a month.     &lt;/div&gt;`)[0];
#                 popup_ba85a851d2089def2f595626964f3e8c.setContent(html_157f99b790ad1165f704674ddd79d29f);
#
#
#
#         marker_13e06fde5126dbea0cdac86f6f7ea2d5.bindPopup(popup_ba85a851d2089def2f595626964f3e8c)
#         ;
#
#
#
#
#             va

# %% [markdown]
# ## Step 5: Export Cleaned Data to CSV

# %%
# Export the cleaned DataFrame to a CSV file
df.to_csv("cleaned_colorado_food_pantries_v3.csv", index=False)

# Confirm the export
print("Data exported to cleaned_colorado_food_pantries_v3.csv")
# Out:
# Data exported to cleaned_colorado_food_pantries_v3.csv
